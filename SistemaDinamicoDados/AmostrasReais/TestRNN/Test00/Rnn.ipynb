# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Carrega e prepara os dados
data = pd.read_csv("../../Data.csv")
data = data.drop(columns=["VD", "VE", "tempo"])
data.index = (np.arange(0, len(data), 1).astype(float) * 0.07).round(5)

data = data.rename(columns={
    "Setpoint VD": "Wd",
    "Setpoint VE": "We",
    "Theta": "theta(Wd,We)",
    "X": "x(Wd,We)",
    "Y": "y(Wd,We)",
})

# %%
import seaborn as sns
from sklearn.preprocessing import StandardScaler

PREDICTORS = ["Wd", "We"]
TARGET = ["theta(Wd,We)"]

def PlotTimeSeries(df, img_name="data.svg", PlotOut=True):    
    # Estilo Seaborn
    sns.set_theme(style="whitegrid")

    # Criando a figura
    fig, ax1 = plt.subplots(figsize=(12, 6))

    # Plotando Wd e We como linhas
    for preds in PREDICTORS:
        sns.lineplot(x=df.index, y=df[preds], ax=ax1, marker="o", label=preds,  linewidth=2)

    if PlotOut:
        ax2 = ax1.twinx()
        for target in TARGET:
            sns.lineplot(x=df.index, y=df[target], ax=ax2, marker="o", label=target, linestyle="dashed", linewidth=2, color="red")
            ax2.set_ylabel("Posição Angular", fontsize=12, color="gray")

    # Ajustando os rótulos dos eixos
    ax1.set_xlabel("Tempo (s) - Período de amostragem (T=0.07 s)", fontsize=12)
    ax1.set_ylabel("Velocidade Angular", fontsize=12, color="black")

    # Adicionando legendas
    ax1.legend(loc="upper left")
    if PlotOut:
        ax2.legend(loc="upper right")

    # Título
    plt.title("Posição angular em função da velocidade nas rodas", fontsize=14)

    # Exibindo o gráfico
    plt.show()

# %%
PlotTimeSeries(data.head(32))

# %%
PREDICTORS = ["Wd", "We"]
TARGET = "theta(Wd,We)"

def get_XY(data, time_steps, units, output_dim):
    total_samples = (len(data) - time_steps) // time_steps

    X = []
    Y = []
    
    for i in range(total_samples):
        start_idx = i * time_steps
        end_idx = start_idx + time_steps

        X_seq = data.iloc[start_idx:end_idx][PREDICTORS].values  # shape: (time_steps, features)
        Y_target = data.iloc[end_idx][TARGET]  # escalar

        X.append(X_seq)
        Y.append(Y_target)

    X = np.array(X)  # shape: (batch, time_steps, features)
    Y =  Y = np.array(Y).reshape(-1, 1).repeat(output_dim, axis=1)  # shape (batch, output_dim)
    h0 = np.full((X.shape[0], units), fill_value=Y[0]) # shape (batch, units)

    print(f"Shape X (batch, time_steps, features): {X.shape}")
    print(f"Shape Y (batch, output_dim): {Y.shape}")
    print(f"Shape h0 (batch, units): {h0.shape}")
    
    return X, Y, h0

# %%
def PlotOut(valuer):
    sns.set_theme(style="whitegrid")

    fig, axs = plt.subplots(3, 1, figsize=(12, 12), sharey=False)

    datasets = [
        ('Treinamento', valuer.train_samples_y, valuer.train_pred),
        ('Validação', valuer.val_samples_y, valuer.val_pred),
        ('Teste', valuer.test_samples_y, valuer.test_pred)
    ]

    times = [
        np.arange(len(valuer.train_samples_y)),
        np.arange(len(valuer.val_samples_y)),
        np.arange(len(valuer.test_samples_y))
    ]

    for i, (title, y_true, y_pred) in enumerate(datasets):
        # Garante que são vetores 1D
        y_true = np.ravel(y_true)
        y_pred = np.ravel(y_pred)

        sns.lineplot(x=times[i], y=y_true, ax=axs[i], marker="o", label="Amostras Reais", linewidth=2)
        sns.lineplot(x=times[i], y=y_pred, ax=axs[i], marker="o", label="Valores preditos", linewidth=2)

        axs[i].set_title(f'{title}')
        axs[i].set_xlabel('Tempo')
        axs[i].set_ylabel('Valor')
        axs[i].legend()
        axs[i].grid(True)

    plt.suptitle('Comparação temporal: Predição (curva) vs Amostras Reais (pontos)')
    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()  
    
    path = f"./content/models/{valuer.fileName}.png"
    fig.savefig(path)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, root_mean_squared_error, mean_absolute_percentage_error 
from keras import layers, models, regularizers, initializers, optimizers
from keras.callbacks import EarlyStopping
from itertools import product


class EvalRNN:
    
    def __init__(self, dataset, epochs, time_steps, act_h, act_o):
        self.epochs = epochs
        self.Dataset = dataset
        self.output_dim = np.size(TARGET)
        self.time_steps = time_steps
        self.act_h = act_h
        self.act_o = act_o
        self.better_metrics = {}


    def SplitData(self, units):
        self.units = units
                
        train_data, test_data = train_test_split(self.Dataset, test_size=0.25, shuffle=False)
        train_data, val_data = train_test_split(train_data, test_size=0.15, shuffle=False)
                
        self.train_samples_x, self.train_samples_y, self.h0_train = get_XY(train_data, self.time_steps, units, self.output_dim)       
        self.val_samples_x, self.val_samples_y, self.h0_val = get_XY(val_data, self.time_steps, units, self.output_dim)
        self.test_samples_x, self.test_samples_y, self.h0_test = get_XY(test_data, self.time_steps, units, self.output_dim)

        self.time_steps = self.train_samples_x.shape[1]
        self.features = self.train_samples_x.shape[2]
        
    def BuildModel(self, hidden_sizes, param_reg):
        initializer = initializers.RandomUniform(minval=-0.5,
                                                maxval=0.5,
                                                # seed=np.random.randint(1, 10000)
                                                )
        regularizer = regularizers.L2(param_reg)
        inputs = layers.Input((self.time_steps, self.features))
        initial_state = layers.Input((self.units,))

        # Primeira camada RNN com estado inicial
        rnn_layer = layers.SimpleRNN(
            hidden_sizes[0],
            activation=self.act_h,
            kernel_regularizer=regularizer,
            kernel_initializer=initializer,
            return_sequences=(len(hidden_sizes) > 1)  
        )(inputs, initial_state=initial_state)

        # Demais camadas RNN
        for size in hidden_sizes[1:-1]:
            rnn_layer = layers.SimpleRNN(
                size,
                activation=self.act_h,
                kernel_regularizer=regularizer,
                kernel_initializer=initializer,
                return_sequences=True 
            )(rnn_layer)

        # Última camada RNN
        if len(hidden_sizes) > 1:
            rnn_layer = layers.SimpleRNN(
                hidden_sizes[-1],
                activation=self.act_h,
                kernel_regularizer=regularizer,
                kernel_initializer=initializer,
                return_sequences=False  
            )(rnn_layer)
       
       # Output mlp layer
        output = layers.Dense(self.output_dim,
                            activation=self.act_o,
                            kernel_regularizer=regularizer,
                            kernel_initializer=initializer)(rnn_layer)
        
        model = models.Model([inputs] + [initial_state], output)
        return(model)
    
    def CompileModel(self, model, lr):
        model.compile(loss="mse", optimizer=optimizers.Adam(learning_rate=lr))
        early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

        model.fit(
            [self.train_samples_x, self.h0_train],
            self.train_samples_y,
            epochs=self.epochs,
            validation_data=([self.val_samples_x, self.h0_val], self.val_samples_y),
            callbacks=[early_stop],
            verbose=False,
            shuffle=False   
        )
    
    def ComputeMetrics(self, model):
        self.train_pred = np.squeeze(model.predict([self.train_samples_x, self.h0_train]))
        self.val_pred = np.squeeze(model.predict([self.val_samples_x, self.h0_val]))
        self.test_pred = np.squeeze(model.predict([self.test_samples_x, self.h0_test]))


        return ({
                    'r2_training': r2_score(self.train_samples_y, self.train_pred),
                    'mse_training': mean_squared_error(self.train_samples_y, self.train_pred),
                    'mape_training': mean_absolute_percentage_error(self.train_samples_y, self.train_pred),
                    'rmse_training': root_mean_squared_error(self.train_samples_y, self.train_pred),

                    'r2_test': r2_score(self.test_samples_y, self.test_pred),
                    'mse_test': mean_squared_error(self.test_samples_y, self.test_pred),
                    'mape_test': mean_absolute_percentage_error(self.test_samples_y, self.test_pred),
                    'rmse_test': root_mean_squared_error(self.test_samples_y, self.test_pred),
                    
                    'r2_val': r2_score(self.val_samples_y, self.val_pred),
                    'mse_val': mean_squared_error(self.val_samples_y, self.val_pred),
                    'mape_val': mean_absolute_percentage_error(self.val_samples_y, self.val_pred),
                    'rmse_val': root_mean_squared_error(self.val_samples_y, self.val_pred),
            })

    def SaveModelWeights(self, model):
        path = f"./content/models/{self.fileName}.weights.h5"
        open(path,'w').close()
        model.save_weights(path) 

    def LoopWeights(self, model, run_times, lr, boundarie, sort_by, idx):
        better_model = 0
        save = False

        for i in range(run_times):
            print (f"+++++++++++ [{idx}] | {i + 1} ++++++++++++++++++")
            self.CompileModel(model, lr)
            metrics = self.ComputeMetrics(model)
            
            if (metrics[sort_by] >= boundarie): # should be >= to acsending metrics
                self.fileName = f"model_{idx}_{better_model}"
                self.SaveModelWeights(model)
                self.better_metrics[self.fileName] = metrics
                better_model += 1
                save = True
        return(save)

    def Evaluate(self, hidden_sizes, regularizers, learning_rate, run_times, boundarie, sort_by):
        for count, (hidden_size, reg, lr) in enumerate(product(hidden_sizes, regularizers, learning_rate), start=1):
            header =  f"Hidden Size={hidden_size}, regularizer={reg}, learning_rate={lr}"
            print(f"Testando combinacao{count}: {header}")
            
            self.SplitData(units=hidden_size[0])        
            model = self.BuildModel(hidden_size, reg)
            
            if (self.LoopWeights(model, run_times, lr, boundarie, sort_by, f"{count}") == True):        
                self.DisplayBetterResults(header, sort_by, f"{count}")
                PlotOut(self)
                
        self.better_metrics = {}
  
                
    def DisplayBetterResults(self, header, sort_by, dataset=0):
        df = pd.DataFrame.from_dict(self.better_metrics, orient='index')
        df = df.sort_values([sort_by])
        display(df)
        path = f'./content/results/metrics_{dataset}'
        df.to_excel(f"{path}.xlsx", index=True)
        print(f"DataFrame salvo em {path}")
        with open(f"{path}.txt", 'w') as arquivo:
            arquivo.write(header)
# Out:
# 2025-05-12 23:42:47.547097: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-12 23:42:47.819871: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-12 23:42:47.960401: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747093368.235842    2246 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747093368.377593    2246 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1747093369.223845    2246 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747093369.223887    2246 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747093369.223891    2246 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747093369.223893    2246 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-12 23:42:49.276545: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
Valuer = EvalRNN(dataset = data,
                epochs = 1000,
                time_steps = 2,
                act_h = 'tanh',
                act_o = 'sigmoid',
                )
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
Valuer.Evaluate(hidden_sizes = [[30], [25], [2, 5], [2, 10], [5, 5], [5, 10]],
            regularizers=[0.02, 0.2],
            learning_rate=[0.01, 0.1],
            run_times = 10, 
            boundarie = 0.6,
            sort_by = 'r2_training',
)
# Out:
# Testando combinacao1: Hidden Size=[30], regularizer=0.02, learning_rate=0.01
# Shape X (batch, time_steps, features): (682, 2, 2)
# Shape Y (batch, output_dim): (682, 1)
# Shape h0 (batch, units): (682, 30)
# Shape X (batch, time_steps, features): (120, 2, 2)
# Shape Y (batch, output_dim): (120, 1)
# Shape h0 (batch, units): (120, 30)
# Shape X (batch, time_steps, features): (267, 2, 2)
# Shape Y (batch, output_dim): (267, 1)
# Shape h0 (batch, units): (267, 30)
# +++++++++++ [1] | 1 ++++++++++++++++++
# 2025-05-12 23:42:53.219816: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [1] | 2 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [1] | 3 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [1] | 4 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [1] | 5 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [1] | 6 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [1] | 7 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [1] | 8 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [1] | 9 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [1] | 10 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Testando combinacao2: Hidden Size=[30], regularizer=0.02, learning_rate=0.1
# Shape X (batch, time_steps, features): (682, 2, 2)
# Shape Y (batch, output_dim): (682, 1)
# Shape h0 (batch, units): (682, 30)
# Shape X (batch, time_steps, features): (120, 2, 2)
# Shape Y (batch, output_dim): (120, 1)
# Shape h0 (batch, units): (120, 30)
# Shape X (batch, time_steps, features): (267, 2, 2)
# Shape Y (batch, output_dim): (267, 1)
# Shape h0 (batch, units): (267, 30)
# +++++++++++ [2] | 1 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [2] | 2 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [2] | 3 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [2] | 4 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [2] | 5 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [2] | 6 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [2] | 7 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [2] | 8 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [2] | 9 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [2] | 10 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Testando combinacao3: Hidden Size=[30], regularizer=0.2, learning_rate=0.01
# Shape X (batch, time_steps, features): (682, 2, 2)
# Shape Y (batch, output_dim): (682, 1)
# Shape h0 (batch, units): (682, 30)
# Shape X (batch, time_steps, features): (120, 2, 2)
# Shape Y (batch, output_dim): (120, 1)
# Shape h0 (batch, units): (120, 30)
# Shape X (batch, time_steps, features): (267, 2, 2)
# Shape Y (batch, output_dim): (267, 1)
# Shape h0 (batch, units): (267, 30)
# +++++++++++ [3] | 1 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [3] | 2 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [3] | 3 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [3] | 4 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [3] | 5 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [3] | 6 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# +++++++++++ [3] | 7 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [3] | 8 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [3] | 9 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [3] | 10 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Testando combinacao4: Hidden Size=[30], regularizer=0.2, learning_rate=0.1
# Shape X (batch, time_steps, features): (682, 2, 2)
# Shape Y (batch, output_dim): (682, 1)
# Shape h0 (batch, units): (682, 30)
# Shape X (batch, time_steps, features): (120, 2, 2)
# Shape Y (batch, output_dim): (120, 1)
# Shape h0 (batch, units): (120, 30)
# Shape X (batch, time_steps, features): (267, 2, 2)
# Shape Y (batch, output_dim): (267, 1)
# Shape h0 (batch, units): (267, 30)
# +++++++++++ [4] | 1 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [4] | 2 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [4] | 3 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [4] | 4 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [4] | 5 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [4] | 6 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [4] | 7 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [4] | 8 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [4] | 9 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [4] | 10 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Testando combinacao5: Hidden Size=[25], regularizer=0.02, learning_rate=0.01
# Shape X (batch, time_steps, features): (682, 2, 2)
# Shape Y (batch, output_dim): (682, 1)
# Shape h0 (batch, units): (682, 25)
# Shape X (batch, time_steps, features): (120, 2, 2)
# Shape Y (batch, output_dim): (120, 1)
# Shape h0 (batch, units): (120, 25)
# Shape X (batch, time_steps, features): (267, 2, 2)
# Shape Y (batch, output_dim): (267, 1)
# Shape h0 (batch, units): (267, 25)
# +++++++++++ [5] | 1 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [5] | 2 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [5] | 3 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [5] | 4 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [5] | 5 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [5] | 6 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# +++++++++++ [5] | 7 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [5] | 8 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [5] | 9 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [5] | 10 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Testando combinacao6: Hidden Size=[25], regularizer=0.02, learning_rate=0.1
# Shape X (batch, time_steps, features): (682, 2, 2)
# Shape Y (batch, output_dim): (682, 1)
# Shape h0 (batch, units): (682, 25)
# Shape X (batch, time_steps, features): (120, 2, 2)
# Shape Y (batch, output_dim): (120, 1)
# Shape h0 (batch, units): (120, 25)
# Shape X (batch, time_steps, features): (267, 2, 2)
# Shape Y (batch, output_dim): (267, 1)
# Shape h0 (batch, units): (267, 25)
# +++++++++++ [6] | 1 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [6] | 2 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [6] | 3 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [6] | 4 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [6] | 5 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [6] | 6 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [6] | 7 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [6] | 8 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [6] | 9 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [6] | 10 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Testando combinacao7: Hidden Size=[25], regularizer=0.2, learning_rate=0.01
# Shape X (batch, time_steps, features): (682, 2, 2)
# Shape Y (batch, output_dim): (682, 1)
# Shape h0 (batch, units): (682, 25)
# Shape X (batch, time_steps, features): (120, 2, 2)
# Shape Y (batch, output_dim): (120, 1)
# Shape h0 (batch, units): (120, 25)
# Shape X (batch, time_steps, features): (267, 2, 2)
# Shape Y (batch, output_dim): (267, 1)
# Shape h0 (batch, units): (267, 25)
# +++++++++++ [7] | 1 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [7] | 2 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [7] | 3 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [7] | 4 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [7] | 5 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [7] | 6 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [7] | 7 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [7] | 8 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [7] | 9 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [7] | 10 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Testando combinacao8: Hidden Size=[25], regularizer=0.2, learning_rate=0.1
# Shape X (batch, time_steps, features): (682, 2, 2)
# Shape Y (batch, output_dim): (682, 1)
# Shape h0 (batch, units): (682, 25)
# Shape X (batch, time_steps, features): (120, 2, 2)
# Shape Y (batch, output_dim): (120, 1)
# Shape h0 (batch, units): (120, 25)
# Shape X (batch, time_steps, features): (267, 2, 2)
# Shape Y (batch, output_dim): (267, 1)
# Shape h0 (batch, units): (267, 25)
# +++++++++++ [8] | 1 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [8] | 2 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [8] | 3 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [8] | 4 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [8] | 5 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [8] | 6 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [8] | 7 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [8] | 8 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [8] | 9 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [8] | 10 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Testando combinacao9: Hidden Size=[2, 5], regularizer=0.02, learning_rate=0.01
# Shape X (batch, time_steps, features): (682, 2, 2)
# Shape Y (batch, output_dim): (682, 1)
# Shape h0 (batch, units): (682, 2)
# Shape X (batch, time_steps, features): (120, 2, 2)
# Shape Y (batch, output_dim): (120, 1)
# Shape h0 (batch, units): (120, 2)
# Shape X (batch, time_steps, features): (267, 2, 2)
# Shape Y (batch, output_dim): (267, 1)
# Shape h0 (batch, units): (267, 2)
# +++++++++++ [9] | 1 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [9] | 2 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [9] | 3 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [9] | 4 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [9] | 5 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [9] | 6 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [9] | 7 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [9] | 8 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [9] | 9 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [9] | 10 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Testando combinacao10: Hidden Size=[2, 5], regularizer=0.02, learning_rate=0.1
# Shape X (batch, time_steps, features): (682, 2, 2)
# Shape Y (batch, output_dim): (682, 1)
# Shape h0 (batch, units): (682, 2)
# Shape X (batch, time_steps, features): (120, 2, 2)
# Shape Y (batch, output_dim): (120, 1)
# Shape h0 (batch, units): (120, 2)
# Shape X (batch, time_steps, features): (267, 2, 2)
# Shape Y (batch, output_dim): (267, 1)
# Shape h0 (batch, units): (267, 2)
# +++++++++++ [10] | 1 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [10] | 2 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [10] | 3 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [10] | 4 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [10] | 5 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [10] | 6 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [10] | 7 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [10] | 8 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# +++++++++++ [10] | 9 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# +++++++++++ [10] | 10 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Testando combinacao11: Hidden Size=[2, 5], regularizer=0.2, learning_rate=0.01
# Shape X (batch, time_steps, features): (682, 2, 2)
# Shape Y (batch, output_dim): (682, 1)
# Shape h0 (batch, units): (682, 2)
# Shape X (batch, time_steps, features): (120, 2, 2)
# Shape Y (batch, output_dim): (120, 1)
# Shape h0 (batch, units): (120, 2)
# Shape X (batch, time_steps, features): (267, 2, 2)
# Shape Y (batch, output_dim): (267, 1)
# Shape h0 (batch, units): (267, 2)
# +++++++++++ [11] | 1 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [11] | 2 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [11] | 3 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [11] | 4 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [11] | 5 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [11] | 6 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [11] | 7 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [11] | 8 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [11] | 9 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [11] | 10 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Testando combinacao12: Hidden Size=[2, 5], regularizer=0.2, learning_rate=0.1
# Shape X (batch, time_steps, features): (682, 2, 2)
# Shape Y (batch, output_dim): (682, 1)
# Shape h0 (batch, units): (682, 2)
# Shape X (batch, time_steps, features): (120, 2, 2)
# Shape Y (batch, output_dim): (120, 1)
# Shape h0 (batch, units): (120, 2)
# Shape X (batch, time_steps, features): (267, 2, 2)
# Shape Y (batch, output_dim): (267, 1)
# Shape h0 (batch, units): (267, 2)
# +++++++++++ [12] | 1 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [12] | 2 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [12] | 3 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [12] | 4 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# +++++++++++ [12] | 5 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# +++++++++++ [12] | 6 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [12] | 7 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [12] | 8 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [12] | 9 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [12] | 10 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Testando combinacao13: Hidden Size=[2, 10], regularizer=0.02, learning_rate=0.01
# Shape X (batch, time_steps, features): (682, 2, 2)
# Shape Y (batch, output_dim): (682, 1)
# Shape h0 (batch, units): (682, 2)
# Shape X (batch, time_steps, features): (120, 2, 2)
# Shape Y (batch, output_dim): (120, 1)
# Shape h0 (batch, units): (120, 2)
# Shape X (batch, time_steps, features): (267, 2, 2)
# Shape Y (batch, output_dim): (267, 1)
# Shape h0 (batch, units): (267, 2)
# +++++++++++ [13] | 1 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [13] | 2 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [13] | 3 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [13] | 4 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# +++++++++++ [13] | 5 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [13] | 6 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [13] | 7 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [13] | 8 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [13] | 9 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [13] | 10 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Testando combinacao14: Hidden Size=[2, 10], regularizer=0.02, learning_rate=0.1
# Shape X (batch, time_steps, features): (682, 2, 2)
# Shape Y (batch, output_dim): (682, 1)
# Shape h0 (batch, units): (682, 2)
# Shape X (batch, time_steps, features): (120, 2, 2)
# Shape Y (batch, output_dim): (120, 1)
# Shape h0 (batch, units): (120, 2)
# Shape X (batch, time_steps, features): (267, 2, 2)
# Shape Y (batch, output_dim): (267, 1)
# Shape h0 (batch, units): (267, 2)
# +++++++++++ [14] | 1 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [14] | 2 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [14] | 3 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [14] | 4 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [14] | 5 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [14] | 6 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [14] | 7 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [14] | 8 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [14] | 9 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [14] | 10 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Testando combinacao15: Hidden Size=[2, 10], regularizer=0.2, learning_rate=0.01
# Shape X (batch, time_steps, features): (682, 2, 2)
# Shape Y (batch, output_dim): (682, 1)
# Shape h0 (batch, units): (682, 2)
# Shape X (batch, time_steps, features): (120, 2, 2)
# Shape Y (batch, output_dim): (120, 1)
# Shape h0 (batch, units): (120, 2)
# Shape X (batch, time_steps, features): (267, 2, 2)
# Shape Y (batch, output_dim): (267, 1)
# Shape h0 (batch, units): (267, 2)
# +++++++++++ [15] | 1 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [15] | 2 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [15] | 3 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [15] | 4 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [15] | 5 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [15] | 6 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [15] | 7 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [15] | 8 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# +++++++++++ [15] | 9 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# +++++++++++ [15] | 10 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Testando combinacao16: Hidden Size=[2, 10], regularizer=0.2, learning_rate=0.1
# Shape X (batch, time_steps, features): (682, 2, 2)
# Shape Y (batch, output_dim): (682, 1)
# Shape h0 (batch, units): (682, 2)
# Shape X (batch, time_steps, features): (120, 2, 2)
# Shape Y (batch, output_dim): (120, 1)
# Shape h0 (batch, units): (120, 2)
# Shape X (batch, time_steps, features): (267, 2, 2)
# Shape Y (batch, output_dim): (267, 1)
# Shape h0 (batch, units): (267, 2)
# +++++++++++ [16] | 1 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [16] | 2 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# +++++++++++ [16] | 3 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# +++++++++++ [16] | 4 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# +++++++++++ [16] | 5 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# +++++++++++ [16] | 6 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# +++++++++++ [16] | 7 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [16] | 8 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# +++++++++++ [16] | 9 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# +++++++++++ [16] | 10 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Testando combinacao17: Hidden Size=[5, 5], regularizer=0.02, learning_rate=0.01
# Shape X (batch, time_steps, features): (682, 2, 2)
# Shape Y (batch, output_dim): (682, 1)
# Shape h0 (batch, units): (682, 5)
# Shape X (batch, time_steps, features): (120, 2, 2)
# Shape Y (batch, output_dim): (120, 1)
# Shape h0 (batch, units): (120, 5)
# Shape X (batch, time_steps, features): (267, 2, 2)
# Shape Y (batch, output_dim): (267, 1)
# Shape h0 (batch, units): (267, 5)
# +++++++++++ [17] | 1 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# +++++++++++ [17] | 2 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# +++++++++++ [17] | 3 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# +++++++++++ [17] | 4 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# +++++++++++ [17] | 5 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# +++++++++++ [17] | 6 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# +++++++++++ [17] | 7 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# +++++++++++ [17] | 8 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# +++++++++++ [17] | 9 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# +++++++++++ [17] | 10 ++++++++++++++++++
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Testando combinacao18: Hidden Size=[5, 5], regularizer=0.02, learning_rate=0.1
# Shape X (batch, time_steps, features): (682, 2, 2)
# Shape Y (batch, output_dim): (682, 1)
# Shape h0 (batch, units): (682, 5)
# Shape X (batch, time_steps, features): (120, 2, 2)
# Shape Y (batch, output_dim): (120, 1)
# Shape h0 (batch, units): (120, 5)
# Shape X (batch, time_steps, features): (267, 2, 2)
# Shape Y (batch, output_dim): (267, 1)
# Shape h0 (batch, units): (267, 5)
# +++++++++++ [18] | 1 ++++++++++++++++++
