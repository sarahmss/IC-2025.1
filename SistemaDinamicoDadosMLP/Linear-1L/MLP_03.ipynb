# %% [markdown]
# # MLP simples

# %% [markdown]
# - 1 saida - Theta
# - 2 entradas - Vd e Ve
# - 1 camada
# - 1 neurônio

# %%
import pandas as pd 
import numpy as np
from sklearn.preprocessing import StandardScaler

Datasets = []
PREDICTORS = ["VD", "VE"]
TARGET = ["Theta"]

for i in range(4):   
    Dataset = pd.read_csv(f"../Dados/Data{i + 1}.csv")
    Dataset = Dataset.drop(columns=["X", "Y", "Setpoint VD", "Setpoint VE", "tempo"])
    Dataset.index = (np.arange(0, len(Dataset), 1).astype(float) * 0.07).round(5)
    Datasets.append(Dataset)
    print(f"++++++++++++++++++++ Dataset {i+1} +++++++++++++++++++++++")
    print(Datasets[i].head(5))
# Out:
# ++++++++++++++++++++ Dataset 1 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  0.00  0.00
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28    0.0  2.33  2.33
# ++++++++++++++++++++ Dataset 2 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  2.33  2.33
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28   -0.0  2.33  2.33
# ++++++++++++++++++++ Dataset 3 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  0.00  0.00
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28    0.0  2.33  2.33
# ++++++++++++++++++++ Dataset 4 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  2.33  2.33
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28    0.0  2.33  2.33

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

TrainDataset = Datasets[0]
TrainDataset[PREDICTORS] = SCALER.fit_transform(TrainDataset[PREDICTORS])
TrainDataset[TARGET] = OUT_SCALER.fit_transform(TrainDataset[TARGET])
NormDatasets.append(TrainDataset)

for i in range(3):
      CurrentTestDataset = Datasets[i + 1]
      CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
      CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
      NormDatasets.append(CurrentTestDataset)
      print(f"++++++++++++++++++++ Dataset Normalizado {i+1} +++++++++++++++++++++++")
      print(NormDatasets[i].head(5))
# Out:
# ++++++++++++++++++++ Dataset Normalizado 1 +++++++++++++++++++++++
#          Theta        VD        VE
# 0.00 -0.147046  0.098819  0.089409
# 0.07 -0.147046  1.268765  1.266904
# 0.14 -0.147046  1.268765  1.266904
# 0.21 -0.147046  1.268765  1.266904
# 0.28 -0.147046  1.268765  1.266904
# ++++++++++++++++++++ Dataset Normalizado 2 +++++++++++++++++++++++
#          Theta        VD        VE
# 0.00 -0.147046  1.268765  1.266904
# 0.07 -0.147046  1.268765  1.266904
# 0.14 -0.147046  1.268765  1.266904
# 0.21 -0.147046  1.268765  1.266904
# 0.28 -0.147046  1.268765  1.266904
# ++++++++++++++++++++ Dataset Normalizado 3 +++++++++++++++++++++++
#          Theta        VD        VE
# 0.00 -0.147046  0.098819  0.089409
# 0.07 -0.147046  1.268765  1.266904
# 0.14 -0.147046  1.268765  1.266904
# 0.21 -0.147046  1.268765  1.266904
# 0.28 -0.147046  1.268765  1.266904

# %%
x_train = np.array(TrainDataset[PREDICTORS])
y_train = np.array(TrainDataset[TARGET])

x_val = np.array((NormDatasets[1])[PREDICTORS])
y_val = np.array((NormDatasets[1])[TARGET])

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")
# Out:
# Dimensão da entrada: (2146, 2)
# Dimensão da saida: (2146, 1)

# %%
import matplotlib.pyplot as plt

def PlotHistory(history):
    plt.figure(figsize=(8, 5))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('MSE Loss')
    plt.title('Training History')
    plt.legend()
    plt.grid(True)
    plt.show()
    
def PlotOut(axs, title, y_true, y_pred):
    y_true = np.ravel(y_true)
    y_pred = np.ravel(y_pred)
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    axs.scatter(time, y_true, marker='o', label='Amostras Reais')
    axs.scatter(time, y_pred, marker='x', label='Valores Preditos')
    axs.set_title(f'{title}')
    axs.set_xlabel('Theta')
    axs.set_ylabel('tempo')
    axs.legend()
    axs.grid(True)

# %%
from sklearn.metrics import mean_squared_error, r2_score

TITLES = ["Training", "Validation", "Test 1", "Test 2"]

def EvalModel(model):
    fig, axs = plt.subplots(4, 1, figsize=(12, 12))
    for i, dataset in enumerate(NormDatasets):
        x = np.array(dataset[PREDICTORS])
        y = OUT_SCALER.inverse_transform(dataset[TARGET])
        y_pred = OUT_SCALER.inverse_transform(model.predict(x))
    
        R2 = r2_score(y, y_pred)
        MSE = mean_squared_error(y, y_pred)
        print(f"R²_{TITLES[i]} = {R2}")
        print(f"MSE_{TITLES[i]} = {MSE}")
        
        PlotOut(axs[i], TITLES[i], y, y_pred)

# %%
from tensorflow import keras
from keras.callbacks import EarlyStopping

INPUT_SIZE = len(PREDICTORS)  


model = keras.models.Sequential([
    keras.layers.Input(shape=(INPUT_SIZE,)),
    keras.layers.Dense(1, activation="linear"),  
])
model.summary()
print(f"Pesos inciais:\n {model.get_weights()}")
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3 (12.00 B)
#  Trainable params: 3 (12.00 B)
#  Non-trainable params: 0 (0.00 B)
# Pesos inciais:
#  [array([[-0.97767067],
#        [ 0.05616963]], dtype=float32), array([0.], dtype=float32)]

# %% [markdown]
# Configures the model for training.

# %%
model.compile(loss="mean_squared_error", optimizer="adam")

# %% [markdown]
# Trains the model for a fixed number of epochs (dataset iterations).

# %%
early_stopping_monitor = EarlyStopping(monitor='val_loss',
                                patience=50,
                                restore_best_weights=True)

history = model.fit(x_train, 
                    y_train, 
                    epochs=1000,
                    callbacks=[early_stopping_monitor],
 validation_data=(x_val, y_val))
# Out:
# Epoch 1/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.6975 - val_loss: 1.3591
# Epoch 2/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5300 - val_loss: 1.1679
# Epoch 3/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3411 - val_loss: 1.0222
# Epoch 4/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2462 - val_loss: 0.9139
# Epoch 5/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1725 - val_loss: 0.8379
# Epoch 6/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1057 - val_loss: 0.7828
# Epoch 7/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.0315 - val_loss: 0.7459
# Epoch 8/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9840 - val_loss: 0.7233
# Epoch 9/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9619 - val_loss: 0.7074
# Epoch 10/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9864 - val_loss: 0.7005
# Epoch 11/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9498 - val_loss: 0.6961
# Epoch 12/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0058 - val_loss: 0.6951
# Epoch 13/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9450 - val_loss: 0.6944
# Epoch 14/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9356 - val_loss: 0.6920
# Epoch 15/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9469 - val_loss: 0.6931
# Epoch 16/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9374 - val_loss: 0.6918
# Epoch 17/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9511 - val_loss: 0.6898
# Epoch 18/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9530 - val_loss: 0.6892
# Epoch 19/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9895 - val_loss: 0.6888
# Epoch 20/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9522 - val_loss: 0.6898
# Epoch 21/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9658 - val_loss: 0.6890
# Epoch 22/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9411 - val_loss: 0.6909
# Epoch 23/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.9625 - val_loss: 0.6906
# Epoch 24/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9284 - val_loss: 0.6890
# Epoch 25/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9693 - val_loss: 0.6883
# Epoch 26/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9613 - val_loss: 0.6896
# Epoch 27/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9480 - val_loss: 0.6898
# Epoch 28/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9622 - val_loss: 0.6913
# Epoch 29/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9717 - val_loss: 0.6916
# Epoch 30/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9246 - val_loss: 0.6909
# Epoch 31/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9460 - val_loss: 0.6891
# Epoch 32/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9904 - val_loss: 0.6892
# Epoch 33/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.9752 - val_loss: 0.6897
# Epoch 34/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9682 - val_loss: 0.6889
# Epoch 35/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8997 - val_loss: 0.6894
# Epoch 36/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9073 - val_loss: 0.6890
# Epoch 37/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9391 - val_loss: 0.6897
# Epoch 38/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9698 - val_loss: 0.6891
# Epoch 39/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9545 - val_loss: 0.6884
# Epoch 40/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9421 - val_loss: 0.6888
# Epoch 41/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9463 - val_loss: 0.6892
# Epoch 42/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9468 - val_loss: 0.6891
# Epoch 43/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9437 - val_loss: 0.6880
# Epoch 44/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9328 - val_loss: 0.6876
# Epoch 45/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9324 - val_loss: 0.6879
# Epoch 46/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9407 - val_loss: 0.6865
# Epoch 47/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9763 - val_loss: 0.6869
# Epoch 48/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9244 - val_loss: 0.6878
# Epoch 49/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9592 - val_loss: 0.6889
# Epoch 50/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9447 - val_loss: 0.6902
# Epoch 51/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9627 - val_loss: 0.6904
# Epoch 52/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9429 - val_loss: 0.6904
# Epoch 53/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9518 - val_loss: 0.6904
# Epoch 54/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9678 - val_loss: 0.6885
# Epoch 55/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9464 - val_loss: 0.6876
# Epoch 56/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9541 - val_loss: 0.6872
# Epoch 57/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9298 - val_loss: 0.6861
# Epoch 58/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9745 - val_loss: 0.6868
# Epoch 59/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9355 - val_loss: 0.6875
# Epoch 60/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9502 - val_loss: 0.6883
# Epoch 61/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9395 - val_loss: 0.6883
# Epoch 62/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9259 - val_loss: 0.6897
# Epoch 63/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9739 - val_loss: 0.6892
# Epoch 64/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9534 - val_loss: 0.6895
# Epoch 65/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9566 - val_loss: 0.6894
# Epoch 66/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9240 - val_loss: 0.6884
# Epoch 67/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9677 - val_loss: 0.6877
# Epoch 68/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9205 - val_loss: 0.6874
# Epoch 69/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9347 - val_loss: 0.6863
# Epoch 70/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9791 - val_loss: 0.6860
# Epoch 71/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9716 - val_loss: 0.6860
# Epoch 72/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9427 - val_loss: 0.6848
# Epoch 73/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9338 - val_loss: 0.6851
# Epoch 74/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9297 - val_loss: 0.6852
# Epoch 75/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9329 - val_loss: 0.6862
# Epoch 76/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9705 - val_loss: 0.6856
# Epoch 77/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9827 - val_loss: 0.6875
# Epoch 78/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9284 - val_loss: 0.6859
# Epoch 79/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9521 - val_loss: 0.6872
# Epoch 80/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9633 - val_loss: 0.6865
# Epoch 81/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9520 - val_loss: 0.6861
# Epoch 82/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9674 - val_loss: 0.6883
# Epoch 83/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9379 - val_loss: 0.6869
# Epoch 84/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9683 - val_loss: 0.6864
# Epoch 85/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9279 - val_loss: 0.6856
# Epoch 86/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9631 - val_loss: 0.6864
# Epoch 87/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9467 - val_loss: 0.6860
# Epoch 88/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9191 - val_loss: 0.6868
# Epoch 89/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9388 - val_loss: 0.6862
# Epoch 90/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9425 - val_loss: 0.6865
# Epoch 91/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9232 - val_loss: 0.6859
# Epoch 92/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9454 - val_loss: 0.6873
# Epoch 93/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9462 - val_loss: 0.6869
# Epoch 94/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9276 - val_loss: 0.6872
# Epoch 95/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9729 - val_loss: 0.6881
# Epoch 96/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9558 - val_loss: 0.6879
# Epoch 97/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9550 - val_loss: 0.6873
# Epoch 98/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9512 - val_loss: 0.6872
# Epoch 99/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9323 - val_loss: 0.6875
# Epoch 100/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9182 - val_loss: 0.6871
# Epoch 101/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9598 - val_loss: 0.6877
# Epoch 102/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9494 - val_loss: 0.6873
# Epoch 103/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9504 - val_loss: 0.6879
# Epoch 104/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9501 - val_loss: 0.6876
# Epoch 105/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9610 - val_loss: 0.6865
# Epoch 106/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9690 - val_loss: 0.6871
# Epoch 107/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9588 - val_loss: 0.6867
# Epoch 108/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9460 - val_loss: 0.6877
# Epoch 109/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9416 - val_loss: 0.6861
# Epoch 110/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9529 - val_loss: 0.6869
# Epoch 111/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9858 - val_loss: 0.6869
# Epoch 112/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9212 - val_loss: 0.6866
# Epoch 113/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9557 - val_loss: 0.6856
# Epoch 114/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9297 - val_loss: 0.6861
# Epoch 115/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9629 - val_loss: 0.6867
# Epoch 116/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9509 - val_loss: 0.6871
# Epoch 117/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9587 - val_loss: 0.6866
# Epoch 118/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9764 - val_loss: 0.6873
# Epoch 119/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9594 - val_loss: 0.6871
# Epoch 120/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9744 - val_loss: 0.6867
# Epoch 121/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9603 - val_loss: 0.6869
# Epoch 122/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9723 - val_loss: 0.6876

# %%
print(f"Pesos finais:\n {model.get_weights()}")
# Out:
# Pesos finais:
#  [array([[-0.678851],
#        [ 0.698494]], dtype=float32), array([-0.00957967], dtype=float32)]

# %%
PlotHistory(history)

# %%
EvalModel(model)
# Out:
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# R²_Training = 0.04817557239419634
# MSE_Training = 0.2458311869705204
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# R²_Validation = 0.0020994336327780916
# MSE_Validation = 0.17686940040983187
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# R²_Test 1 = 0.06491141205054618
# MSE_Test 1 = 0.23163559499926534
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# R²_Test 2 = 0.027151901652492372
# MSE_Test 2 = 0.1718927541225277
