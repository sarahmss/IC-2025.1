# %% [markdown]
# # MLP simples

# %% [markdown]
# - 1 saida - Theta
# - 2 entradas - Vd e Ve
# - 1 camada
# - 1 neurônio

# %%
import pandas as pd 
import numpy as np
from sklearn.preprocessing import StandardScaler

Datasets = []
PREDICTORS = ["VD", "VE"]
TARGET = ["Theta"]

for i in range(4):   
    Dataset = pd.read_csv(f"../Dados/Data{i + 1}.csv")
    Dataset = Dataset.drop(columns=["X", "Y", "Setpoint VD", "Setpoint VE", "tempo"])
    Dataset.index = (np.arange(0, len(Dataset), 1).astype(float) * 0.07).round(5)
    Datasets.append(Dataset)
    print(f"++++++++++++++++++++ Dataset {i+1} +++++++++++++++++++++++")
    print(Datasets[i].head(5))
# Out:
# ++++++++++++++++++++ Dataset 1 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  0.00  0.00
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28    0.0  2.33  2.33
# ++++++++++++++++++++ Dataset 2 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  2.33  2.33
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28   -0.0  2.33  2.33
# ++++++++++++++++++++ Dataset 3 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  0.00  0.00
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28    0.0  2.33  2.33
# ++++++++++++++++++++ Dataset 4 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  2.33  2.33
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28    0.0  2.33  2.33

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

TrainDataset = Datasets[0]
TrainDataset[PREDICTORS] = SCALER.fit_transform(TrainDataset[PREDICTORS])
TrainDataset[TARGET] = OUT_SCALER.fit_transform(TrainDataset[TARGET])
NormDatasets.append(TrainDataset)

for i in range(3):
      CurrentTestDataset = Datasets[i + 1]
      CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
      CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
      NormDatasets.append(CurrentTestDataset)
      print(f"++++++++++++++++++++ Dataset Normalizado {i+1} +++++++++++++++++++++++")
      print(NormDatasets[i].head(5))
# Out:
# ++++++++++++++++++++ Dataset Normalizado 1 +++++++++++++++++++++++
#          Theta        VD        VE
# 0.00 -0.147046  0.098819  0.089409
# 0.07 -0.147046  1.268765  1.266904
# 0.14 -0.147046  1.268765  1.266904
# 0.21 -0.147046  1.268765  1.266904
# 0.28 -0.147046  1.268765  1.266904
# ++++++++++++++++++++ Dataset Normalizado 2 +++++++++++++++++++++++
#          Theta        VD        VE
# 0.00 -0.147046  1.268765  1.266904
# 0.07 -0.147046  1.268765  1.266904
# 0.14 -0.147046  1.268765  1.266904
# 0.21 -0.147046  1.268765  1.266904
# 0.28 -0.147046  1.268765  1.266904
# ++++++++++++++++++++ Dataset Normalizado 3 +++++++++++++++++++++++
#          Theta        VD        VE
# 0.00 -0.147046  0.098819  0.089409
# 0.07 -0.147046  1.268765  1.266904
# 0.14 -0.147046  1.268765  1.266904
# 0.21 -0.147046  1.268765  1.266904
# 0.28 -0.147046  1.268765  1.266904

# %%
x_train = np.array(TrainDataset[PREDICTORS])
y_train = np.array(TrainDataset[TARGET])

x_val = np.array((NormDatasets[1])[PREDICTORS])
y_val = np.array((NormDatasets[1])[TARGET])

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")
# Out:
# Dimensão da entrada: (2146, 2)
# Dimensão da saida: (2146, 1)

# %%
import matplotlib.pyplot as plt

def PlotHistory(history):
    plt.figure(figsize=(8, 5))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('MSE Loss')
    plt.title('Training History')
    plt.legend()
    plt.grid(True)
    plt.show()
    
def PlotOut(axs, title, y_true, y_pred):
    y_true = np.ravel(y_true)
    y_pred = np.ravel(y_pred)
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    axs.scatter(time, y_true, marker='o', label='Amostras Reais')
    axs.scatter(time, y_pred, marker='x', label='Valores Preditos')
    axs.set_title(f'{title}')
    axs.set_xlabel('Theta')
    axs.set_ylabel('tempo')
    axs.legend()
    axs.grid(True)

# %%
from sklearn.metrics import mean_squared_error, r2_score

TITLES = ["Training", "Validation", "Test 1", "Test 2"]

def EvalModel(model):
    fig, axs = plt.subplots(4, 1, figsize=(12, 12))
    for i, dataset in enumerate(NormDatasets):
        x = np.array(dataset[PREDICTORS])
        y = OUT_SCALER.inverse_transform(dataset[TARGET])
        y_pred = OUT_SCALER.inverse_transform(model.predict(x))
    
        R2 = r2_score(y, y_pred)
        MSE = mean_squared_error(y, y_pred)
        print(f"R²_{TITLES[i]} = {R2}")
        print(f"MSE_{TITLES[i]} = {MSE}")
        
        PlotOut(axs[i], TITLES[i], y, y_pred)

# %%
from tensorflow import keras
from keras.callbacks import EarlyStopping

INPUT_SIZE = len(PREDICTORS)  


model = keras.models.Sequential([
    keras.layers.Input(shape=(INPUT_SIZE,)),
    keras.layers.Dense(1, activation="linear"),  
])
model.summary()
print(f"Pesos inciais:\n {model.get_weights()}")
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3 (12.00 B)
#  Trainable params: 3 (12.00 B)
#  Non-trainable params: 0 (0.00 B)
# Pesos inciais:
#  [array([[1.3468753 ],
#        [0.84521973]], dtype=float32), array([0.], dtype=float32)]

# %% [markdown]
# Configures the model for training.

# %%
model.compile(loss="mean_squared_error", optimizer="adam")

# %% [markdown]
# Trains the model for a fixed number of epochs (dataset iterations).

# %%
early_stopping_monitor = EarlyStopping(monitor='val_loss',
                                patience=50,
                                restore_best_weights=True)

history = model.fit(x_train, 
                    y_train, 
                    epochs=1000,
                    callbacks=[early_stopping_monitor],
 validation_data=(x_val, y_val))
# Out:
# Epoch 1/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.5856 - val_loss: 5.2304
# Epoch 2/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0067 - val_loss: 4.6763
# Epoch 3/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4596 - val_loss: 4.1803
# Epoch 4/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9562 - val_loss: 3.7230
# Epoch 5/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6403 - val_loss: 3.3274
# Epoch 6/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3133 - val_loss: 2.9689
# Epoch 7/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9611 - val_loss: 2.6460
# Epoch 8/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7765 - val_loss: 2.3621
# Epoch 9/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4560 - val_loss: 2.1165
# Epoch 10/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3206 - val_loss: 1.8959
# Epoch 11/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0337 - val_loss: 1.7033
# Epoch 12/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8692 - val_loss: 1.5380
# Epoch 13/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7050 - val_loss: 1.3992
# Epoch 14/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6684 - val_loss: 1.2806
# Epoch 15/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4969 - val_loss: 1.1773
# Epoch 16/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4288 - val_loss: 1.0920
# Epoch 17/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3309 - val_loss: 1.0206
# Epoch 18/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2602 - val_loss: 0.9599
# Epoch 19/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2176 - val_loss: 0.9113
# Epoch 20/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1809 - val_loss: 0.8727
# Epoch 21/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1684 - val_loss: 0.8406
# Epoch 22/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1311 - val_loss: 0.8158
# Epoch 23/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1342 - val_loss: 0.7953
# Epoch 24/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0466 - val_loss: 0.7812
# Epoch 25/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0668 - val_loss: 0.7691
# Epoch 26/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0860 - val_loss: 0.7613
# Epoch 27/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0780 - val_loss: 0.7546
# Epoch 28/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0191 - val_loss: 0.7495
# Epoch 29/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0365 - val_loss: 0.7464
# Epoch 30/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0623 - val_loss: 0.7435
# Epoch 31/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0520 - val_loss: 0.7411
# Epoch 32/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0459 - val_loss: 0.7416
# Epoch 33/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0516 - val_loss: 0.7394
# Epoch 34/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0452 - val_loss: 0.7377
# Epoch 35/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0234 - val_loss: 0.7370
# Epoch 36/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0364 - val_loss: 0.7356
# Epoch 37/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0194 - val_loss: 0.7361
# Epoch 38/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9894 - val_loss: 0.7356
# Epoch 39/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0107 - val_loss: 0.7348
# Epoch 40/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0377 - val_loss: 0.7336
# Epoch 41/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0330 - val_loss: 0.7325
# Epoch 42/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0142 - val_loss: 0.7330
# Epoch 43/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0196 - val_loss: 0.7328
# Epoch 44/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0174 - val_loss: 0.7323
# Epoch 45/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0182 - val_loss: 0.7302
# Epoch 46/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0143 - val_loss: 0.7318
# Epoch 47/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0230 - val_loss: 0.7319
# Epoch 48/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0368 - val_loss: 0.7303
# Epoch 49/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0325 - val_loss: 0.7312
# Epoch 50/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9981 - val_loss: 0.7309
# Epoch 51/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0080 - val_loss: 0.7278
# Epoch 52/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.0135 - val_loss: 0.7279
# Epoch 53/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9717 - val_loss: 0.7271
# Epoch 54/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0246 - val_loss: 0.7291
# Epoch 55/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9986 - val_loss: 0.7283
# Epoch 56/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9955 - val_loss: 0.7282
# Epoch 57/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0012 - val_loss: 0.7253
# Epoch 58/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0101 - val_loss: 0.7234
# Epoch 59/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0249 - val_loss: 0.7231
# Epoch 60/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0424 - val_loss: 0.7244
# Epoch 61/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9940 - val_loss: 0.7223
# Epoch 62/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9811 - val_loss: 0.7235
# Epoch 63/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0368 - val_loss: 0.7233
# Epoch 64/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0130 - val_loss: 0.7217
# Epoch 65/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9814 - val_loss: 0.7213
# Epoch 66/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9954 - val_loss: 0.7220
# Epoch 67/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0003 - val_loss: 0.7201
# Epoch 68/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0214 - val_loss: 0.7185
# Epoch 69/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0022 - val_loss: 0.7190
# Epoch 70/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0044 - val_loss: 0.7191
# Epoch 71/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0044 - val_loss: 0.7182
# Epoch 72/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9814 - val_loss: 0.7167
# Epoch 73/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9392 - val_loss: 0.7166
# Epoch 74/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0476 - val_loss: 0.7142
# Epoch 75/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0062 - val_loss: 0.7150
# Epoch 76/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9832 - val_loss: 0.7130
# Epoch 77/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9575 - val_loss: 0.7128
# Epoch 78/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9678 - val_loss: 0.7129
# Epoch 79/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9832 - val_loss: 0.7113
# Epoch 80/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0334 - val_loss: 0.7120
# Epoch 81/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9772 - val_loss: 0.7111
# Epoch 82/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0050 - val_loss: 0.7093
# Epoch 83/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0275 - val_loss: 0.7088
# Epoch 84/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9730 - val_loss: 0.7102
# Epoch 85/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0172 - val_loss: 0.7096
# Epoch 86/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9919 - val_loss: 0.7076
# Epoch 87/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9963 - val_loss: 0.7065
# Epoch 88/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0043 - val_loss: 0.7071
# Epoch 89/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9632 - val_loss: 0.7064
# Epoch 90/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9463 - val_loss: 0.7060
# Epoch 91/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9918 - val_loss: 0.7068
# Epoch 92/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9915 - val_loss: 0.7043
# Epoch 93/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9877 - val_loss: 0.7034
# Epoch 94/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9907 - val_loss: 0.7043
# Epoch 95/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9426 - val_loss: 0.7027
# Epoch 96/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9678 - val_loss: 0.7023
# Epoch 97/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9383 - val_loss: 0.7029
# Epoch 98/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9595 - val_loss: 0.7046
# Epoch 99/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9742 - val_loss: 0.7045
# Epoch 100/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9513 - val_loss: 0.7032
# Epoch 101/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9268 - val_loss: 0.7032
# Epoch 102/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9726 - val_loss: 0.7038
# Epoch 103/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9745 - val_loss: 0.7012
# Epoch 104/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9828 - val_loss: 0.7000
# Epoch 105/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9968 - val_loss: 0.6989
# Epoch 106/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0395 - val_loss: 0.6992
# Epoch 107/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9833 - val_loss: 0.6992
# Epoch 108/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9926 - val_loss: 0.7007
# Epoch 109/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9436 - val_loss: 0.6994
# Epoch 110/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9214 - val_loss: 0.6983
# Epoch 111/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9892 - val_loss: 0.6974
# Epoch 112/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9770 - val_loss: 0.6978
# Epoch 113/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9672 - val_loss: 0.6989
# Epoch 114/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9717 - val_loss: 0.6975
# Epoch 115/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9927 - val_loss: 0.6990
# Epoch 116/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9821 - val_loss: 0.6984
# Epoch 117/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9472 - val_loss: 0.6973
# Epoch 118/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9395 - val_loss: 0.6961
# Epoch 119/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9439 - val_loss: 0.6938
# Epoch 120/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.9406 - val_loss: 0.6942
# Epoch 121/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9531 - val_loss: 0.6951
# Epoch 122/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9433 - val_loss: 0.6960
# Epoch 123/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.0000 - val_loss: 0.6959
# Epoch 124/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9423 - val_loss: 0.6955
# Epoch 125/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9500 - val_loss: 0.6946
# Epoch 126/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9398 - val_loss: 0.6953
# Epoch 127/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9707 - val_loss: 0.6946
# Epoch 128/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9406 - val_loss: 0.6937
# Epoch 129/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9581 - val_loss: 0.6920
# Epoch 130/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9441 - val_loss: 0.6918
# Epoch 131/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9821 - val_loss: 0.6906
# Epoch 132/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9909 - val_loss: 0.6906
# Epoch 133/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9608 - val_loss: 0.6896
# Epoch 134/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9671 - val_loss: 0.6920
# Epoch 135/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9632 - val_loss: 0.6933
# Epoch 136/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9627 - val_loss: 0.6946
# Epoch 137/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9584 - val_loss: 0.6926
# Epoch 138/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9461 - val_loss: 0.6919
# Epoch 139/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9866 - val_loss: 0.6917
# Epoch 140/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9950 - val_loss: 0.6923
# Epoch 141/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9282 - val_loss: 0.6929
# Epoch 142/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9333 - val_loss: 0.6935
# Epoch 143/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9591 - val_loss: 0.6922
# Epoch 144/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9609 - val_loss: 0.6925
# Epoch 145/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0003 - val_loss: 0.6914
# Epoch 146/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9456 - val_loss: 0.6907
# Epoch 147/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9327 - val_loss: 0.6934
# Epoch 148/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9696 - val_loss: 0.6908
# Epoch 149/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9368 - val_loss: 0.6897
# Epoch 150/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9436 - val_loss: 0.6909
# Epoch 151/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9573 - val_loss: 0.6902
# Epoch 152/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9214 - val_loss: 0.6905
# Epoch 153/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9438 - val_loss: 0.6910
# Epoch 154/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9606 - val_loss: 0.6916
# Epoch 155/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9309 - val_loss: 0.6895
# Epoch 156/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9848 - val_loss: 0.6902
# Epoch 157/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9385 - val_loss: 0.6893
# Epoch 158/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9596 - val_loss: 0.6894
# Epoch 159/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9514 - val_loss: 0.6878
# Epoch 160/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9548 - val_loss: 0.6891
# Epoch 161/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9959 - val_loss: 0.6898
# Epoch 162/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9655 - val_loss: 0.6899
# Epoch 163/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9451 - val_loss: 0.6892
# Epoch 164/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9580 - val_loss: 0.6896
# Epoch 165/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9540 - val_loss: 0.6889
# Epoch 166/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9303 - val_loss: 0.6908
# Epoch 167/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9800 - val_loss: 0.6902
# Epoch 168/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9809 - val_loss: 0.6889
# Epoch 169/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9587 - val_loss: 0.6879
# Epoch 170/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9404 - val_loss: 0.6879
# Epoch 171/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9342 - val_loss: 0.6883
# Epoch 172/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9536 - val_loss: 0.6884
# Epoch 173/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9394 - val_loss: 0.6876
# Epoch 174/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9428 - val_loss: 0.6877
# Epoch 175/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9703 - val_loss: 0.6876
# Epoch 176/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9719 - val_loss: 0.6871
# Epoch 177/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9261 - val_loss: 0.6869
# Epoch 178/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9501 - val_loss: 0.6861
# Epoch 179/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9772 - val_loss: 0.6859
# Epoch 180/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9767 - val_loss: 0.6865
# Epoch 181/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9203 - val_loss: 0.6868
# Epoch 182/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9847 - val_loss: 0.6871
# Epoch 183/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9438 - val_loss: 0.6879
# Epoch 184/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9522 - val_loss: 0.6887
# Epoch 185/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9668 - val_loss: 0.6889
# Epoch 186/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9525 - val_loss: 0.6875
# Epoch 187/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9353 - val_loss: 0.6875
# Epoch 188/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9371 - val_loss: 0.6864
# Epoch 189/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9432 - val_loss: 0.6858
# Epoch 190/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9669 - val_loss: 0.6855
# Epoch 191/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9738 - val_loss: 0.6856
# Epoch 192/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9100 - val_loss: 0.6865
# Epoch 193/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9419 - val_loss: 0.6858
# Epoch 194/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9495 - val_loss: 0.6885
# Epoch 195/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9578 - val_loss: 0.6873
# Epoch 196/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9843 - val_loss: 0.6866
# Epoch 197/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9519 - val_loss: 0.6880
# Epoch 198/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9586 - val_loss: 0.6877
# Epoch 199/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9203 - val_loss: 0.6876
# Epoch 200/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9726 - val_loss: 0.6881
# Epoch 201/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9871 - val_loss: 0.6872
# Epoch 202/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9762 - val_loss: 0.6887
# Epoch 203/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9435 - val_loss: 0.6875
# Epoch 204/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9490 - val_loss: 0.6880
# Epoch 205/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9510 - val_loss: 0.6866
# Epoch 206/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9771 - val_loss: 0.6859
# Epoch 207/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9384 - val_loss: 0.6855
# Epoch 208/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9640 - val_loss: 0.6850
# Epoch 209/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9795 - val_loss: 0.6848
# Epoch 210/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9497 - val_loss: 0.6850
# Epoch 211/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9564 - val_loss: 0.6869
# Epoch 212/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9280 - val_loss: 0.6877
# Epoch 213/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9767 - val_loss: 0.6879
# Epoch 214/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9511 - val_loss: 0.6874
# Epoch 215/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9232 - val_loss: 0.6849
# Epoch 216/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9611 - val_loss: 0.6860
# Epoch 217/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9311 - val_loss: 0.6874
# Epoch 218/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9393 - val_loss: 0.6876
# Epoch 219/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9740 - val_loss: 0.6870
# Epoch 220/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9585 - val_loss: 0.6866
# Epoch 221/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9472 - val_loss: 0.6865
# Epoch 222/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9448 - val_loss: 0.6862
# Epoch 223/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9633 - val_loss: 0.6863
# Epoch 224/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9754 - val_loss: 0.6879
# Epoch 225/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0071 - val_loss: 0.6874
# Epoch 226/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9446 - val_loss: 0.6872
# Epoch 227/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9472 - val_loss: 0.6858
# Epoch 228/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9501 - val_loss: 0.6863
# Epoch 229/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0054 - val_loss: 0.6861
# Epoch 230/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9520 - val_loss: 0.6864
# Epoch 231/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9274 - val_loss: 0.6861
# Epoch 232/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9832 - val_loss: 0.6859
# Epoch 233/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9909 - val_loss: 0.6877
# Epoch 234/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9462 - val_loss: 0.6877
# Epoch 235/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9733 - val_loss: 0.6887
# Epoch 236/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9570 - val_loss: 0.6871
# Epoch 237/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9471 - val_loss: 0.6858
# Epoch 238/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9338 - val_loss: 0.6862
# Epoch 239/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9373 - val_loss: 0.6862
# Epoch 240/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9649 - val_loss: 0.6877
# Epoch 241/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9723 - val_loss: 0.6885
# Epoch 242/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9082 - val_loss: 0.6881
# Epoch 243/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9675 - val_loss: 0.6876
# Epoch 244/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9229 - val_loss: 0.6890
# Epoch 245/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9729 - val_loss: 0.6874
# Epoch 246/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9792 - val_loss: 0.6884
# Epoch 247/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9494 - val_loss: 0.6865
# Epoch 248/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9271 - val_loss: 0.6869
# Epoch 249/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9251 - val_loss: 0.6871
# Epoch 250/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9292 - val_loss: 0.6879
# Epoch 251/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9114 - val_loss: 0.6882
# Epoch 252/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9533 - val_loss: 0.6870
# Epoch 253/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9380 - val_loss: 0.6869
# Epoch 254/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9255 - val_loss: 0.6874
# Epoch 255/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9242 - val_loss: 0.6869
# Epoch 256/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9343 - val_loss: 0.6859
# Epoch 257/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9732 - val_loss: 0.6860
# Epoch 258/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9149 - val_loss: 0.6861
# Epoch 259/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9365 - val_loss: 0.6863

# %%
print(f"Pesos finais:\n {model.get_weights()}")
# Out:
# Pesos finais:
#  [array([[-0.73099726],
#        [ 0.7523628 ]], dtype=float32), array([-0.00779755], dtype=float32)]

# %%
PlotHistory(history)

# %%
EvalModel(model)
# Out:
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# R²_Training = 0.04931126001651287
# MSE_Training = 0.24553786876169478
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# R²_Validation = 0.0021113369552354655
# MSE_Validation = 0.17686729064701895
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# R²_Test 1 = 0.0659531376079664
# MSE_Test 1 = 0.23137754381306905
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# R²_Test 2 = 0.02992009780225835
# MSE_Test 2 = 0.17140364090850907
