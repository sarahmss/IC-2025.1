# %% [markdown]
# # MLP simples com a diferença

# %% [markdown]
# - 1 saida - DeltaTheta
# - 2 entradas - Vd e Ve
# - 1 camada
# - 1 neurônio

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

Datasets = []
PREDICTORS = "VD-VE"   
TARGET = "Theta"       

for i in range(4):   
    Dataset = pd.read_csv(f"../Dados/Data{i + 1}.csv")
    
    # Remove colunas desnecessárias
    Dataset = Dataset.drop(columns=["X", "Y", "Setpoint VD", "Setpoint VE", "tempo"])
    
    # Ajusta índice pelo tempo
    Dataset.index = (np.arange(0, len(Dataset), 1).astype(float) * 0.07).round(5)
    
    # Cria nova coluna com VD - VE
    Dataset[PREDICTORS] = Dataset["VD"] - Dataset["VE"]
    
    Datasets.append(Dataset)
    
    print(f"++++++++++++++++++++ Dataset {i+1} +++++++++++++++++++++++")
    print(Dataset.head(5))
# Out:
# ++++++++++++++++++++ Dataset 1 +++++++++++++++++++++++
#       Theta    VD    VE  VD-VE
# 0.00    0.0  0.00  0.00    0.0
# 0.07    0.0  2.33  2.33    0.0
# 0.14    0.0  2.33  2.33    0.0
# 0.21    0.0  2.33  2.33    0.0
# 0.28    0.0  2.33  2.33    0.0
# ++++++++++++++++++++ Dataset 2 +++++++++++++++++++++++
#       Theta    VD    VE  VD-VE
# 0.00    0.0  2.33  2.33    0.0
# 0.07    0.0  2.33  2.33    0.0
# 0.14    0.0  2.33  2.33    0.0
# 0.21    0.0  2.33  2.33    0.0
# 0.28   -0.0  2.33  2.33    0.0
# ++++++++++++++++++++ Dataset 3 +++++++++++++++++++++++
#       Theta    VD    VE  VD-VE
# 0.00    0.0  0.00  0.00    0.0
# 0.07    0.0  2.33  2.33    0.0
# 0.14    0.0  2.33  2.33    0.0
# 0.21    0.0  2.33  2.33    0.0
# 0.28    0.0  2.33  2.33    0.0
# ++++++++++++++++++++ Dataset 4 +++++++++++++++++++++++
#       Theta    VD    VE  VD-VE
# 0.00    0.0  2.33  2.33    0.0
# 0.07    0.0  2.33  2.33    0.0
# 0.14    0.0  2.33  2.33    0.0
# 0.21    0.0  2.33  2.33    0.0
# 0.28    0.0  2.33  2.33    0.0

# %%
for  i in range(4):
    Dataset = Datasets[i].copy()  # evita sobrescrever o original
    Dataset["DeltaTheta"] = Dataset[TARGET].shift(-1) - Dataset[TARGET]
    # ou equivalente: Dataset["DeltaTheta"] = Dataset[TARGET].diff().shift(-1)
    
    # remove o último NaN (último ponto não tem próximo valor)
    Dataset = Dataset.dropna(subset=["DeltaTheta"])
    Datasets[i] = Dataset
    print(f"++++++++++++++++++++ Dataset {i+1} +++++++++++++++++++++++")
    print(Datasets[i].tail(5))
# Out:
# ++++++++++++++++++++ Dataset 1 +++++++++++++++++++++++
#         Theta    VD    VE  VD-VE  DeltaTheta
# 149.80  -0.81 -2.20 -2.38   0.18        0.00
# 149.87  -0.81 -2.23 -2.40   0.17        0.01
# 149.94  -0.80 -2.41 -2.24  -0.17        0.00
# 150.01  -0.80 -2.40 -2.22  -0.18        0.00
# 150.08  -0.80 -2.40 -2.22  -0.18        0.00
# ++++++++++++++++++++ Dataset 2 +++++++++++++++++++++++
#         Theta    VD    VE  VD-VE  DeltaTheta
# 141.47   0.73 -2.22 -2.40   0.18        0.00
# 141.54   0.73 -2.23 -2.40   0.17        0.00
# 141.61   0.73 -2.23 -2.40   0.17        0.01
# 141.68   0.74 -2.24 -2.41   0.17        0.00
# 141.75   0.74 -2.41 -2.25  -0.16        0.00
# ++++++++++++++++++++ Dataset 3 +++++++++++++++++++++++
#        Theta    VD    VE  VD-VE  DeltaTheta
# 92.40  -0.81 -2.36 -2.18  -0.18        0.00
# 92.47  -0.81 -2.37 -2.19  -0.18        0.00
# 92.54  -0.81 -2.37 -2.19  -0.18       -0.01
# 92.61  -0.82 -2.37 -2.18  -0.19       -0.01
# 92.68  -0.83 -2.38 -2.20  -0.18       -0.01
# ++++++++++++++++++++ Dataset 4 +++++++++++++++++++++++
#         Theta    VD    VE  VD-VE  DeltaTheta
# 114.17   0.74 -2.09 -2.30   0.21        0.00
# 114.24   0.74 -2.11 -2.31   0.20        0.01
# 114.31   0.75 -2.12 -2.32   0.20        0.00
# 114.38   0.75 -2.13 -2.33   0.20        0.01
# 114.45   0.76 -2.13 -2.33   0.20        0.00

# %%
NormDatasets = []

PREDICTORS = ["VD-VE" ]  
TARGET = ["DeltaTheta"]
SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

TrainDataset = Datasets[0]
TrainDataset[PREDICTORS] = SCALER.fit_transform(TrainDataset[PREDICTORS])
TrainDataset[TARGET] = OUT_SCALER.fit_transform(TrainDataset[TARGET])
NormDatasets.append(TrainDataset)

for i in range(3):
      CurrentTestDataset = Datasets[i + 1]
      CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
      CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
      NormDatasets.append(CurrentTestDataset)
      print(f"++++++++++++++++++++ Dataset Normalizado {i+1} +++++++++++++++++++++++")
      print(NormDatasets[i].head(5))
# Out:
# ++++++++++++++++++++ Dataset Normalizado 1 +++++++++++++++++++++++
#       Theta    VD    VE     VD-VE  DeltaTheta
# 0.00    0.0  0.00  0.00  0.038989    0.035731
# 0.07    0.0  2.33  2.33  0.038989    0.035731
# 0.14    0.0  2.33  2.33  0.038989    0.035731
# 0.21    0.0  2.33  2.33  0.038989    0.035731
# 0.28    0.0  2.33  2.33  0.038989    0.035731
# ++++++++++++++++++++ Dataset Normalizado 2 +++++++++++++++++++++++
#       Theta    VD    VE     VD-VE  DeltaTheta
# 0.00    0.0  2.33  2.33  0.038989    0.035731
# 0.07    0.0  2.33  2.33  0.038989    0.035731
# 0.14    0.0  2.33  2.33  0.038989    0.035731
# 0.21    0.0  2.33  2.33  0.038989    0.035731
# 0.28   -0.0  2.33  2.33  0.038989    0.035731
# ++++++++++++++++++++ Dataset Normalizado 3 +++++++++++++++++++++++
#       Theta    VD    VE     VD-VE  DeltaTheta
# 0.00    0.0  0.00  0.00  0.038989    0.035731
# 0.07    0.0  2.33  2.33  0.038989    0.035731
# 0.14    0.0  2.33  2.33  0.038989    0.035731
# 0.21    0.0  2.33  2.33  0.038989    0.035731
# 0.28    0.0  2.33  2.33  0.038989    0.035731

# %%
x_train = np.array(TrainDataset[PREDICTORS])
y_train = np.array(TrainDataset[TARGET])

x_val = np.array((NormDatasets[1])[PREDICTORS])
y_val = np.array((NormDatasets[1])[TARGET])

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")
# Out:
# Dimensão da entrada: (2145, 1)
# Dimensão da saida: (2145, 1)

# %%
import matplotlib.pyplot as plt

def PlotHistory(history):
    plt.figure(figsize=(8, 5))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('MSE Loss')
    plt.title('Training History')
    plt.legend()
    plt.grid(True)
    plt.show()
    
def PlotOut(axs, title, y_true, y_pred):
    y_true = np.ravel(y_true)
    y_pred = np.ravel(y_pred)
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    axs.scatter(time, y_true, marker='o', label='Amostras Reais')
    axs.scatter(time, y_pred, marker='x', label='Valores Preditos')
    axs.set_title(f'{title}')
    axs.set_xlabel('Theta')
    axs.set_ylabel('tempo')
    axs.legend()
    axs.grid(True)

# %%
from sklearn.metrics import mean_squared_error, r2_score

TITLES = ["Training", "Validation", "Test 1", "Test 2"]

def EvalModel(model):
    fig, axs = plt.subplots(4, 1, figsize=(12, 12))
    for i, dataset in enumerate(NormDatasets):
        x = np.array(dataset[PREDICTORS])
        
        # diferenças reais e previstas (já desnormalizadas)
        y_diff = OUT_SCALER.inverse_transform(dataset[TARGET])
        y_pred_diff = OUT_SCALER.inverse_transform(model.predict(x))
        
        # valor inicial de theta no dataset original (não normalizado)
        theta0 = Datasets[i]["Theta"].iloc[0]  
        
        # reconstrução: soma cumulativa
        y_real = theta0 + np.cumsum(y_diff, axis=0)
        y_pred = theta0 + np.cumsum(y_pred_diff, axis=0)
        
        # métricas no espaço de θ
        R2 = r2_score(y_real, y_pred)
        MSE = mean_squared_error(y_real, y_pred)
        print(f"R²_{TITLES[i]} = {R2}")
        print(f"MSE_{TITLES[i]} = {MSE}")
        
        # plota saída
        PlotOut(axs[i], TITLES[i], y_real, y_pred)

# %%
from tensorflow import keras
from keras.callbacks import EarlyStopping

INPUT_SIZE = len(PREDICTORS)  

model = keras.models.Sequential([
    keras.layers.Input(shape=(INPUT_SIZE,)),
    keras.layers.Dense(1, activation="linear"),  
])
model.summary()
print(f"Pesos inciais:\n {model.get_weights()}")
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)
# Pesos inciais:
#  [array([[1.6100978]], dtype=float32), array([0.], dtype=float32)]

# %% [markdown]
# Configures the model for training.

# %%
model.compile(loss="mean_squared_error", optimizer="adam")

# %% [markdown]
# Trains the model for a fixed number of epochs (dataset iterations).

# %%
early_stopping_monitor = EarlyStopping(monitor='val_loss',
                                patience=50,
                                restore_best_weights=True)

history = model.fit(x_train, 
                    y_train, 
                    epochs=1000,
                    callbacks=[early_stopping_monitor],
 validation_data=(x_val, y_val))
# Out:
# Epoch 1/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.6451 - val_loss: 1.8669
# Epoch 2/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6943 - val_loss: 1.7662
# Epoch 3/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5320 - val_loss: 1.6711
# Epoch 4/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5073 - val_loss: 1.5844
# Epoch 5/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1254 - val_loss: 1.5053
# Epoch 6/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1592 - val_loss: 1.4313
# Epoch 7/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0892 - val_loss: 1.3652
# Epoch 8/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7702 - val_loss: 1.3037
# Epoch 9/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6339 - val_loss: 1.2488
# Epoch 10/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7225 - val_loss: 1.1958
# Epoch 11/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6710 - val_loss: 1.1506
# Epoch 12/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5713 - val_loss: 1.1080
# Epoch 13/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5002 - val_loss: 1.0686
# Epoch 14/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3699 - val_loss: 1.0358
# Epoch 15/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3326 - val_loss: 1.0065
# Epoch 16/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2334 - val_loss: 0.9800
# Epoch 17/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2203 - val_loss: 0.9553
# Epoch 18/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3567 - val_loss: 0.9354
# Epoch 19/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1744 - val_loss: 0.9180
# Epoch 20/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2848 - val_loss: 0.9026
# Epoch 21/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2001 - val_loss: 0.8886
# Epoch 22/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0426 - val_loss: 0.8777
# Epoch 23/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9537 - val_loss: 0.8686
# Epoch 24/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0619 - val_loss: 0.8608
# Epoch 25/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0766 - val_loss: 0.8540
# Epoch 26/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9634 - val_loss: 0.8486
# Epoch 27/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0023 - val_loss: 0.8441
# Epoch 28/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0205 - val_loss: 0.8402
# Epoch 29/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9733 - val_loss: 0.8366
# Epoch 30/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1806 - val_loss: 0.8346
# Epoch 31/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1001 - val_loss: 0.8332
# Epoch 32/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8766 - val_loss: 0.8326
# Epoch 33/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9520 - val_loss: 0.8318
# Epoch 34/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8594 - val_loss: 0.8313
# Epoch 35/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9373 - val_loss: 0.8306
# Epoch 36/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0249 - val_loss: 0.8305
# Epoch 37/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0651 - val_loss: 0.8305
# Epoch 38/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9539 - val_loss: 0.8308
# Epoch 39/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9729 - val_loss: 0.8326
# Epoch 40/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9122 - val_loss: 0.8322
# Epoch 41/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9773 - val_loss: 0.8310
# Epoch 42/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0534 - val_loss: 0.8311
# Epoch 43/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9879 - val_loss: 0.8316
# Epoch 44/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9829 - val_loss: 0.8318
# Epoch 45/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9497 - val_loss: 0.8319
# Epoch 46/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9878 - val_loss: 0.8304
# Epoch 47/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9323 - val_loss: 0.8307
# Epoch 48/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8593 - val_loss: 0.8312
# Epoch 49/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9453 - val_loss: 0.8316
# Epoch 50/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9920 - val_loss: 0.8320
# Epoch 51/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9134 - val_loss: 0.8322
# Epoch 52/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1341 - val_loss: 0.8327
# Epoch 53/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9084 - val_loss: 0.8334
# Epoch 54/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0315 - val_loss: 0.8333
# Epoch 55/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8785 - val_loss: 0.8337
# Epoch 56/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9243 - val_loss: 0.8342
# Epoch 57/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9678 - val_loss: 0.8342
# Epoch 58/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9716 - val_loss: 0.8340
# Epoch 59/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9603 - val_loss: 0.8340
# Epoch 60/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0102 - val_loss: 0.8339
# Epoch 61/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9733 - val_loss: 0.8340
# Epoch 62/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8949 - val_loss: 0.8340
# Epoch 63/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9196 - val_loss: 0.8340
# Epoch 64/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.0133 - val_loss: 0.8342
# Epoch 65/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8977 - val_loss: 0.8342
# Epoch 66/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0263 - val_loss: 0.8343
# Epoch 67/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9119 - val_loss: 0.8343
# Epoch 68/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8783 - val_loss: 0.8344
# Epoch 69/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8476 - val_loss: 0.8341
# Epoch 70/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0148 - val_loss: 0.8343
# Epoch 71/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9652 - val_loss: 0.8344
# Epoch 72/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0556 - val_loss: 0.8340
# Epoch 73/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9226 - val_loss: 0.8341
# Epoch 74/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0431 - val_loss: 0.8344
# Epoch 75/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8309 - val_loss: 0.8340
# Epoch 76/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9775 - val_loss: 0.8341
# Epoch 77/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9000 - val_loss: 0.8349
# Epoch 78/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8656 - val_loss: 0.8343
# Epoch 79/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8984 - val_loss: 0.8347
# Epoch 80/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8478 - val_loss: 0.8346
# Epoch 81/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8785 - val_loss: 0.8346
# Epoch 82/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8602 - val_loss: 0.8344
# Epoch 83/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9183 - val_loss: 0.8355
# Epoch 84/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9678 - val_loss: 0.8351
# Epoch 85/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1448 - val_loss: 0.8350
# Epoch 86/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0334 - val_loss: 0.8352
# Epoch 87/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8760 - val_loss: 0.8357
# Epoch 88/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1020 - val_loss: 0.8353
# Epoch 89/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0143 - val_loss: 0.8354
# Epoch 90/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9411 - val_loss: 0.8348
# Epoch 91/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8409 - val_loss: 0.8341
# Epoch 92/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8338 - val_loss: 0.8345
# Epoch 93/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9998 - val_loss: 0.8339
# Epoch 94/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8195 - val_loss: 0.8339
# Epoch 95/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9301 - val_loss: 0.8345
# Epoch 96/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9362 - val_loss: 0.8342

# %%
print(f"Pesos finais:\n {model.get_weights()}")
# Out:
# Pesos finais:
#  [array([[0.2623623]], dtype=float32), array([0.0190428], dtype=float32)]

# %%
PlotHistory(history)

# %%
EvalModel(model)
# Out:
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# R²_Training = 0.3741212758902683
# MSE_Training = 0.13996672907376223
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step
# R²_Validation = 0.32618119900125414
# MSE_Validation = 0.10639417458189575
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# R²_Test 1 = 0.35699224982750816
# MSE_Test 1 = 0.127443466436906
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# R²_Test 2 = 0.3384343089898642
# MSE_Test 2 = 0.11453778150144688
