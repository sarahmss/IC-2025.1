# %% [markdown]
# # MLP simples com a diferença

# %% [markdown]
# - 1 saida - DeltaTheta
# - 2 entradas - Vd e Ve
# - 1 camada
# - 1 neurônio

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

Datasets = []
PREDICTORS = "VD-VE"   
TARGET = "Theta"       

for i in range(4):   
    Dataset = pd.read_csv(f"../Dados/Data{i + 1}.csv")
    
    # Remove colunas desnecessárias
    Dataset = Dataset.drop(columns=["X", "Y", "Setpoint VD", "Setpoint VE", "tempo"])
    
    # Ajusta índice pelo tempo
    Dataset.index = (np.arange(0, len(Dataset), 1).astype(float) * 0.07).round(5)
    
    # Cria nova coluna com VD - VE
    Dataset[PREDICTORS] = Dataset["VD"] - Dataset["VE"]
    
    Datasets.append(Dataset)
    
    print(f"++++++++++++++++++++ Dataset {i+1} +++++++++++++++++++++++")
    print(Dataset.head(5))
# Out:
# ++++++++++++++++++++ Dataset 1 +++++++++++++++++++++++
#       Theta    VD    VE  VD-VE
# 0.00    0.0  0.00  0.00    0.0
# 0.07    0.0  2.33  2.33    0.0
# 0.14    0.0  2.33  2.33    0.0
# 0.21    0.0  2.33  2.33    0.0
# 0.28    0.0  2.33  2.33    0.0
# ++++++++++++++++++++ Dataset 2 +++++++++++++++++++++++
#       Theta    VD    VE  VD-VE
# 0.00    0.0  2.33  2.33    0.0
# 0.07    0.0  2.33  2.33    0.0
# 0.14    0.0  2.33  2.33    0.0
# 0.21    0.0  2.33  2.33    0.0
# 0.28   -0.0  2.33  2.33    0.0
# ++++++++++++++++++++ Dataset 3 +++++++++++++++++++++++
#       Theta    VD    VE  VD-VE
# 0.00    0.0  0.00  0.00    0.0
# 0.07    0.0  2.33  2.33    0.0
# 0.14    0.0  2.33  2.33    0.0
# 0.21    0.0  2.33  2.33    0.0
# 0.28    0.0  2.33  2.33    0.0
# ++++++++++++++++++++ Dataset 4 +++++++++++++++++++++++
#       Theta    VD    VE  VD-VE
# 0.00    0.0  2.33  2.33    0.0
# 0.07    0.0  2.33  2.33    0.0
# 0.14    0.0  2.33  2.33    0.0
# 0.21    0.0  2.33  2.33    0.0
# 0.28    0.0  2.33  2.33    0.0

# %%
for  i in range(4):
    Dataset = Datasets[i].copy()  # evita sobrescrever o original
    Dataset["DeltaTheta"] = Dataset[TARGET].shift(-1) - Dataset[TARGET]
    # ou equivalente: Dataset["DeltaTheta"] = Dataset[TARGET].diff().shift(-1)
    
    # remove o último NaN (último ponto não tem próximo valor)
    Dataset = Dataset.dropna(subset=["DeltaTheta"])
    Datasets[i] = Dataset
    print(f"++++++++++++++++++++ Dataset {i+1} +++++++++++++++++++++++")
    print(Datasets[i].tail(5))
# Out:
# ++++++++++++++++++++ Dataset 1 +++++++++++++++++++++++
#         Theta    VD    VE  VD-VE  DeltaTheta
# 149.80  -0.81 -2.20 -2.38   0.18        0.00
# 149.87  -0.81 -2.23 -2.40   0.17        0.01
# 149.94  -0.80 -2.41 -2.24  -0.17        0.00
# 150.01  -0.80 -2.40 -2.22  -0.18        0.00
# 150.08  -0.80 -2.40 -2.22  -0.18        0.00
# ++++++++++++++++++++ Dataset 2 +++++++++++++++++++++++
#         Theta    VD    VE  VD-VE  DeltaTheta
# 141.47   0.73 -2.22 -2.40   0.18        0.00
# 141.54   0.73 -2.23 -2.40   0.17        0.00
# 141.61   0.73 -2.23 -2.40   0.17        0.01
# 141.68   0.74 -2.24 -2.41   0.17        0.00
# 141.75   0.74 -2.41 -2.25  -0.16        0.00
# ++++++++++++++++++++ Dataset 3 +++++++++++++++++++++++
#        Theta    VD    VE  VD-VE  DeltaTheta
# 92.40  -0.81 -2.36 -2.18  -0.18        0.00
# 92.47  -0.81 -2.37 -2.19  -0.18        0.00
# 92.54  -0.81 -2.37 -2.19  -0.18       -0.01
# 92.61  -0.82 -2.37 -2.18  -0.19       -0.01
# 92.68  -0.83 -2.38 -2.20  -0.18       -0.01
# ++++++++++++++++++++ Dataset 4 +++++++++++++++++++++++
#         Theta    VD    VE  VD-VE  DeltaTheta
# 114.17   0.74 -2.09 -2.30   0.21        0.00
# 114.24   0.74 -2.11 -2.31   0.20        0.01
# 114.31   0.75 -2.12 -2.32   0.20        0.00
# 114.38   0.75 -2.13 -2.33   0.20        0.01
# 114.45   0.76 -2.13 -2.33   0.20        0.00

# %%
NormDatasets = []

PREDICTORS = ["VD-VE" ]  
TARGET = ["DeltaTheta"]
SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

TrainDataset = Datasets[0]
TrainDataset[PREDICTORS] = SCALER.fit_transform(TrainDataset[PREDICTORS])
TrainDataset[TARGET] = OUT_SCALER.fit_transform(TrainDataset[TARGET])
NormDatasets.append(TrainDataset)

for i in range(3):
      CurrentTestDataset = Datasets[i + 1]
      CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
      CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
      NormDatasets.append(CurrentTestDataset)
      print(f"++++++++++++++++++++ Dataset Normalizado {i+1} +++++++++++++++++++++++")
      print(NormDatasets[i].head(5))
# Out:
# ++++++++++++++++++++ Dataset Normalizado 1 +++++++++++++++++++++++
#       Theta    VD    VE     VD-VE  DeltaTheta
# 0.00    0.0  0.00  0.00  0.038989    0.035731
# 0.07    0.0  2.33  2.33  0.038989    0.035731
# 0.14    0.0  2.33  2.33  0.038989    0.035731
# 0.21    0.0  2.33  2.33  0.038989    0.035731
# 0.28    0.0  2.33  2.33  0.038989    0.035731
# ++++++++++++++++++++ Dataset Normalizado 2 +++++++++++++++++++++++
#       Theta    VD    VE     VD-VE  DeltaTheta
# 0.00    0.0  2.33  2.33  0.038989    0.035731
# 0.07    0.0  2.33  2.33  0.038989    0.035731
# 0.14    0.0  2.33  2.33  0.038989    0.035731
# 0.21    0.0  2.33  2.33  0.038989    0.035731
# 0.28   -0.0  2.33  2.33  0.038989    0.035731
# ++++++++++++++++++++ Dataset Normalizado 3 +++++++++++++++++++++++
#       Theta    VD    VE     VD-VE  DeltaTheta
# 0.00    0.0  0.00  0.00  0.038989    0.035731
# 0.07    0.0  2.33  2.33  0.038989    0.035731
# 0.14    0.0  2.33  2.33  0.038989    0.035731
# 0.21    0.0  2.33  2.33  0.038989    0.035731
# 0.28    0.0  2.33  2.33  0.038989    0.035731

# %%
x_train = np.array(TrainDataset[PREDICTORS])
y_train = np.array(TrainDataset[TARGET])

x_val = np.array((NormDatasets[1])[PREDICTORS])
y_val = np.array((NormDatasets[1])[TARGET])

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")
# Out:
# Dimensão da entrada: (2145, 1)
# Dimensão da saida: (2145, 1)

# %%
import matplotlib.pyplot as plt

def PlotHistory(history):
    plt.figure(figsize=(8, 5))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('MSE Loss')
    plt.title('Training History')
    plt.legend()
    plt.grid(True)
    plt.show()
    
def PlotOut(axs, title, y_true, y_pred):
    y_true = np.ravel(y_true)
    y_pred = np.ravel(y_pred)
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    axs.scatter(time, y_true, marker='o', label='Amostras Reais')
    axs.scatter(time, y_pred, marker='x', label='Valores Preditos')
    axs.set_title(f'{title}')
    axs.set_xlabel('Theta')
    axs.set_ylabel('tempo')
    axs.legend()
    axs.grid(True)

# %%
from sklearn.metrics import mean_squared_error, r2_score

TITLES = ["Training", "Validation", "Test 1", "Test 2"]

def EvalModel(model):
    fig, axs = plt.subplots(4, 1, figsize=(12, 12))
    for i, dataset in enumerate(NormDatasets):
        x = np.array(dataset[PREDICTORS])
        
        # diferenças reais e previstas (já desnormalizadas)
        y_diff = OUT_SCALER.inverse_transform(dataset[TARGET])
        y_pred_diff = OUT_SCALER.inverse_transform(model.predict(x))
        
        # valor inicial de theta no dataset original (não normalizado)
        theta0 = Datasets[i]["Theta"].iloc[0]  
        
        # reconstrução: soma cumulativa
        y_real = theta0 + np.cumsum(y_diff, axis=0)
        y_pred = theta0 + np.cumsum(y_pred_diff, axis=0)
        
        # métricas no espaço de θ
        R2 = r2_score(y_real, y_pred)
        MSE = mean_squared_error(y_real, y_pred)
        print(f"R²_{TITLES[i]} = {R2}")
        print(f"MSE_{TITLES[i]} = {MSE}")
        
        # plota saída
        PlotOut(axs[i], TITLES[i], y_real, y_pred)

# %%
import numpy as np
from tensorflow import keras
from keras.callbacks import EarlyStopping

INPUT_SIZE = len(PREDICTORS)

model = keras.models.Sequential([
    keras.layers.Input(shape=(INPUT_SIZE,)),
    keras.layers.Dense(1, activation="linear"),
])
model.summary()

w, b = [[[0.02710000053048134]], [0.0]]

# Converte para numpy arrays no formato certo
weights = np.array(w, dtype=np.float32).reshape(INPUT_SIZE, 1)
bias = np.array(b, dtype=np.float32).reshape(1,)

model.set_weights([weights, bias])
print(f"Pesos iniciais:\n{model.get_weights()}")
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)
# Pesos iniciais:
# [array([[0.0271]], dtype=float32), array([0.], dtype=float32)]

# %% [markdown]
# Configures the model for training.

# %%
model.compile(loss="mean_squared_error", optimizer="adam")

# %% [markdown]
# Trains the model for a fixed number of epochs (dataset iterations).

# %%
early_stopping_monitor = EarlyStopping(monitor='val_loss',
                                patience=50,
                                restore_best_weights=True)

history = model.fit(x_train, 
                    y_train, 
                    epochs=1000,
                    callbacks=[early_stopping_monitor],
 validation_data=(x_val, y_val))
# Out:
# Epoch 1/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1420 - val_loss: 0.8670
# Epoch 2/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8853 - val_loss: 0.8560
# Epoch 3/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0083 - val_loss: 0.8487
# Epoch 4/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9404 - val_loss: 0.8435
# Epoch 5/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9737 - val_loss: 0.8409
# Epoch 6/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8991 - val_loss: 0.8393
# Epoch 7/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9090 - val_loss: 0.8375
# Epoch 8/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9194 - val_loss: 0.8362
# Epoch 9/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1220 - val_loss: 0.8336
# Epoch 10/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9670 - val_loss: 0.8343
# Epoch 11/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8953 - val_loss: 0.8343
# Epoch 12/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9805 - val_loss: 0.8341
# Epoch 13/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0029 - val_loss: 0.8341
# Epoch 14/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9964 - val_loss: 0.8340
# Epoch 15/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9297 - val_loss: 0.8345
# Epoch 16/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8612 - val_loss: 0.8342
# Epoch 17/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0301 - val_loss: 0.8343
# Epoch 18/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0109 - val_loss: 0.8344
# Epoch 19/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0869 - val_loss: 0.8340
# Epoch 20/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0384 - val_loss: 0.8343
# Epoch 21/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9898 - val_loss: 0.8350
# Epoch 22/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9606 - val_loss: 0.8342
# Epoch 23/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9406 - val_loss: 0.8343
# Epoch 24/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9095 - val_loss: 0.8343
# Epoch 25/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1125 - val_loss: 0.8344
# Epoch 26/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9630 - val_loss: 0.8349
# Epoch 27/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0179 - val_loss: 0.8341
# Epoch 28/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0054 - val_loss: 0.8342
# Epoch 29/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9692 - val_loss: 0.8341
# Epoch 30/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7402 - val_loss: 0.8343
# Epoch 31/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9730 - val_loss: 0.8344
# Epoch 32/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9941 - val_loss: 0.8366
# Epoch 33/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9223 - val_loss: 0.8361
# Epoch 34/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8857 - val_loss: 0.8356
# Epoch 35/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9204 - val_loss: 0.8354
# Epoch 36/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8608 - val_loss: 0.8356
# Epoch 37/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0206 - val_loss: 0.8354
# Epoch 38/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8807 - val_loss: 0.8346
# Epoch 39/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8915 - val_loss: 0.8343
# Epoch 40/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8012 - val_loss: 0.8349
# Epoch 41/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9059 - val_loss: 0.8343
# Epoch 42/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9040 - val_loss: 0.8340
# Epoch 43/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9451 - val_loss: 0.8343
# Epoch 44/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9337 - val_loss: 0.8345
# Epoch 45/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8684 - val_loss: 0.8343
# Epoch 46/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9493 - val_loss: 0.8340
# Epoch 47/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0144 - val_loss: 0.8337
# Epoch 48/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9783 - val_loss: 0.8340
# Epoch 49/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8710 - val_loss: 0.8337
# Epoch 50/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0364 - val_loss: 0.8336
# Epoch 51/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8695 - val_loss: 0.8341
# Epoch 52/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9404 - val_loss: 0.8341
# Epoch 53/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0298 - val_loss: 0.8346
# Epoch 54/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9543 - val_loss: 0.8341
# Epoch 55/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9337 - val_loss: 0.8345
# Epoch 56/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9362 - val_loss: 0.8342
# Epoch 57/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9372 - val_loss: 0.8336
# Epoch 58/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0827 - val_loss: 0.8339
# Epoch 59/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9274 - val_loss: 0.8340
# Epoch 60/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0400 - val_loss: 0.8337
# Epoch 61/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1891 - val_loss: 0.8339
# Epoch 62/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8853 - val_loss: 0.8346
# Epoch 63/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0326 - val_loss: 0.8341
# Epoch 64/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9606 - val_loss: 0.8355
# Epoch 65/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9353 - val_loss: 0.8348
# Epoch 66/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9380 - val_loss: 0.8349
# Epoch 67/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8921 - val_loss: 0.8345
# Epoch 68/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0451 - val_loss: 0.8345
# Epoch 69/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0343 - val_loss: 0.8344
# Epoch 70/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9475 - val_loss: 0.8343
# Epoch 71/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8262 - val_loss: 0.8340
# Epoch 72/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9285 - val_loss: 0.8338
# Epoch 73/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1160 - val_loss: 0.8339
# Epoch 74/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8501 - val_loss: 0.8341
# Epoch 75/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0137 - val_loss: 0.8339
# Epoch 76/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1047 - val_loss: 0.8366
# Epoch 77/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9717 - val_loss: 0.8358
# Epoch 78/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8998 - val_loss: 0.8356
# Epoch 79/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8275 - val_loss: 0.8356
# Epoch 80/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9777 - val_loss: 0.8354
# Epoch 81/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9856 - val_loss: 0.8346
# Epoch 82/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8476 - val_loss: 0.8345
# Epoch 83/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9676 - val_loss: 0.8340
# Epoch 84/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0004 - val_loss: 0.8343
# Epoch 85/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9438 - val_loss: 0.8337
# Epoch 86/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9681 - val_loss: 0.8341
# Epoch 87/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8829 - val_loss: 0.8344
# Epoch 88/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.0025 - val_loss: 0.8340
# Epoch 89/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8894 - val_loss: 0.8346
# Epoch 90/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0847 - val_loss: 0.8344
# Epoch 91/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8850 - val_loss: 0.8341
# Epoch 92/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9179 - val_loss: 0.8344
# Epoch 93/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9113 - val_loss: 0.8341
# Epoch 94/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9915 - val_loss: 0.8344
# Epoch 95/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0155 - val_loss: 0.8340
# Epoch 96/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9153 - val_loss: 0.8323
# Epoch 97/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9592 - val_loss: 0.8327
# Epoch 98/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9747 - val_loss: 0.8332
# Epoch 99/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8790 - val_loss: 0.8333
# Epoch 100/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9990 - val_loss: 0.8311
# Epoch 101/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8952 - val_loss: 0.8319
# Epoch 102/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9243 - val_loss: 0.8321
# Epoch 103/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9635 - val_loss: 0.8325
# Epoch 104/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0379 - val_loss: 0.8328
# Epoch 105/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0769 - val_loss: 0.8332
# Epoch 106/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9511 - val_loss: 0.8335
# Epoch 107/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8678 - val_loss: 0.8332
# Epoch 108/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.8411 - val_loss: 0.8337
# Epoch 109/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9571 - val_loss: 0.8335
# Epoch 110/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8358 - val_loss: 0.8338
# Epoch 111/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0430 - val_loss: 0.8340
# Epoch 112/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0617 - val_loss: 0.8341
# Epoch 113/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8474 - val_loss: 0.8342
# Epoch 114/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9410 - val_loss: 0.8334
# Epoch 115/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0083 - val_loss: 0.8339
# Epoch 116/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9384 - val_loss: 0.8335
# Epoch 117/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9762 - val_loss: 0.8338
# Epoch 118/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9561 - val_loss: 0.8344
# Epoch 119/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9944 - val_loss: 0.8339
# Epoch 120/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8545 - val_loss: 0.8340
# Epoch 121/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9718 - val_loss: 0.8333
# Epoch 122/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8669 - val_loss: 0.8340
# Epoch 123/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0429 - val_loss: 0.8335
# Epoch 124/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9596 - val_loss: 0.8337
# Epoch 125/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9801 - val_loss: 0.8340
# Epoch 126/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9669 - val_loss: 0.8335
# Epoch 127/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8373 - val_loss: 0.8339
# Epoch 128/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8947 - val_loss: 0.8340
# Epoch 129/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9301 - val_loss: 0.8341
# Epoch 130/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0213 - val_loss: 0.8340
# Epoch 131/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0481 - val_loss: 0.8342
# Epoch 132/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9800 - val_loss: 0.8341
# Epoch 133/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0426 - val_loss: 0.8345
# Epoch 134/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9041 - val_loss: 0.8341
# Epoch 135/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9910 - val_loss: 0.8340
# Epoch 136/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7739 - val_loss: 0.8341
# Epoch 137/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9887 - val_loss: 0.8325
# Epoch 138/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0763 - val_loss: 0.8329
# Epoch 139/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8821 - val_loss: 0.8332
# Epoch 140/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0130 - val_loss: 0.8329
# Epoch 141/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8882 - val_loss: 0.8334
# Epoch 142/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0124 - val_loss: 0.8335
# Epoch 143/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8948 - val_loss: 0.8338
# Epoch 144/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8405 - val_loss: 0.8342
# Epoch 145/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9120 - val_loss: 0.8335
# Epoch 146/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0822 - val_loss: 0.8332
# Epoch 147/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9332 - val_loss: 0.8333
# Epoch 148/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9956 - val_loss: 0.8339
# Epoch 149/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9443 - val_loss: 0.8356
# Epoch 150/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8672 - val_loss: 0.8349

# %%
print(f"Pesos finais:\n {model.get_weights()}")
# Out:
# Pesos finais:
#  [array([[0.25131962]], dtype=float32), array([0.01730857], dtype=float32)]

# %%
PlotHistory(history)

# %%
EvalModel(model)
# Out:
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# R²_Training = 0.4320612946346476
# MSE_Training = 0.1467505177322448
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# R²_Validation = 0.33591256539241143
# MSE_Validation = 0.11776184569195178
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# R²_Test 1 = 0.47521610884088883
# MSE_Test 1 = 0.13009454420808947
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step
# R²_Test 2 = 0.30700624187778947
# MSE_Test 2 = 0.12251827403106494

# %%
w, b = [[[0.25679999589920044]], [0.022199999541044235]]

# Converte para numpy arrays no formato certo
weights = np.array(w, dtype=np.float32).reshape(INPUT_SIZE, 1)
bias = np.array(b, dtype=np.float32).reshape(1,)

model.set_weights([weights, bias])
print(f"Pesos iniciais:\n{model.get_weights()}")
EvalModel(model)
# Out:
# Pesos iniciais:
# [array([[0.2568]], dtype=float32), array([0.0222], dtype=float32)]
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# R²_Training = 0.458345318652287
# MSE_Training = 0.13995895009257492
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step
# R²_Validation = 0.43964649245602905
# MSE_Validation = 0.09936683010322236
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# R²_Test 1 = 0.4702169594544683
# MSE_Test 1 = 0.13133383922421135
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# R²_Test 2 = 0.3796245395610035
# MSE_Test 2 = 0.10967967571622635
