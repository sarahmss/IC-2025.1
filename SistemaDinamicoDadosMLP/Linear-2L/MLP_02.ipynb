# %% [markdown]
# # MLP simples

# %%
import pandas as pd 
import numpy as np
from sklearn.preprocessing import StandardScaler

Datasets = []
PREDICTORS = ["VD", "VE"]
TARGET = ["Theta"]

for i in range(4):   
    Dataset = pd.read_csv(f"../Dados/Data{i + 1}.csv")
    Dataset = Dataset.drop(columns=["X", "Y", "Setpoint VD", "Setpoint VE", "tempo"])
    Dataset.index = (np.arange(0, len(Dataset), 1).astype(float) * 0.07).round(5)
    Datasets.append(Dataset)
    print(f"++++++++++++++++++++ Dataset {i+1} +++++++++++++++++++++++")
    print(Datasets[i].head(5))
# Out:
# ++++++++++++++++++++ Dataset 1 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  0.00  0.00
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28    0.0  2.33  2.33
# ++++++++++++++++++++ Dataset 2 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  2.33  2.33
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28   -0.0  2.33  2.33
# ++++++++++++++++++++ Dataset 3 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  0.00  0.00
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28    0.0  2.33  2.33
# ++++++++++++++++++++ Dataset 4 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  2.33  2.33
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28    0.0  2.33  2.33

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

TrainDataset = Datasets[0]
TrainDataset[PREDICTORS] = SCALER.fit_transform(TrainDataset[PREDICTORS])
TrainDataset[TARGET] = OUT_SCALER.fit_transform(TrainDataset[TARGET])
NormDatasets.append(TrainDataset)

for i in range(3):
      CurrentTestDataset = Datasets[i + 1]
      CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
      CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
      NormDatasets.append(CurrentTestDataset)
      print(f"++++++++++++++++++++ Dataset Normalizado {i+1} +++++++++++++++++++++++")
      print(NormDatasets[i].head(5))
# Out:
# ++++++++++++++++++++ Dataset Normalizado 1 +++++++++++++++++++++++
#          Theta        VD        VE
# 0.00 -0.147046  0.098819  0.089409
# 0.07 -0.147046  1.268765  1.266904
# 0.14 -0.147046  1.268765  1.266904
# 0.21 -0.147046  1.268765  1.266904
# 0.28 -0.147046  1.268765  1.266904
# ++++++++++++++++++++ Dataset Normalizado 2 +++++++++++++++++++++++
#          Theta        VD        VE
# 0.00 -0.147046  1.268765  1.266904
# 0.07 -0.147046  1.268765  1.266904
# 0.14 -0.147046  1.268765  1.266904
# 0.21 -0.147046  1.268765  1.266904
# 0.28 -0.147046  1.268765  1.266904
# ++++++++++++++++++++ Dataset Normalizado 3 +++++++++++++++++++++++
#          Theta        VD        VE
# 0.00 -0.147046  0.098819  0.089409
# 0.07 -0.147046  1.268765  1.266904
# 0.14 -0.147046  1.268765  1.266904
# 0.21 -0.147046  1.268765  1.266904
# 0.28 -0.147046  1.268765  1.266904

# %%
x_train = np.array(TrainDataset[PREDICTORS])
y_train = np.array(TrainDataset[TARGET])

x_val = np.array((NormDatasets[1])[PREDICTORS])
y_val = np.array((NormDatasets[1])[TARGET])

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")
# Out:
# Dimensão da entrada: (2146, 2)
# Dimensão da saida: (2146, 1)

# %%
import matplotlib.pyplot as plt

def PlotHistory(history):
    plt.figure(figsize=(8, 5))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('MSE Loss')
    plt.title('Training History')
    plt.legend()
    plt.grid(True)
    plt.show()
    
def PlotOut(axs, title, y_true, y_pred):
    y_true = np.ravel(y_true)
    y_pred = np.ravel(y_pred)
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    axs.scatter(time, y_true, marker='o', label='Amostras Reais')
    axs.scatter(time, y_pred, marker='x', label='Valores Preditos')
    axs.set_title(f'{title}')
    axs.set_xlabel('Theta')
    axs.set_ylabel('tempo')
    axs.legend()
    axs.grid(True)

# %%
from sklearn.metrics import mean_squared_error, r2_score

TITLES = ["Training", "Validation", "Test 1", "Test 2"]

def EvalModel(model):
    fig, axs = plt.subplots(4, 1, figsize=(12, 12))
    for i, dataset in enumerate(NormDatasets):
        x = np.array(dataset[PREDICTORS])
        y = OUT_SCALER.inverse_transform(dataset[TARGET])
        y_pred = OUT_SCALER.inverse_transform(model.predict(x))
    
        R2 = r2_score(y, y_pred)
        MSE = mean_squared_error(y, y_pred)
        print(f"R²_{TITLES[i]} = {R2}")
        print(f"MSE_{TITLES[i]} = {MSE}")
        
        PlotOut(axs[i], TITLES[i], y, y_pred)

# %%
from tensorflow import keras
from keras.callbacks import EarlyStopping

INPUT_SIZE = len(PREDICTORS)  


model = keras.models.Sequential([
    keras.layers.Input(shape=(INPUT_SIZE,)),
    keras.layers.Dense(1, activation="linear"),  
    keras.layers.Dense(1)  
])
model.summary()
print(f"Pesos inciais:\n {model.get_weights()}")
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1)              │             3 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5 (20.00 B)
#  Trainable params: 5 (20.00 B)
#  Non-trainable params: 0 (0.00 B)
# Pesos inciais:
#  [array([[0.4881401],
#        [1.3002521]], dtype=float32), array([0.], dtype=float32), array([[-1.0281639]], dtype=float32), array([0.], dtype=float32)]

# %% [markdown]
# Configures the model for training.

# %%
model.compile(loss="mean_squared_error", optimizer="adam")

# %% [markdown]
# Trains the model for a fixed number of epochs (dataset iterations).

# %%
early_stopping_monitor = EarlyStopping(monitor='val_loss',
                                patience=100,
                                restore_best_weights=True)

history = model.fit(x_train, 
                    y_train, 
                    epochs=1000,
                    callbacks=[early_stopping_monitor],
 validation_data=(x_val, y_val))
# Out:
# Epoch 1/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.3418 - val_loss: 3.5639
# Epoch 2/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5001 - val_loss: 2.8984
# Epoch 3/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7975 - val_loss: 2.3997
# Epoch 4/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.4793 - val_loss: 2.0313
# Epoch 5/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1443 - val_loss: 1.7623
# Epoch 6/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8466 - val_loss: 1.5519
# Epoch 7/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7487 - val_loss: 1.3835
# Epoch 8/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.5710 - val_loss: 1.2609
# Epoch 9/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5812 - val_loss: 1.1651
# Epoch 10/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4114 - val_loss: 1.0921
# Epoch 11/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3200 - val_loss: 1.0281
# Epoch 12/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.2856 - val_loss: 0.9820
# Epoch 13/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2029 - val_loss: 0.9405
# Epoch 14/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.1942 - val_loss: 0.9063
# Epoch 15/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1474 - val_loss: 0.8796
# Epoch 16/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.1632 - val_loss: 0.8550
# Epoch 17/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1316 - val_loss: 0.8382
# Epoch 18/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1251 - val_loss: 0.8220
# Epoch 19/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1005 - val_loss: 0.8102
# Epoch 20/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1362 - val_loss: 0.8018
# Epoch 21/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0636 - val_loss: 0.7953
# Epoch 22/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0738 - val_loss: 0.7836
# Epoch 23/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0701 - val_loss: 0.7761
# Epoch 24/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0575 - val_loss: 0.7712
# Epoch 25/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0477 - val_loss: 0.7654
# Epoch 26/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0893 - val_loss: 0.7600
# Epoch 27/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0727 - val_loss: 0.7561
# Epoch 28/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0158 - val_loss: 0.7522
# Epoch 29/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0773 - val_loss: 0.7511
# Epoch 30/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0500 - val_loss: 0.7490
# Epoch 31/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0790 - val_loss: 0.7465
# Epoch 32/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0209 - val_loss: 0.7439
# Epoch 33/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.0191 - val_loss: 0.7424
# Epoch 34/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0032 - val_loss: 0.7392
# Epoch 35/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0149 - val_loss: 0.7352
# Epoch 36/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9926 - val_loss: 0.7348
# Epoch 37/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0014 - val_loss: 0.7326
# Epoch 38/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0306 - val_loss: 0.7307
# Epoch 39/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.0095 - val_loss: 0.7303
# Epoch 40/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9969 - val_loss: 0.7281
# Epoch 41/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0381 - val_loss: 0.7305
# Epoch 42/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0128 - val_loss: 0.7292
# Epoch 43/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0025 - val_loss: 0.7284
# Epoch 44/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0182 - val_loss: 0.7278
# Epoch 45/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0103 - val_loss: 0.7286
# Epoch 46/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0391 - val_loss: 0.7271
# Epoch 47/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9999 - val_loss: 0.7280
# Epoch 48/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0095 - val_loss: 0.7283
# Epoch 49/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0531 - val_loss: 0.7273
# Epoch 50/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9800 - val_loss: 0.7275
# Epoch 51/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.0246 - val_loss: 0.7267
# Epoch 52/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9991 - val_loss: 0.7283
# Epoch 53/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0127 - val_loss: 0.7294
# Epoch 54/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0394 - val_loss: 0.7281
# Epoch 55/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9922 - val_loss: 0.7304
# Epoch 56/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9937 - val_loss: 0.7277
# Epoch 57/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9664 - val_loss: 0.7253
# Epoch 58/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0200 - val_loss: 0.7252
# Epoch 59/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0044 - val_loss: 0.7231
# Epoch 60/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9622 - val_loss: 0.7224
# Epoch 61/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9654 - val_loss: 0.7227
# Epoch 62/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0495 - val_loss: 0.7252
# Epoch 63/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9933 - val_loss: 0.7234
# Epoch 64/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0152 - val_loss: 0.7228
# Epoch 65/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9922 - val_loss: 0.7231
# Epoch 66/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0160 - val_loss: 0.7213
# Epoch 67/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9910 - val_loss: 0.7199
# Epoch 68/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0653 - val_loss: 0.7208
# Epoch 69/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0501 - val_loss: 0.7225
# Epoch 70/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9985 - val_loss: 0.7230
# Epoch 71/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0036 - val_loss: 0.7213
# Epoch 72/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.0132 - val_loss: 0.7204
# Epoch 73/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0023 - val_loss: 0.7199
# Epoch 74/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9834 - val_loss: 0.7205
# Epoch 75/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.0326 - val_loss: 0.7202
# Epoch 76/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9840 - val_loss: 0.7202
# Epoch 77/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0345 - val_loss: 0.7217
# Epoch 78/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0057 - val_loss: 0.7209
# Epoch 79/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9667 - val_loss: 0.7201
# Epoch 80/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9857 - val_loss: 0.7182
# Epoch 81/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9952 - val_loss: 0.7183
# Epoch 82/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9747 - val_loss: 0.7189
# Epoch 83/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0306 - val_loss: 0.7166
# Epoch 84/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0452 - val_loss: 0.7167
# Epoch 85/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.0134 - val_loss: 0.7188
# Epoch 86/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0232 - val_loss: 0.7182
# Epoch 87/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0338 - val_loss: 0.7148
# Epoch 88/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9925 - val_loss: 0.7152
# Epoch 89/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0526 - val_loss: 0.7172
# Epoch 90/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0326 - val_loss: 0.7157
# Epoch 91/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0151 - val_loss: 0.7173
# Epoch 92/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0235 - val_loss: 0.7168
# Epoch 93/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9827 - val_loss: 0.7152
# Epoch 94/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9831 - val_loss: 0.7148
# Epoch 95/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0375 - val_loss: 0.7131
# Epoch 96/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0000 - val_loss: 0.7124
# Epoch 97/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9723 - val_loss: 0.7129
# Epoch 98/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9936 - val_loss: 0.7140
# Epoch 99/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9821 - val_loss: 0.7108
# Epoch 100/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9683 - val_loss: 0.7112
# Epoch 101/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9790 - val_loss: 0.7098
# Epoch 102/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9878 - val_loss: 0.7110
# Epoch 103/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0117 - val_loss: 0.7115
# Epoch 104/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9587 - val_loss: 0.7119
# Epoch 105/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9853 - val_loss: 0.7101
# Epoch 106/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0218 - val_loss: 0.7056
# Epoch 107/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9860 - val_loss: 0.7036
# Epoch 108/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9734 - val_loss: 0.7001
# Epoch 109/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0025 - val_loss: 0.7007
# Epoch 110/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9984 - val_loss: 0.7018
# Epoch 111/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9839 - val_loss: 0.6992
# Epoch 112/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9470 - val_loss: 0.6969
# Epoch 113/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9611 - val_loss: 0.6984
# Epoch 114/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9555 - val_loss: 0.6955
# Epoch 115/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9637 - val_loss: 0.6960
# Epoch 116/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9535 - val_loss: 0.6985
# Epoch 117/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9503 - val_loss: 0.6965
# Epoch 118/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9578 - val_loss: 0.6924
# Epoch 119/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9629 - val_loss: 0.6895
# Epoch 120/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9601 - val_loss: 0.6886
# Epoch 121/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9652 - val_loss: 0.6873
# Epoch 122/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9920 - val_loss: 0.6895
# Epoch 123/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9725 - val_loss: 0.6881
# Epoch 124/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9559 - val_loss: 0.6862
# Epoch 125/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9574 - val_loss: 0.6866
# Epoch 126/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9609 - val_loss: 0.6881
# Epoch 127/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9423 - val_loss: 0.6875
# Epoch 128/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9595 - val_loss: 0.6880
# Epoch 129/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9679 - val_loss: 0.6869
# Epoch 130/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9377 - val_loss: 0.6870
# Epoch 131/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9601 - val_loss: 0.6867
# Epoch 132/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9361 - val_loss: 0.6864
# Epoch 133/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9764 - val_loss: 0.6861
# Epoch 134/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9491 - val_loss: 0.6882
# Epoch 135/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9693 - val_loss: 0.6883
# Epoch 136/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9105 - val_loss: 0.6871
# Epoch 137/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9531 - val_loss: 0.6898
# Epoch 138/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9269 - val_loss: 0.6904
# Epoch 139/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9470 - val_loss: 0.6905
# Epoch 140/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9358 - val_loss: 0.6857
# Epoch 141/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9279 - val_loss: 0.6853
# Epoch 142/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9600 - val_loss: 0.6835
# Epoch 143/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9755 - val_loss: 0.6822
# Epoch 144/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9359 - val_loss: 0.6846
# Epoch 145/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9338 - val_loss: 0.6838
# Epoch 146/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9644 - val_loss: 0.6853
# Epoch 147/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9280 - val_loss: 0.6849
# Epoch 148/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9329 - val_loss: 0.6850
# Epoch 149/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9256 - val_loss: 0.6855
# Epoch 150/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9423 - val_loss: 0.6862
# Epoch 151/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9624 - val_loss: 0.6856
# Epoch 152/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9311 - val_loss: 0.6839
# Epoch 153/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9473 - val_loss: 0.6870
# Epoch 154/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9449 - val_loss: 0.6853
# Epoch 155/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9215 - val_loss: 0.6849
# Epoch 156/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9408 - val_loss: 0.6854
# Epoch 157/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9681 - val_loss: 0.6902
# Epoch 158/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9631 - val_loss: 0.6892
# Epoch 159/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9740 - val_loss: 0.6861
# Epoch 160/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9917 - val_loss: 0.6843
# Epoch 161/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9628 - val_loss: 0.6864
# Epoch 162/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9661 - val_loss: 0.6848
# Epoch 163/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9576 - val_loss: 0.6859
# Epoch 164/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9437 - val_loss: 0.6852
# Epoch 165/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9410 - val_loss: 0.6837
# Epoch 166/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9333 - val_loss: 0.6857
# Epoch 167/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9464 - val_loss: 0.6842
# Epoch 168/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9213 - val_loss: 0.6838
# Epoch 169/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9437 - val_loss: 0.6848
# Epoch 170/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9694 - val_loss: 0.6865
# Epoch 171/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9288 - val_loss: 0.6853
# Epoch 172/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9364 - val_loss: 0.6875
# Epoch 173/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9500 - val_loss: 0.6893
# Epoch 174/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9570 - val_loss: 0.6871
# Epoch 175/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9478 - val_loss: 0.6871
# Epoch 176/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9297 - val_loss: 0.6860
# Epoch 177/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9610 - val_loss: 0.6883
# Epoch 178/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9727 - val_loss: 0.6861
# Epoch 179/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9303 - val_loss: 0.6894
# Epoch 180/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9602 - val_loss: 0.6877
# Epoch 181/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9472 - val_loss: 0.6872
# Epoch 182/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9475 - val_loss: 0.6900
# Epoch 183/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9738 - val_loss: 0.6834
# Epoch 184/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9545 - val_loss: 0.6836
# Epoch 185/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9730 - val_loss: 0.6853
# Epoch 186/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9308 - val_loss: 0.6850
# Epoch 187/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9234 - val_loss: 0.6870
# Epoch 188/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.9456 - val_loss: 0.6858
# Epoch 189/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9144 - val_loss: 0.6852
# Epoch 190/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9754 - val_loss: 0.6883
# Epoch 191/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9660 - val_loss: 0.6864
# Epoch 192/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9481 - val_loss: 0.6877
# Epoch 193/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9340 - val_loss: 0.6871
# Epoch 194/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9691 - val_loss: 0.6854
# Epoch 195/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9528 - val_loss: 0.6877
# Epoch 196/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9217 - val_loss: 0.6872
# Epoch 197/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9513 - val_loss: 0.6873
# Epoch 198/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9284 - val_loss: 0.6859
# Epoch 199/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9561 - val_loss: 0.6882
# Epoch 200/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9425 - val_loss: 0.6857
# Epoch 201/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9275 - val_loss: 0.6857
# Epoch 202/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9499 - val_loss: 0.6855
# Epoch 203/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9477 - val_loss: 0.6860
# Epoch 204/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9227 - val_loss: 0.6854
# Epoch 205/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9450 - val_loss: 0.6866
# Epoch 206/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9458 - val_loss: 0.6859
# Epoch 207/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9366 - val_loss: 0.6876
# Epoch 208/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9044 - val_loss: 0.6895
# Epoch 209/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9401 - val_loss: 0.6866
# Epoch 210/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9516 - val_loss: 0.6863
# Epoch 211/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9172 - val_loss: 0.6836
# Epoch 212/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9581 - val_loss: 0.6834
# Epoch 213/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9596 - val_loss: 0.6846
# Epoch 214/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9459 - val_loss: 0.6855
# Epoch 215/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9536 - val_loss: 0.6871
# Epoch 216/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9382 - val_loss: 0.6863
# Epoch 217/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9520 - val_loss: 0.6876
# Epoch 218/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9388 - val_loss: 0.6881
# Epoch 219/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9683 - val_loss: 0.6869
# Epoch 220/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9284 - val_loss: 0.6866
# Epoch 221/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9342 - val_loss: 0.6886
# Epoch 222/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9438 - val_loss: 0.6877
# Epoch 223/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9637 - val_loss: 0.6859
# Epoch 224/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9503 - val_loss: 0.6884
# Epoch 225/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9511 - val_loss: 0.6879
# Epoch 226/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9619 - val_loss: 0.6869
# Epoch 227/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9576 - val_loss: 0.6862
# Epoch 228/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9299 - val_loss: 0.6857
# Epoch 229/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9243 - val_loss: 0.6861
# Epoch 230/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9450 - val_loss: 0.6855
# Epoch 231/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9698 - val_loss: 0.6855
# Epoch 232/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9314 - val_loss: 0.6853
# Epoch 233/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9687 - val_loss: 0.6845
# Epoch 234/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9512 - val_loss: 0.6840
# Epoch 235/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9628 - val_loss: 0.6842
# Epoch 236/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9477 - val_loss: 0.6882
# Epoch 237/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9361 - val_loss: 0.6895
# Epoch 238/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9492 - val_loss: 0.6869
# Epoch 239/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9603 - val_loss: 0.6859
# Epoch 240/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9776 - val_loss: 0.6843
# Epoch 241/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9593 - val_loss: 0.6886
# Epoch 242/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9357 - val_loss: 0.6886
# Epoch 243/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9414 - val_loss: 0.6877

# %%
print(f"Pesos finais:\n {model.get_weights()}")
# Out:
# Pesos finais:
#  [array([[-0.6952822],
#        [ 0.7135177]], dtype=float32), array([-0.00703867], dtype=float32), array([[1.1369586]], dtype=float32), array([-0.0065627], dtype=float32)]

# %%
PlotHistory(history)

# %%
EvalModel(model)
# Out:
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# R²_Training = 0.050020767399554744
# MSE_Training = 0.2453546216868364
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# R²_Validation = 0.0058692406015485865
# MSE_Validation = 0.1762012341408673
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# R²_Test 1 = 0.06789086918396581
# MSE_Test 1 = 0.2308975383757877
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# R²_Test 2 = 0.03874240320243194
# MSE_Test 2 = 0.16984482573939705
