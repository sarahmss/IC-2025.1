# %% [markdown]
# # MLP simples

# %% [markdown]
# - 1 saida - DeltaTheta
# - 2 entradas - Vd e Ve
# - 2 camadas
# - n neurônios

# %%
import pandas as pd 
import numpy as np
from sklearn.preprocessing import StandardScaler

Datasets = []
PREDICTORS = ["VD", "VE"]
TARGET = ["Theta"]

for i in range(4):   
    Dataset = pd.read_csv(f"../Dados/Data{i + 1}.csv")
    Dataset = Dataset.drop(columns=["X", "Y", "Setpoint VD", "Setpoint VE", "tempo"])
    Dataset.index = (np.arange(0, len(Dataset), 1).astype(float) * 0.07).round(5)
    Datasets.append(Dataset)
    print(f"++++++++++++++++++++ Dataset {i+1} +++++++++++++++++++++++")
    print(Datasets[i].head(5))
# Out:
# ++++++++++++++++++++ Dataset 1 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  0.00  0.00
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28    0.0  2.33  2.33
# ++++++++++++++++++++ Dataset 2 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  2.33  2.33
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28   -0.0  2.33  2.33
# ++++++++++++++++++++ Dataset 3 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  0.00  0.00
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28    0.0  2.33  2.33
# ++++++++++++++++++++ Dataset 4 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  2.33  2.33
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28    0.0  2.33  2.33

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

TrainDataset = Datasets[0]
TrainDataset[PREDICTORS] = SCALER.fit_transform(TrainDataset[PREDICTORS])
TrainDataset[TARGET] = OUT_SCALER.fit_transform(TrainDataset[TARGET])
NormDatasets.append(TrainDataset)

for i in range(3):
      CurrentTestDataset = Datasets[i + 1]
      CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
      CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
      NormDatasets.append(CurrentTestDataset)
      print(f"++++++++++++++++++++ Dataset Normalizado {i+1} +++++++++++++++++++++++")
      print(NormDatasets[i].head(5))
# Out:
# ++++++++++++++++++++ Dataset Normalizado 1 +++++++++++++++++++++++
#          Theta        VD        VE
# 0.00 -0.147046  0.098819  0.089409
# 0.07 -0.147046  1.268765  1.266904
# 0.14 -0.147046  1.268765  1.266904
# 0.21 -0.147046  1.268765  1.266904
# 0.28 -0.147046  1.268765  1.266904
# ++++++++++++++++++++ Dataset Normalizado 2 +++++++++++++++++++++++
#          Theta        VD        VE
# 0.00 -0.147046  1.268765  1.266904
# 0.07 -0.147046  1.268765  1.266904
# 0.14 -0.147046  1.268765  1.266904
# 0.21 -0.147046  1.268765  1.266904
# 0.28 -0.147046  1.268765  1.266904
# ++++++++++++++++++++ Dataset Normalizado 3 +++++++++++++++++++++++
#          Theta        VD        VE
# 0.00 -0.147046  0.098819  0.089409
# 0.07 -0.147046  1.268765  1.266904
# 0.14 -0.147046  1.268765  1.266904
# 0.21 -0.147046  1.268765  1.266904
# 0.28 -0.147046  1.268765  1.266904

# %%
x_train = np.array(TrainDataset[PREDICTORS])
y_train = np.array(TrainDataset[TARGET])

x_val = np.array((NormDatasets[1])[PREDICTORS])
y_val = np.array((NormDatasets[1])[TARGET])

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")
# Out:
# Dimensão da entrada: (2146, 2)
# Dimensão da saida: (2146, 1)

# %%
import matplotlib.pyplot as plt

def PlotHistory(history):
    plt.figure(figsize=(8, 5))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('MSE Loss')
    plt.title('Training History')
    plt.legend()
    plt.grid(True)
    plt.show()
    
def PlotOut(axs, title, y_true, y_pred):
    y_true = np.ravel(y_true)
    y_pred = np.ravel(y_pred)
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    axs.scatter(time, y_true, marker='o', label='Amostras Reais')
    axs.scatter(time, y_pred, marker='x', label='Valores Preditos')
    axs.set_title(f'{title}')
    axs.set_xlabel('Theta')
    axs.set_ylabel('tempo')
    axs.legend()
    axs.grid(True)

# %%
from sklearn.metrics import mean_squared_error, r2_score

TITLES = ["Training", "Validation", "Test 1", "Test 2"]

def EvalModel(model):
    fig, axs = plt.subplots(4, 1, figsize=(12, 12))
    for i, dataset in enumerate(NormDatasets):
        x = np.array(dataset[PREDICTORS])
        y = OUT_SCALER.inverse_transform(dataset[TARGET])
        y_pred = OUT_SCALER.inverse_transform(model.predict(x))
    
        R2 = r2_score(y, y_pred)
        MSE = mean_squared_error(y, y_pred)
        print(f"R²_{TITLES[i]} = {R2}")
        print(f"MSE_{TITLES[i]} = {MSE}")
        
        PlotOut(axs[i], TITLES[i], y, y_pred)

# %%
from tensorflow import keras
from keras.callbacks import EarlyStopping

INPUT_SIZE = len(PREDICTORS)  


model = keras.models.Sequential([
    keras.layers.Input(shape=(INPUT_SIZE,)),
    keras.layers.Dense(3, activation="linear"),  
    keras.layers.Dense(1)  
])
model.summary()
print(f"Pesos inciais:\n {model.get_weights()}")
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 3)              │             9 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (52.00 B)
#  Trainable params: 13 (52.00 B)
#  Non-trainable params: 0 (0.00 B)
# Pesos inciais:
#  [array([[ 0.4650334 ,  0.76533425,  0.8835982 ],
#        [ 0.81046927,  0.3637395 , -0.14343935]], dtype=float32), array([0., 0., 0.], dtype=float32), array([[0.8327962 ],
#        [0.9196719 ],
#        [0.19997287]], dtype=float32), array([0.], dtype=float32)]

# %% [markdown]
# Configures the model for training.

# %%
model.compile(loss="mean_squared_error", optimizer="adam")

# %% [markdown]
# Trains the model for a fixed number of epochs (dataset iterations).

# %%
early_stopping_monitor = EarlyStopping(monitor='val_loss',
                                patience=100,
                                restore_best_weights=True)

history = model.fit(x_train, 
                    y_train, 
                    epochs=2000,
                    callbacks=[early_stopping_monitor],
 validation_data=(x_val, y_val))
# Out:
# Epoch 1/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 5.5521 - val_loss: 4.2566
# Epoch 2/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.9009 - val_loss: 3.1000
# Epoch 3/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.9237 - val_loss: 2.3579
# Epoch 4/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.3367 - val_loss: 1.8647
# Epoch 5/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.9404 - val_loss: 1.5319
# Epoch 6/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.6832 - val_loss: 1.2915
# Epoch 7/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5339 - val_loss: 1.1255
# Epoch 8/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3290 - val_loss: 0.9952
# Epoch 9/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2205 - val_loss: 0.8984
# Epoch 10/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1558 - val_loss: 0.8286
# Epoch 11/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0976 - val_loss: 0.7786
# Epoch 12/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0169 - val_loss: 0.7476
# Epoch 13/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9997 - val_loss: 0.7307
# Epoch 14/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9820 - val_loss: 0.7201
# Epoch 15/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0177 - val_loss: 0.7159
# Epoch 16/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9804 - val_loss: 0.7106
# Epoch 17/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9891 - val_loss: 0.7103
# Epoch 18/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0076 - val_loss: 0.7094
# Epoch 19/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0046 - val_loss: 0.7077
# Epoch 20/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9440 - val_loss: 0.7083
# Epoch 21/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9582 - val_loss: 0.7087
# Epoch 22/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9844 - val_loss: 0.7081
# Epoch 23/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9616 - val_loss: 0.7087
# Epoch 24/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9911 - val_loss: 0.7057
# Epoch 25/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0229 - val_loss: 0.7065
# Epoch 26/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9973 - val_loss: 0.7053
# Epoch 27/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9545 - val_loss: 0.7050
# Epoch 28/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9406 - val_loss: 0.7049
# Epoch 29/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9525 - val_loss: 0.7053
# Epoch 30/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9338 - val_loss: 0.7049
# Epoch 31/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9725 - val_loss: 0.7016
# Epoch 32/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9817 - val_loss: 0.7025
# Epoch 33/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9574 - val_loss: 0.7012
# Epoch 34/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9766 - val_loss: 0.6976
# Epoch 35/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9492 - val_loss: 0.6979
# Epoch 36/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9869 - val_loss: 0.6973
# Epoch 37/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9738 - val_loss: 0.6959
# Epoch 38/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9932 - val_loss: 0.7001
# Epoch 39/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9514 - val_loss: 0.6977
# Epoch 40/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9703 - val_loss: 0.6973
# Epoch 41/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0014 - val_loss: 0.7010
# Epoch 42/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9651 - val_loss: 0.6965
# Epoch 43/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9727 - val_loss: 0.6958
# Epoch 44/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9607 - val_loss: 0.6952
# Epoch 45/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9327 - val_loss: 0.6963
# Epoch 46/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9741 - val_loss: 0.6942
# Epoch 47/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9988 - val_loss: 0.6921
# Epoch 48/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9501 - val_loss: 0.6947
# Epoch 49/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9605 - val_loss: 0.6948
# Epoch 50/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9507 - val_loss: 0.6949
# Epoch 51/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9885 - val_loss: 0.6957
# Epoch 52/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9372 - val_loss: 0.6926
# Epoch 53/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9616 - val_loss: 0.6918
# Epoch 54/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9831 - val_loss: 0.6900
# Epoch 55/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9556 - val_loss: 0.6942
# Epoch 56/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9238 - val_loss: 0.6910
# Epoch 57/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9315 - val_loss: 0.6926
# Epoch 58/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9301 - val_loss: 0.6885
# Epoch 59/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9674 - val_loss: 0.6890
# Epoch 60/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9456 - val_loss: 0.6902
# Epoch 61/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9409 - val_loss: 0.6900
# Epoch 62/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9143 - val_loss: 0.6897
# Epoch 63/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9673 - val_loss: 0.6876
# Epoch 64/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9727 - val_loss: 0.6876
# Epoch 65/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9108 - val_loss: 0.6884
# Epoch 66/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9229 - val_loss: 0.6889
# Epoch 67/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9691 - val_loss: 0.6863
# Epoch 68/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9541 - val_loss: 0.6852
# Epoch 69/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9501 - val_loss: 0.6861
# Epoch 70/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9161 - val_loss: 0.6851
# Epoch 71/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9322 - val_loss: 0.6838
# Epoch 72/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9448 - val_loss: 0.6850
# Epoch 73/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9602 - val_loss: 0.6888
# Epoch 74/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9515 - val_loss: 0.6864
# Epoch 75/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9041 - val_loss: 0.6855
# Epoch 76/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9658 - val_loss: 0.6881
# Epoch 77/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9305 - val_loss: 0.6902
# Epoch 78/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9722 - val_loss: 0.6877
# Epoch 79/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9495 - val_loss: 0.6865
# Epoch 80/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9268 - val_loss: 0.6851
# Epoch 81/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9672 - val_loss: 0.6868
# Epoch 82/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9316 - val_loss: 0.6880
# Epoch 83/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9296 - val_loss: 0.6891
# Epoch 84/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9546 - val_loss: 0.6903
# Epoch 85/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9833 - val_loss: 0.6874
# Epoch 86/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9535 - val_loss: 0.6884
# Epoch 87/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9468 - val_loss: 0.6891
# Epoch 88/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9833 - val_loss: 0.6880
# Epoch 89/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9753 - val_loss: 0.6874
# Epoch 90/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9657 - val_loss: 0.6872
# Epoch 91/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9338 - val_loss: 0.6878
# Epoch 92/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9468 - val_loss: 0.6885
# Epoch 93/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9638 - val_loss: 0.6877
# Epoch 94/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9480 - val_loss: 0.6863
# Epoch 95/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9616 - val_loss: 0.6843
# Epoch 96/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9549 - val_loss: 0.6852
# Epoch 97/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9482 - val_loss: 0.6840
# Epoch 98/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9380 - val_loss: 0.6838
# Epoch 99/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9351 - val_loss: 0.6844
# Epoch 100/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9567 - val_loss: 0.6849
# Epoch 101/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9401 - val_loss: 0.6846
# Epoch 102/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9272 - val_loss: 0.6865
# Epoch 103/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9250 - val_loss: 0.6849
# Epoch 104/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9747 - val_loss: 0.6839
# Epoch 105/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9449 - val_loss: 0.6852
# Epoch 106/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9641 - val_loss: 0.6854
# Epoch 107/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9653 - val_loss: 0.6893
# Epoch 108/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9271 - val_loss: 0.6855
# Epoch 109/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9331 - val_loss: 0.6865
# Epoch 110/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9452 - val_loss: 0.6856
# Epoch 111/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9159 - val_loss: 0.6856
# Epoch 112/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9548 - val_loss: 0.6848
# Epoch 113/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9856 - val_loss: 0.6855
# Epoch 114/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9572 - val_loss: 0.6868
# Epoch 115/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9571 - val_loss: 0.6852
# Epoch 116/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9641 - val_loss: 0.6862
# Epoch 117/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9103 - val_loss: 0.6832
# Epoch 118/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9573 - val_loss: 0.6847
# Epoch 119/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9551 - val_loss: 0.6831
# Epoch 120/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9398 - val_loss: 0.6823
# Epoch 121/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9705 - val_loss: 0.6856
# Epoch 122/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9563 - val_loss: 0.6842
# Epoch 123/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9740 - val_loss: 0.6862
# Epoch 124/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9592 - val_loss: 0.6863
# Epoch 125/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9500 - val_loss: 0.6847
# Epoch 126/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9768 - val_loss: 0.6869
# Epoch 127/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9544 - val_loss: 0.6851
# Epoch 128/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9644 - val_loss: 0.6866
# Epoch 129/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9524 - val_loss: 0.6859
# Epoch 130/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9506 - val_loss: 0.6880
# Epoch 131/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9365 - val_loss: 0.6864
# Epoch 132/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9754 - val_loss: 0.6882
# Epoch 133/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9643 - val_loss: 0.6855
# Epoch 134/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9188 - val_loss: 0.6850
# Epoch 135/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9443 - val_loss: 0.6873
# Epoch 136/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9145 - val_loss: 0.6860
# Epoch 137/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9169 - val_loss: 0.6852
# Epoch 138/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9831 - val_loss: 0.6873
# Epoch 139/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9730 - val_loss: 0.6869
# Epoch 140/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9615 - val_loss: 0.6868
# Epoch 141/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9670 - val_loss: 0.6873
# Epoch 142/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9690 - val_loss: 0.6866
# Epoch 143/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9457 - val_loss: 0.6853
# Epoch 144/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9883 - val_loss: 0.6828
# Epoch 145/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9786 - val_loss: 0.6855
# Epoch 146/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9672 - val_loss: 0.6813
# Epoch 147/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9374 - val_loss: 0.6852
# Epoch 148/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9381 - val_loss: 0.6863
# Epoch 149/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9689 - val_loss: 0.6849
# Epoch 150/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9453 - val_loss: 0.6863
# Epoch 151/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9190 - val_loss: 0.6843
# Epoch 152/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9783 - val_loss: 0.6887
# Epoch 153/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9356 - val_loss: 0.6861
# Epoch 154/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9659 - val_loss: 0.6821
# Epoch 155/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9763 - val_loss: 0.6830
# Epoch 156/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9534 - val_loss: 0.6864
# Epoch 157/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9430 - val_loss: 0.6858
# Epoch 158/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9238 - val_loss: 0.6856
# Epoch 159/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9835 - val_loss: 0.6877
# Epoch 160/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9456 - val_loss: 0.6881
# Epoch 161/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9616 - val_loss: 0.6868
# Epoch 162/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9717 - val_loss: 0.6852
# Epoch 163/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9415 - val_loss: 0.6871
# Epoch 164/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9600 - val_loss: 0.6865
# Epoch 165/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9504 - val_loss: 0.6827
# Epoch 166/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9581 - val_loss: 0.6874
# Epoch 167/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9607 - val_loss: 0.6868
# Epoch 168/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9784 - val_loss: 0.6919
# Epoch 169/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9745 - val_loss: 0.6884
# Epoch 170/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9427 - val_loss: 0.6872
# Epoch 171/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9232 - val_loss: 0.6870
# Epoch 172/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9328 - val_loss: 0.6853
# Epoch 173/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9198 - val_loss: 0.6844
# Epoch 174/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9313 - val_loss: 0.6868
# Epoch 175/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9225 - val_loss: 0.6846
# Epoch 176/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9282 - val_loss: 0.6846
# Epoch 177/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9584 - val_loss: 0.6872
# Epoch 178/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9482 - val_loss: 0.6844
# Epoch 179/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9279 - val_loss: 0.6853
# Epoch 180/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9555 - val_loss: 0.6854
# Epoch 181/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9294 - val_loss: 0.6823
# Epoch 182/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9427 - val_loss: 0.6868
# Epoch 183/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9553 - val_loss: 0.6885
# Epoch 184/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9560 - val_loss: 0.6874
# Epoch 185/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.9658 - val_loss: 0.6860
# Epoch 186/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9110 - val_loss: 0.6848
# Epoch 187/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9167 - val_loss: 0.6867
# Epoch 188/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9257 - val_loss: 0.6875
# Epoch 189/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9733 - val_loss: 0.6853
# Epoch 190/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9409 - val_loss: 0.6841
# Epoch 191/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9551 - val_loss: 0.6841
# Epoch 192/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9516 - val_loss: 0.6833
# Epoch 193/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9732 - val_loss: 0.6839
# Epoch 194/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9890 - val_loss: 0.6836
# Epoch 195/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9396 - val_loss: 0.6840
# Epoch 196/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9484 - val_loss: 0.6875
# Epoch 197/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9428 - val_loss: 0.6858
# Epoch 198/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9850 - val_loss: 0.6840
# Epoch 199/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9819 - val_loss: 0.6837
# Epoch 200/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9852 - val_loss: 0.6826
# Epoch 201/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9708 - val_loss: 0.6840
# Epoch 202/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9418 - val_loss: 0.6859
# Epoch 203/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9479 - val_loss: 0.6856
# Epoch 204/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9642 - val_loss: 0.6852
# Epoch 205/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9521 - val_loss: 0.6860
# Epoch 206/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9290 - val_loss: 0.6864
# Epoch 207/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9448 - val_loss: 0.6904
# Epoch 208/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9651 - val_loss: 0.6871
# Epoch 209/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9656 - val_loss: 0.6848
# Epoch 210/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9359 - val_loss: 0.6841
# Epoch 211/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9615 - val_loss: 0.6868
# Epoch 212/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9635 - val_loss: 0.6834
# Epoch 213/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9656 - val_loss: 0.6830
# Epoch 214/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9456 - val_loss: 0.6834
# Epoch 215/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9393 - val_loss: 0.6831
# Epoch 216/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9461 - val_loss: 0.6869
# Epoch 217/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9272 - val_loss: 0.6862
# Epoch 218/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9448 - val_loss: 0.6858
# Epoch 219/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9565 - val_loss: 0.6861
# Epoch 220/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9729 - val_loss: 0.6849
# Epoch 221/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9515 - val_loss: 0.6841
# Epoch 222/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9569 - val_loss: 0.6853
# Epoch 223/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0062 - val_loss: 0.6846
# Epoch 224/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9407 - val_loss: 0.6856
# Epoch 225/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9636 - val_loss: 0.6855
# Epoch 226/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9597 - val_loss: 0.6851
# Epoch 227/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9758 - val_loss: 0.6831
# Epoch 228/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9348 - val_loss: 0.6853
# Epoch 229/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9521 - val_loss: 0.6858
# Epoch 230/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9483 - val_loss: 0.6844
# Epoch 231/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9586 - val_loss: 0.6849
# Epoch 232/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9464 - val_loss: 0.6842
# Epoch 233/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9331 - val_loss: 0.6830
# Epoch 234/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9612 - val_loss: 0.6831
# Epoch 235/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9416 - val_loss: 0.6836
# Epoch 236/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9105 - val_loss: 0.6835
# Epoch 237/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9023 - val_loss: 0.6857
# Epoch 238/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9619 - val_loss: 0.6892
# Epoch 239/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9665 - val_loss: 0.6880
# Epoch 240/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9505 - val_loss: 0.6846
# Epoch 241/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9543 - val_loss: 0.6868
# Epoch 242/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9292 - val_loss: 0.6834
# Epoch 243/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9343 - val_loss: 0.6862
# Epoch 244/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9293 - val_loss: 0.6869
# Epoch 245/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9711 - val_loss: 0.6867
# Epoch 246/2000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9259 - val_loss: 0.6838

# %%
print(f"Pesos finais:\n {model.get_weights()}")
# Out:
# Pesos finais:
#  [array([[-0.10499899,  0.19378297,  1.3316898 ],
#        [ 0.6617536 ,  0.18451238, -0.518791  ]], dtype=float32), array([-0.00410051, -0.00370848,  0.00810441], dtype=float32), array([[ 0.66579765],
#        [ 0.5128242 ],
#        [-0.6748915 ]], dtype=float32), array([-0.00635505], dtype=float32)]

# %%
PlotHistory(history)

# %%
EvalModel(model)
# Out:
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# R²_Training = 0.050467259294593725
# MSE_Training = 0.24523930458701554
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# R²_Validation = 0.007199233833380281
# MSE_Validation = 0.17596550413590342
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# R²_Test 1 = 0.06839494031374604
# MSE_Test 1 = 0.23077267232825668
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# R²_Test 2 = 0.04401854354987078
# MSE_Test 2 = 0.16891258328859843
