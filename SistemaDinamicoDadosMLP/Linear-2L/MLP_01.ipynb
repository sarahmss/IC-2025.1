# %% [markdown]
# # MLP simples

# %% [markdown]
# - 1 saida - DeltaTheta
# - 2 entradas - Vd e Ve
# - 2 camadas
# - n neurônios

# %%
import pandas as pd 
import numpy as np
from sklearn.preprocessing import StandardScaler

Datasets = []
PREDICTORS = ["VD", "VE"]
TARGET = ["Theta"]

for i in range(4):   
    Dataset = pd.read_csv(f"../Dados/Data{i + 1}.csv")
    Dataset = Dataset.drop(columns=["X", "Y", "Setpoint VD", "Setpoint VE", "tempo"])
    Dataset.index = (np.arange(0, len(Dataset), 1).astype(float) * 0.07).round(5)
    Datasets.append(Dataset)
    print(f"++++++++++++++++++++ Dataset {i+1} +++++++++++++++++++++++")
    print(Datasets[i].head(5))
# Out:
# ++++++++++++++++++++ Dataset 1 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  0.00  0.00
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28    0.0  2.33  2.33
# ++++++++++++++++++++ Dataset 2 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  2.33  2.33
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28   -0.0  2.33  2.33
# ++++++++++++++++++++ Dataset 3 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  0.00  0.00
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28    0.0  2.33  2.33
# ++++++++++++++++++++ Dataset 4 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  2.33  2.33
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28    0.0  2.33  2.33

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

TrainDataset = Datasets[0]
TrainDataset[PREDICTORS] = SCALER.fit_transform(TrainDataset[PREDICTORS])
TrainDataset[TARGET] = OUT_SCALER.fit_transform(TrainDataset[TARGET])
NormDatasets.append(TrainDataset)

for i in range(3):
      CurrentTestDataset = Datasets[i + 1]
      CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
      CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
      NormDatasets.append(CurrentTestDataset)
      print(f"++++++++++++++++++++ Dataset Normalizado {i+1} +++++++++++++++++++++++")
      print(NormDatasets[i].head(5))
# Out:
# ++++++++++++++++++++ Dataset Normalizado 1 +++++++++++++++++++++++
#          Theta        VD        VE
# 0.00 -0.147046  0.098819  0.089409
# 0.07 -0.147046  1.268765  1.266904
# 0.14 -0.147046  1.268765  1.266904
# 0.21 -0.147046  1.268765  1.266904
# 0.28 -0.147046  1.268765  1.266904
# ++++++++++++++++++++ Dataset Normalizado 2 +++++++++++++++++++++++
#          Theta        VD        VE
# 0.00 -0.147046  1.268765  1.266904
# 0.07 -0.147046  1.268765  1.266904
# 0.14 -0.147046  1.268765  1.266904
# 0.21 -0.147046  1.268765  1.266904
# 0.28 -0.147046  1.268765  1.266904
# ++++++++++++++++++++ Dataset Normalizado 3 +++++++++++++++++++++++
#          Theta        VD        VE
# 0.00 -0.147046  0.098819  0.089409
# 0.07 -0.147046  1.268765  1.266904
# 0.14 -0.147046  1.268765  1.266904
# 0.21 -0.147046  1.268765  1.266904
# 0.28 -0.147046  1.268765  1.266904

# %%
x_train = np.array(TrainDataset[PREDICTORS])
y_train = np.array(TrainDataset[TARGET])

x_val = np.array((NormDatasets[1])[PREDICTORS])
y_val = np.array((NormDatasets[1])[TARGET])

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")
# Out:
# Dimensão da entrada: (2146, 2)
# Dimensão da saida: (2146, 1)

# %%
import matplotlib.pyplot as plt

def PlotHistory(history):
    plt.figure(figsize=(8, 5))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('MSE Loss')
    plt.title('Training History')
    plt.legend()
    plt.grid(True)
    plt.show()
    
def PlotOut(axs, title, y_true, y_pred):
    y_true = np.ravel(y_true)
    y_pred = np.ravel(y_pred)
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    axs.scatter(time, y_true, marker='o', label='Amostras Reais')
    axs.scatter(time, y_pred, marker='x', label='Valores Preditos')
    axs.set_title(f'{title}')
    axs.set_xlabel('Theta')
    axs.set_ylabel('tempo')
    axs.legend()
    axs.grid(True)

# %%
from sklearn.metrics import mean_squared_error, r2_score

TITLES = ["Training", "Validation", "Test 1", "Test 2"]

def EvalModel(model):
    fig, axs = plt.subplots(4, 1, figsize=(12, 12))
    for i, dataset in enumerate(NormDatasets):
        x = np.array(dataset[PREDICTORS])
        y = OUT_SCALER.inverse_transform(dataset[TARGET])
        y_pred = OUT_SCALER.inverse_transform(model.predict(x))
    
        R2 = r2_score(y, y_pred)
        MSE = mean_squared_error(y, y_pred)
        print(f"R²_{TITLES[i]} = {R2}")
        print(f"MSE_{TITLES[i]} = {MSE}")
        
        PlotOut(axs[i], TITLES[i], y, y_pred)

# %%
from tensorflow import keras
from keras.callbacks import EarlyStopping

INPUT_SIZE = len(PREDICTORS)  


model = keras.models.Sequential([
    keras.layers.Input(shape=(INPUT_SIZE,)),
    keras.layers.Dense(1, activation="linear"),  
    keras.layers.Dense(1)  
])
model.summary()
print(f"Pesos inciais:\n {model.get_weights()}")
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1)              │             3 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5 (20.00 B)
#  Trainable params: 5 (20.00 B)
#  Non-trainable params: 0 (0.00 B)
# Pesos inciais:
#  [array([[ 0.2697897],
#        [-1.176212 ]], dtype=float32), array([0.], dtype=float32), array([[0.07144332]], dtype=float32), array([0.], dtype=float32)]

# %% [markdown]
# Configures the model for training.

# %%
model.compile(loss="mean_squared_error", optimizer="adam")

# %% [markdown]
# Trains the model for a fixed number of epochs (dataset iterations).

# %%
early_stopping_monitor = EarlyStopping(monitor='val_loss',
                                patience=50,
                                restore_best_weights=True)

history = model.fit(x_train, 
                    y_train, 
                    epochs=1000,
                    callbacks=[early_stopping_monitor],
 validation_data=(x_val, y_val))
# Out:
# Epoch 1/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.0341 - val_loss: 0.7240
# Epoch 2/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0115 - val_loss: 0.7191
# Epoch 3/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9850 - val_loss: 0.7190
# Epoch 4/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.9890 - val_loss: 0.7200
# Epoch 5/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0034 - val_loss: 0.7192
# Epoch 6/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9942 - val_loss: 0.7186
# Epoch 7/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0155 - val_loss: 0.7186
# Epoch 8/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9863 - val_loss: 0.7168
# Epoch 9/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9939 - val_loss: 0.7173
# Epoch 10/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9985 - val_loss: 0.7166
# Epoch 11/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9967 - val_loss: 0.7155
# Epoch 12/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9878 - val_loss: 0.7136
# Epoch 13/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0231 - val_loss: 0.7136
# Epoch 14/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9795 - val_loss: 0.7113
# Epoch 15/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0188 - val_loss: 0.7125
# Epoch 16/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9850 - val_loss: 0.7106
# Epoch 17/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9882 - val_loss: 0.7095
# Epoch 18/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9934 - val_loss: 0.7072
# Epoch 19/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9912 - val_loss: 0.7042
# Epoch 20/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9628 - val_loss: 0.7025
# Epoch 21/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.9739 - val_loss: 0.7002
# Epoch 22/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9427 - val_loss: 0.7021
# Epoch 23/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9661 - val_loss: 0.6983
# Epoch 24/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9426 - val_loss: 0.6974
# Epoch 25/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9303 - val_loss: 0.6952
# Epoch 26/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9810 - val_loss: 0.6972
# Epoch 27/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.9306 - val_loss: 0.6944
# Epoch 28/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9317 - val_loss: 0.6933
# Epoch 29/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9446 - val_loss: 0.6948
# Epoch 30/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9211 - val_loss: 0.6944
# Epoch 31/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9677 - val_loss: 0.6914
# Epoch 32/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9309 - val_loss: 0.6894
# Epoch 33/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9433 - val_loss: 0.6908
# Epoch 34/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9559 - val_loss: 0.6886
# Epoch 35/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9811 - val_loss: 0.6886
# Epoch 36/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9645 - val_loss: 0.6869
# Epoch 37/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9652 - val_loss: 0.6851
# Epoch 38/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9350 - val_loss: 0.6868
# Epoch 39/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9157 - val_loss: 0.6849
# Epoch 40/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9397 - val_loss: 0.6859
# Epoch 41/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9359 - val_loss: 0.6879
# Epoch 42/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9287 - val_loss: 0.6850
# Epoch 43/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9764 - val_loss: 0.6854
# Epoch 44/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9259 - val_loss: 0.6856
# Epoch 45/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9535 - val_loss: 0.6879
# Epoch 46/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9854 - val_loss: 0.6882
# Epoch 47/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9770 - val_loss: 0.6876
# Epoch 48/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9516 - val_loss: 0.6866
# Epoch 49/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9403 - val_loss: 0.6853
# Epoch 50/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9457 - val_loss: 0.6865
# Epoch 51/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9388 - val_loss: 0.6887
# Epoch 52/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9775 - val_loss: 0.6877
# Epoch 53/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9334 - val_loss: 0.6859
# Epoch 54/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9466 - val_loss: 0.6868
# Epoch 55/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9209 - val_loss: 0.6866
# Epoch 56/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9399 - val_loss: 0.6878
# Epoch 57/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9727 - val_loss: 0.6873
# Epoch 58/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9298 - val_loss: 0.6873
# Epoch 59/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9481 - val_loss: 0.6878
# Epoch 60/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9634 - val_loss: 0.6860
# Epoch 61/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9359 - val_loss: 0.6859
# Epoch 62/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9331 - val_loss: 0.6850
# Epoch 63/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9628 - val_loss: 0.6875
# Epoch 64/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9494 - val_loss: 0.6862
# Epoch 65/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9532 - val_loss: 0.6861
# Epoch 66/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9575 - val_loss: 0.6860
# Epoch 67/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9416 - val_loss: 0.6877
# Epoch 68/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9222 - val_loss: 0.6859
# Epoch 69/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9461 - val_loss: 0.6857
# Epoch 70/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9083 - val_loss: 0.6864
# Epoch 71/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9181 - val_loss: 0.6859
# Epoch 72/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9771 - val_loss: 0.6864
# Epoch 73/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9398 - val_loss: 0.6860
# Epoch 74/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9618 - val_loss: 0.6848
# Epoch 75/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9608 - val_loss: 0.6885
# Epoch 76/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9667 - val_loss: 0.6862
# Epoch 77/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9568 - val_loss: 0.6863
# Epoch 78/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9821 - val_loss: 0.6855
# Epoch 79/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9510 - val_loss: 0.6861
# Epoch 80/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9514 - val_loss: 0.6860
# Epoch 81/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9457 - val_loss: 0.6865
# Epoch 82/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9165 - val_loss: 0.6857
# Epoch 83/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9426 - val_loss: 0.6839
# Epoch 84/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9573 - val_loss: 0.6830
# Epoch 85/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9398 - val_loss: 0.6835
# Epoch 86/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9852 - val_loss: 0.6845
# Epoch 87/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9403 - val_loss: 0.6857
# Epoch 88/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9260 - val_loss: 0.6841
# Epoch 89/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9379 - val_loss: 0.6857
# Epoch 90/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9616 - val_loss: 0.6872
# Epoch 91/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9395 - val_loss: 0.6855
# Epoch 92/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9451 - val_loss: 0.6866
# Epoch 93/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9727 - val_loss: 0.6894
# Epoch 94/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9331 - val_loss: 0.6863
# Epoch 95/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9463 - val_loss: 0.6871
# Epoch 96/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9397 - val_loss: 0.6875
# Epoch 97/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9756 - val_loss: 0.6887
# Epoch 98/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9488 - val_loss: 0.6877
# Epoch 99/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9619 - val_loss: 0.6859
# Epoch 100/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9606 - val_loss: 0.6862
# Epoch 101/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9503 - val_loss: 0.6856
# Epoch 102/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9521 - val_loss: 0.6851
# Epoch 103/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9662 - val_loss: 0.6851
# Epoch 104/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9813 - val_loss: 0.6848
# Epoch 105/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9504 - val_loss: 0.6846
# Epoch 106/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9353 - val_loss: 0.6854
# Epoch 107/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9760 - val_loss: 0.6871
# Epoch 108/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9488 - val_loss: 0.6879
# Epoch 109/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9347 - val_loss: 0.6859
# Epoch 110/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9507 - val_loss: 0.6843
# Epoch 111/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9578 - val_loss: 0.6864
# Epoch 112/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9469 - val_loss: 0.6867
# Epoch 113/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9359 - val_loss: 0.6860
# Epoch 114/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9404 - val_loss: 0.6852
# Epoch 115/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9628 - val_loss: 0.6863
# Epoch 116/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9492 - val_loss: 0.6879
# Epoch 117/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9499 - val_loss: 0.6885
# Epoch 118/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9572 - val_loss: 0.6877
# Epoch 119/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9341 - val_loss: 0.6890
# Epoch 120/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9634 - val_loss: 0.6881
# Epoch 121/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9692 - val_loss: 0.6864
# Epoch 122/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9334 - val_loss: 0.6845
# Epoch 123/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9782 - val_loss: 0.6855
# Epoch 124/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9595 - val_loss: 0.6838
# Epoch 125/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9357 - val_loss: 0.6840
# Epoch 126/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9482 - val_loss: 0.6860
# Epoch 127/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9828 - val_loss: 0.6853
# Epoch 128/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9382 - val_loss: 0.6868
# Epoch 129/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9500 - val_loss: 0.6871
# Epoch 130/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9372 - val_loss: 0.6867
# Epoch 131/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9614 - val_loss: 0.6857
# Epoch 132/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9465 - val_loss: 0.6854
# Epoch 133/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9704 - val_loss: 0.6854
# Epoch 134/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9549 - val_loss: 0.6874

# %%
print(f"Pesos finais:\n {model.get_weights()}")
# Out:
# Pesos finais:
#  [array([[ 1.1459528],
#        [-1.1691189]], dtype=float32), array([0.00572313], dtype=float32), array([[-0.75405246]], dtype=float32), array([-0.00666476], dtype=float32)]

# %%
PlotHistory(history)

# %%
EvalModel(model)
# Out:
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# R²_Training = 0.050591118382806166
# MSE_Training = 0.24520731504588877
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# R²_Validation = 0.004702604837974356
# MSE_Validation = 0.1764080104219463
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# R²_Test 1 = 0.06756103540725145
# MSE_Test 1 = 0.23097924319403132
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# R²_Test 2 = 0.039789006031415775
# MSE_Test 2 = 0.16965990124496463
