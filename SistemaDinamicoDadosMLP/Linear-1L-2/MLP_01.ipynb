# %% [markdown]
# # MLP simples com a diferença

# %% [markdown]
# - 1 saida - DeltaTheta
# - 2 entradas - Vd e Ve
# - 1 camada
# - 1 neurônio

# %%
import pandas as pd 
import numpy as np
from sklearn.preprocessing import StandardScaler

Datasets = []
PREDICTORS = ["VD", "VE"]
TARGET = ["Theta"]

for i in range(4):   
    Dataset = pd.read_csv(f"../Dados/Data{i + 1}.csv")
    Dataset = Dataset.drop(columns=["X", "Y", "Setpoint VD", "Setpoint VE", "tempo"])
    Dataset.index = (np.arange(0, len(Dataset), 1).astype(float) * 0.07).round(5)
    Datasets.append(Dataset)
    print(f"++++++++++++++++++++ Dataset {i+1} +++++++++++++++++++++++")
    print(Datasets[i].head(5))
# Out:
# ++++++++++++++++++++ Dataset 1 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  0.00  0.00
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28    0.0  2.33  2.33
# ++++++++++++++++++++ Dataset 2 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  2.33  2.33
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28   -0.0  2.33  2.33
# ++++++++++++++++++++ Dataset 3 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  0.00  0.00
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28    0.0  2.33  2.33
# ++++++++++++++++++++ Dataset 4 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  2.33  2.33
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28    0.0  2.33  2.33

# %%
for  i in range(4):
    Dataset = Datasets[i].copy()  # evita sobrescrever o original
    Dataset["DeltaTheta"] = Dataset[TARGET].shift(-1) - Dataset[TARGET]
    # ou equivalente: Dataset["DeltaTheta"] = Dataset[TARGET].diff().shift(-1)
    
    # remove o último NaN (último ponto não tem próximo valor)
    Dataset = Dataset.dropna(subset=["DeltaTheta"])
    Datasets[i] = Dataset
    print(f"++++++++++++++++++++ Dataset {i+1} +++++++++++++++++++++++")
    print(Datasets[i].tail(5))
# Out:
# ++++++++++++++++++++ Dataset 1 +++++++++++++++++++++++
#         Theta    VD    VE  DeltaTheta
# 149.80  -0.81 -2.20 -2.38        0.00
# 149.87  -0.81 -2.23 -2.40        0.01
# 149.94  -0.80 -2.41 -2.24        0.00
# 150.01  -0.80 -2.40 -2.22        0.00
# 150.08  -0.80 -2.40 -2.22        0.00
# ++++++++++++++++++++ Dataset 2 +++++++++++++++++++++++
#         Theta    VD    VE  DeltaTheta
# 141.47   0.73 -2.22 -2.40        0.00
# 141.54   0.73 -2.23 -2.40        0.00
# 141.61   0.73 -2.23 -2.40        0.01
# 141.68   0.74 -2.24 -2.41        0.00
# 141.75   0.74 -2.41 -2.25        0.00
# ++++++++++++++++++++ Dataset 3 +++++++++++++++++++++++
#        Theta    VD    VE  DeltaTheta
# 92.40  -0.81 -2.36 -2.18        0.00
# 92.47  -0.81 -2.37 -2.19        0.00
# 92.54  -0.81 -2.37 -2.19       -0.01
# 92.61  -0.82 -2.37 -2.18       -0.01
# 92.68  -0.83 -2.38 -2.20       -0.01
# ++++++++++++++++++++ Dataset 4 +++++++++++++++++++++++
#         Theta    VD    VE  DeltaTheta
# 114.17   0.74 -2.09 -2.30        0.00
# 114.24   0.74 -2.11 -2.31        0.01
# 114.31   0.75 -2.12 -2.32        0.00
# 114.38   0.75 -2.13 -2.33        0.01
# 114.45   0.76 -2.13 -2.33        0.00

# %%
NormDatasets = []

TARGET = ["DeltaTheta"]
SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

TrainDataset = Datasets[0]
TrainDataset[PREDICTORS] = SCALER.fit_transform(TrainDataset[PREDICTORS])
TrainDataset[TARGET] = OUT_SCALER.fit_transform(TrainDataset[TARGET])
NormDatasets.append(TrainDataset)

for i in range(3):
      CurrentTestDataset = Datasets[i + 1]
      CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
      CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
      NormDatasets.append(CurrentTestDataset)
      print(f"++++++++++++++++++++ Dataset Normalizado {i+1} +++++++++++++++++++++++")
      print(NormDatasets[i].head(5))
# Out:
# ++++++++++++++++++++ Dataset Normalizado 1 +++++++++++++++++++++++
#       Theta        VD        VE  DeltaTheta
# 0.00    0.0  0.098309  0.088927    0.035731
# 0.07    0.0  1.268315  1.266443    0.035731
# 0.14    0.0  1.268315  1.266443    0.035731
# 0.21    0.0  1.268315  1.266443    0.035731
# 0.28    0.0  1.268315  1.266443    0.035731
# ++++++++++++++++++++ Dataset Normalizado 2 +++++++++++++++++++++++
#       Theta        VD        VE  DeltaTheta
# 0.00    0.0  1.268315  1.266443    0.035731
# 0.07    0.0  1.268315  1.266443    0.035731
# 0.14    0.0  1.268315  1.266443    0.035731
# 0.21    0.0  1.268315  1.266443    0.035731
# 0.28   -0.0  1.268315  1.266443    0.035731
# ++++++++++++++++++++ Dataset Normalizado 3 +++++++++++++++++++++++
#       Theta        VD        VE  DeltaTheta
# 0.00    0.0  0.098309  0.088927    0.035731
# 0.07    0.0  1.268315  1.266443    0.035731
# 0.14    0.0  1.268315  1.266443    0.035731
# 0.21    0.0  1.268315  1.266443    0.035731
# 0.28    0.0  1.268315  1.266443    0.035731

# %%
x_train = np.array(TrainDataset[PREDICTORS])
y_train = np.array(TrainDataset[TARGET])

x_val = np.array((NormDatasets[1])[PREDICTORS])
y_val = np.array((NormDatasets[1])[TARGET])

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")
# Out:
# Dimensão da entrada: (2145, 2)
# Dimensão da saida: (2145, 1)

# %%
import matplotlib.pyplot as plt

def PlotHistory(history):
    plt.figure(figsize=(8, 5))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('MSE Loss')
    plt.title('Training History')
    plt.legend()
    plt.grid(True)
    plt.show()
    
def PlotOut(axs, title, y_true, y_pred):
    y_true = np.ravel(y_true)
    y_pred = np.ravel(y_pred)
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    axs.scatter(time, y_true, marker='o', label='Amostras Reais')
    axs.scatter(time, y_pred, marker='x', label='Valores Preditos')
    axs.set_title(f'{title}')
    axs.set_xlabel('Theta')
    axs.set_ylabel('tempo')
    axs.legend()
    axs.grid(True)

# %%
from sklearn.metrics import mean_squared_error, r2_score

TITLES = ["Training", "Validation", "Test 1", "Test 2"]

def EvalModel(model):
    fig, axs = plt.subplots(4, 1, figsize=(12, 12))
    for i, dataset in enumerate(NormDatasets):
        x = np.array(dataset[PREDICTORS])
        
        # diferenças reais e previstas (já desnormalizadas)
        y_diff = OUT_SCALER.inverse_transform(dataset[TARGET])
        y_pred_diff = OUT_SCALER.inverse_transform(model.predict(x))
        
        # valor inicial de theta no dataset original (não normalizado)
        theta0 = Datasets[i]["Theta"].iloc[0]  
        
        # reconstrução: soma cumulativa
        y_real = theta0 + np.cumsum(y_diff, axis=0)
        y_pred = theta0 + np.cumsum(y_pred_diff, axis=0)
        
        # métricas no espaço de θ
        R2 = r2_score(y_real, y_pred)
        MSE = mean_squared_error(y_real, y_pred)
        print(f"R²_{TITLES[i]} = {R2}")
        print(f"MSE_{TITLES[i]} = {MSE}")
        
        # plota saída
        PlotOut(axs[i], TITLES[i], y_real, y_pred)

# %%
from tensorflow import keras
from keras.callbacks import EarlyStopping

INPUT_SIZE = len(PREDICTORS)  


model = keras.models.Sequential([
    keras.layers.Input(shape=(INPUT_SIZE,)),
    keras.layers.Dense(1, activation="linear"),  
])
model.summary()
print(f"Pesos inciais:\n {model.get_weights()}")
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3 (12.00 B)
#  Trainable params: 3 (12.00 B)
#  Non-trainable params: 0 (0.00 B)
# Pesos inciais:
#  [array([[ 1.3313636],
#        [-1.3201064]], dtype=float32), array([0.], dtype=float32)]

# %% [markdown]
# Configures the model for training.

# %%
model.compile(loss="mean_squared_error", optimizer="adam")

# %% [markdown]
# Trains the model for a fixed number of epochs (dataset iterations).

# %%
early_stopping_monitor = EarlyStopping(monitor='val_loss',
                                patience=50,
                                restore_best_weights=True)

history = model.fit(x_train, 
                    y_train, 
                    epochs=1000,
                    callbacks=[early_stopping_monitor],
 validation_data=(x_val, y_val))
# Out:
# Epoch 1/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.8958 - val_loss: 0.8312
# Epoch 2/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.7882 - val_loss: 0.8312
# Epoch 3/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.8596 - val_loss: 0.8310
# Epoch 4/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9622 - val_loss: 0.8307
# Epoch 5/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.1881 - val_loss: 0.8310
# Epoch 6/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.8962 - val_loss: 0.8311
# Epoch 7/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9489 - val_loss: 0.8310
# Epoch 8/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9878 - val_loss: 0.8308
# Epoch 9/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.0137 - val_loss: 0.8307
# Epoch 10/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9309 - val_loss: 0.8310
# Epoch 11/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9838 - val_loss: 0.8308
# Epoch 12/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.8823 - val_loss: 0.8312
# Epoch 13/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9578 - val_loss: 0.8347
# Epoch 14/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9768 - val_loss: 0.8335
# Epoch 15/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9682 - val_loss: 0.8326
# Epoch 16/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9155 - val_loss: 0.8315
# Epoch 17/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9082 - val_loss: 0.8311
# Epoch 18/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.8741 - val_loss: 0.8311
# Epoch 19/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0574 - val_loss: 0.8309
# Epoch 20/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9673 - val_loss: 0.8311
# Epoch 21/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.8064 - val_loss: 0.8310
# Epoch 22/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9106 - val_loss: 0.8297
# Epoch 23/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9193 - val_loss: 0.8295
# Epoch 24/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.1320 - val_loss: 0.8298
# Epoch 25/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9438 - val_loss: 0.8303
# Epoch 26/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9955 - val_loss: 0.8301
# Epoch 27/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8850 - val_loss: 0.8303
# Epoch 28/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8956 - val_loss: 0.8306
# Epoch 29/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0059 - val_loss: 0.8302
# Epoch 30/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.0343 - val_loss: 0.8293
# Epoch 31/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.8718 - val_loss: 0.8301
# Epoch 32/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8664 - val_loss: 0.8301
# Epoch 33/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9891 - val_loss: 0.8304
# Epoch 34/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9369 - val_loss: 0.8307
# Epoch 35/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9695 - val_loss: 0.8306
# Epoch 36/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.8953 - val_loss: 0.8306
# Epoch 37/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8322 - val_loss: 0.8310
# Epoch 38/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9388 - val_loss: 0.8309
# Epoch 39/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.8789 - val_loss: 0.8306
# Epoch 40/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9970 - val_loss: 0.8314
# Epoch 41/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9469 - val_loss: 0.8309
# Epoch 42/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.8315 - val_loss: 0.8318
# Epoch 43/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9662 - val_loss: 0.8314
# Epoch 44/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.8912 - val_loss: 0.8320
# Epoch 45/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0832 - val_loss: 0.8319
# Epoch 46/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9912 - val_loss: 0.8314
# Epoch 47/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9890 - val_loss: 0.8310
# Epoch 48/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9541 - val_loss: 0.8313
# Epoch 49/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.8841 - val_loss: 0.8311
# Epoch 50/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9691 - val_loss: 0.8314
# Epoch 51/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9037 - val_loss: 0.8314
# Epoch 52/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9504 - val_loss: 0.8316
# Epoch 53/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0470 - val_loss: 0.8311
# Epoch 54/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.8896 - val_loss: 0.8310
# Epoch 55/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0428 - val_loss: 0.8313
# Epoch 56/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0344 - val_loss: 0.8314
# Epoch 57/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9270 - val_loss: 0.8311
# Epoch 58/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9245 - val_loss: 0.8313
# Epoch 59/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9163 - val_loss: 0.8309
# Epoch 60/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8496 - val_loss: 0.8317
# Epoch 61/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0706 - val_loss: 0.8317
# Epoch 62/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9151 - val_loss: 0.8317
# Epoch 63/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9496 - val_loss: 0.8315
# Epoch 64/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9168 - val_loss: 0.8317
# Epoch 65/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0774 - val_loss: 0.8322
# Epoch 66/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9021 - val_loss: 0.8320
# Epoch 67/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8433 - val_loss: 0.8319
# Epoch 68/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8611 - val_loss: 0.8320
# Epoch 69/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9721 - val_loss: 0.8316
# Epoch 70/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9186 - val_loss: 0.8317
# Epoch 71/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0095 - val_loss: 0.8314
# Epoch 72/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7907 - val_loss: 0.8319
# Epoch 73/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9243 - val_loss: 0.8346
# Epoch 74/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9920 - val_loss: 0.8328
# Epoch 75/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7928 - val_loss: 0.8322
# Epoch 76/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8933 - val_loss: 0.8324
# Epoch 77/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.8564 - val_loss: 0.8327
# Epoch 78/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0090 - val_loss: 0.8320
# Epoch 79/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9880 - val_loss: 0.8318
# Epoch 80/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9394 - val_loss: 0.8321

# %%
print(f"Pesos finais:\n {model.get_weights()}")
# Out:
# Pesos finais:
#  [array([[ 1.1979755],
#        [-1.1949567]], dtype=float32), array([0.01386856], dtype=float32)]

# %%
PlotHistory(history)

# %%
EvalModel(model)
# Out:
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# R²_Training = 0.4603911838607505
# MSE_Training = 0.1394303159711176
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# R²_Validation = 0.38885616634022435
# MSE_Validation = 0.10837341904768506
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# R²_Test 1 = 0.5348871813460225
# MSE_Test 1 = 0.11530201511041263
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# R²_Test 2 = 0.33973232147641896
# MSE_Test 2 = 0.11673244588869912
