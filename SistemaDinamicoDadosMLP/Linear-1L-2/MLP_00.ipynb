# %% [markdown]
# # MLP simples com a diferença

# %% [markdown]
# - 1 saida - DeltaTheta
# - 2 entradas - Vd e Ve
# - 1 camada
# - 1 neurônio

# %%
import pandas as pd 
import numpy as np
from sklearn.preprocessing import StandardScaler

Datasets = []
PREDICTORS = ["VD", "VE"]
TARGET = ["Theta"]

for i in range(4):   
    Dataset = pd.read_csv(f"../Dados/Data{i + 1}.csv")
    Dataset = Dataset.drop(columns=["X", "Y", "Setpoint VD", "Setpoint VE", "tempo"])
    Dataset.index = (np.arange(0, len(Dataset), 1).astype(float) * 0.07).round(5)
    Datasets.append(Dataset)
    print(f"++++++++++++++++++++ Dataset {i+1} +++++++++++++++++++++++")
    print(Datasets[i].head(5))
# Out:
# ++++++++++++++++++++ Dataset 1 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  0.00  0.00
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28    0.0  2.33  2.33
# ++++++++++++++++++++ Dataset 2 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  2.33  2.33
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28   -0.0  2.33  2.33
# ++++++++++++++++++++ Dataset 3 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  0.00  0.00
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28    0.0  2.33  2.33
# ++++++++++++++++++++ Dataset 4 +++++++++++++++++++++++
#       Theta    VD    VE
# 0.00    0.0  2.33  2.33
# 0.07    0.0  2.33  2.33
# 0.14    0.0  2.33  2.33
# 0.21    0.0  2.33  2.33
# 0.28    0.0  2.33  2.33

# %%
for  i in range(4):
    Dataset = Datasets[i].copy()  # evita sobrescrever o original
    Dataset["DeltaTheta"] = Dataset[TARGET].shift(-1) - Dataset[TARGET]
    # ou equivalente: Dataset["DeltaTheta"] = Dataset[TARGET].diff().shift(-1)
    
    # remove o último NaN (último ponto não tem próximo valor)
    Dataset = Dataset.dropna(subset=["DeltaTheta"])
    Datasets[i] = Dataset
    print(f"++++++++++++++++++++ Dataset {i+1} +++++++++++++++++++++++")
    print(Datasets[i].tail(5))
# Out:
# ++++++++++++++++++++ Dataset 1 +++++++++++++++++++++++
#         Theta    VD    VE  DeltaTheta
# 149.80  -0.81 -2.20 -2.38        0.00
# 149.87  -0.81 -2.23 -2.40        0.01
# 149.94  -0.80 -2.41 -2.24        0.00
# 150.01  -0.80 -2.40 -2.22        0.00
# 150.08  -0.80 -2.40 -2.22        0.00
# ++++++++++++++++++++ Dataset 2 +++++++++++++++++++++++
#         Theta    VD    VE  DeltaTheta
# 141.47   0.73 -2.22 -2.40        0.00
# 141.54   0.73 -2.23 -2.40        0.00
# 141.61   0.73 -2.23 -2.40        0.01
# 141.68   0.74 -2.24 -2.41        0.00
# 141.75   0.74 -2.41 -2.25        0.00
# ++++++++++++++++++++ Dataset 3 +++++++++++++++++++++++
#        Theta    VD    VE  DeltaTheta
# 92.40  -0.81 -2.36 -2.18        0.00
# 92.47  -0.81 -2.37 -2.19        0.00
# 92.54  -0.81 -2.37 -2.19       -0.01
# 92.61  -0.82 -2.37 -2.18       -0.01
# 92.68  -0.83 -2.38 -2.20       -0.01
# ++++++++++++++++++++ Dataset 4 +++++++++++++++++++++++
#         Theta    VD    VE  DeltaTheta
# 114.17   0.74 -2.09 -2.30        0.00
# 114.24   0.74 -2.11 -2.31        0.01
# 114.31   0.75 -2.12 -2.32        0.00
# 114.38   0.75 -2.13 -2.33        0.01
# 114.45   0.76 -2.13 -2.33        0.00

# %%
NormDatasets = []

TARGET = ["DeltaTheta"]
SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

TrainDataset = Datasets[0]
TrainDataset[PREDICTORS] = SCALER.fit_transform(TrainDataset[PREDICTORS])
TrainDataset[TARGET] = OUT_SCALER.fit_transform(TrainDataset[TARGET])
NormDatasets.append(TrainDataset)

for i in range(3):
      CurrentTestDataset = Datasets[i + 1]
      CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
      CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
      NormDatasets.append(CurrentTestDataset)
      print(f"++++++++++++++++++++ Dataset Normalizado {i+1} +++++++++++++++++++++++")
      print(NormDatasets[i].head(5))
# Out:
# ++++++++++++++++++++ Dataset Normalizado 1 +++++++++++++++++++++++
#       Theta        VD        VE  DeltaTheta
# 0.00    0.0  0.098309  0.088927    0.035731
# 0.07    0.0  1.268315  1.266443    0.035731
# 0.14    0.0  1.268315  1.266443    0.035731
# 0.21    0.0  1.268315  1.266443    0.035731
# 0.28    0.0  1.268315  1.266443    0.035731
# ++++++++++++++++++++ Dataset Normalizado 2 +++++++++++++++++++++++
#       Theta        VD        VE  DeltaTheta
# 0.00    0.0  1.268315  1.266443    0.035731
# 0.07    0.0  1.268315  1.266443    0.035731
# 0.14    0.0  1.268315  1.266443    0.035731
# 0.21    0.0  1.268315  1.266443    0.035731
# 0.28   -0.0  1.268315  1.266443    0.035731
# ++++++++++++++++++++ Dataset Normalizado 3 +++++++++++++++++++++++
#       Theta        VD        VE  DeltaTheta
# 0.00    0.0  0.098309  0.088927    0.035731
# 0.07    0.0  1.268315  1.266443    0.035731
# 0.14    0.0  1.268315  1.266443    0.035731
# 0.21    0.0  1.268315  1.266443    0.035731
# 0.28    0.0  1.268315  1.266443    0.035731

# %%
x_train = np.array(TrainDataset[PREDICTORS])
y_train = np.array(TrainDataset[TARGET])

x_val = np.array((NormDatasets[1])[PREDICTORS])
y_val = np.array((NormDatasets[1])[TARGET])

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")
# Out:
# Dimensão da entrada: (2145, 2)
# Dimensão da saida: (2145, 1)

# %%
import matplotlib.pyplot as plt

def PlotHistory(history):
    plt.figure(figsize=(8, 5))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('MSE Loss')
    plt.title('Training History')
    plt.legend()
    plt.grid(True)
    plt.show()
    
def PlotOut(axs, title, y_true, y_pred):
    y_true = np.ravel(y_true)
    y_pred = np.ravel(y_pred)
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    axs.scatter(time, y_true, marker='o', label='Amostras Reais')
    axs.scatter(time, y_pred, marker='x', label='Valores Preditos')
    axs.set_title(f'{title}')
    axs.set_xlabel('Theta')
    axs.set_ylabel('tempo')
    axs.legend()
    axs.grid(True)

# %%
from sklearn.metrics import mean_squared_error, r2_score

TITLES = ["Training", "Validation", "Test 1", "Test 2"]

def EvalModel(model):
    fig, axs = plt.subplots(4, 1, figsize=(12, 12))
    for i, dataset in enumerate(NormDatasets):
        x = np.array(dataset[PREDICTORS])
        
        # diferenças reais e previstas (já desnormalizadas)
        y_diff = OUT_SCALER.inverse_transform(dataset[TARGET])
        y_pred_diff = OUT_SCALER.inverse_transform(model.predict(x))
        
        # valor inicial de theta no dataset original (não normalizado)
        theta0 = Datasets[i]["Theta"].iloc[0]  
        
        # reconstrução: soma cumulativa
        y_real = theta0 + np.cumsum(y_diff, axis=0)
        y_pred = theta0 + np.cumsum(y_pred_diff, axis=0)
        
        # métricas no espaço de θ
        R2 = r2_score(y_real, y_pred)
        MSE = mean_squared_error(y_real, y_pred)
        print(f"R²_{TITLES[i]} = {R2}")
        print(f"MSE_{TITLES[i]} = {MSE}")
        
        # plota saída
        PlotOut(axs[i], TITLES[i], y_real, y_pred)

# %%
from tensorflow import keras
from keras.callbacks import EarlyStopping

INPUT_SIZE = len(PREDICTORS)  


model = keras.models.Sequential([
    keras.layers.Input(shape=(INPUT_SIZE,)),
    keras.layers.Dense(1, activation="linear"),  
])
model.summary()
print(f"Pesos inciais:\n {model.get_weights()}")
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3 (12.00 B)
#  Trainable params: 3 (12.00 B)
#  Non-trainable params: 0 (0.00 B)
# Pesos inciais:
#  [array([[0.13783002],
#        [1.2452809 ]], dtype=float32), array([0.], dtype=float32)]

# %% [markdown]
# Configures the model for training.

# %%
model.compile(loss="mean_squared_error", optimizer="adam")

# %% [markdown]
# Trains the model for a fixed number of epochs (dataset iterations).

# %%
early_stopping_monitor = EarlyStopping(monitor='val_loss',
                                patience=50,
                                restore_best_weights=True)

history = model.fit(x_train, 
                    y_train, 
                    epochs=1000,
                    callbacks=[early_stopping_monitor],
 validation_data=(x_val, y_val))
# Out:
# Epoch 1/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 2.7819 - val_loss: 2.7359
# Epoch 2/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.3149 - val_loss: 2.4041
# Epoch 3/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.1843 - val_loss: 2.1226
# Epoch 4/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.9673 - val_loss: 1.8876
# Epoch 5/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.5748 - val_loss: 1.6923
# Epoch 6/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6185 - val_loss: 1.5328
# Epoch 7/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6767 - val_loss: 1.4053
# Epoch 8/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.4681 - val_loss: 1.3022
# Epoch 9/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.3308 - val_loss: 1.2192
# Epoch 10/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.1855 - val_loss: 1.1570
# Epoch 11/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.2720 - val_loss: 1.1065
# Epoch 12/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.2437 - val_loss: 1.0691
# Epoch 13/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.1822 - val_loss: 1.0408
# Epoch 14/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.0984 - val_loss: 1.0215
# Epoch 15/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.0922 - val_loss: 1.0083
# Epoch 16/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2945 - val_loss: 0.9956
# Epoch 17/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.0875 - val_loss: 0.9864
# Epoch 18/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.1861 - val_loss: 0.9791
# Epoch 19/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.1692 - val_loss: 0.9746
# Epoch 20/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.0551 - val_loss: 0.9704
# Epoch 21/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.0696 - val_loss: 0.9679
# Epoch 22/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.1485 - val_loss: 0.9643
# Epoch 23/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.1829 - val_loss: 0.9627
# Epoch 24/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9951 - val_loss: 0.9604
# Epoch 25/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.0649 - val_loss: 0.9597
# Epoch 26/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0410 - val_loss: 0.9576
# Epoch 27/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0548 - val_loss: 0.9562
# Epoch 28/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.0720 - val_loss: 0.9551
# Epoch 29/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.1750 - val_loss: 0.9520
# Epoch 30/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.2083 - val_loss: 0.9510
# Epoch 31/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9980 - val_loss: 0.9503
# Epoch 32/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.1388 - val_loss: 0.9489
# Epoch 33/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0778 - val_loss: 0.9473
# Epoch 34/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9776 - val_loss: 0.9462
# Epoch 35/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.2325 - val_loss: 0.9446
# Epoch 36/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9604 - val_loss: 0.9439
# Epoch 37/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9280 - val_loss: 0.9424
# Epoch 38/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0345 - val_loss: 0.9410
# Epoch 39/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.0707 - val_loss: 0.9418
# Epoch 40/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0744 - val_loss: 0.9399
# Epoch 41/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9937 - val_loss: 0.9385
# Epoch 42/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9945 - val_loss: 0.9357
# Epoch 43/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0549 - val_loss: 0.9350
# Epoch 44/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0244 - val_loss: 0.9329
# Epoch 45/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9876 - val_loss: 0.9312
# Epoch 46/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9936 - val_loss: 0.9297
# Epoch 47/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9010 - val_loss: 0.9279
# Epoch 48/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0479 - val_loss: 0.9256
# Epoch 49/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9816 - val_loss: 0.9247
# Epoch 50/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9839 - val_loss: 0.9230
# Epoch 51/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9287 - val_loss: 0.9209
# Epoch 52/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9575 - val_loss: 0.9200
# Epoch 53/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9276 - val_loss: 0.9188
# Epoch 54/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.1528 - val_loss: 0.9169
# Epoch 55/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0021 - val_loss: 0.9164
# Epoch 56/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1948 - val_loss: 0.9147
# Epoch 57/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0461 - val_loss: 0.9133
# Epoch 58/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9193 - val_loss: 0.9101
# Epoch 59/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.0584 - val_loss: 0.9093
# Epoch 60/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1394 - val_loss: 0.9094
# Epoch 61/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0922 - val_loss: 0.9076
# Epoch 62/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8912 - val_loss: 0.9062
# Epoch 63/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9787 - val_loss: 0.9046
# Epoch 64/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9060 - val_loss: 0.9049
# Epoch 65/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9232 - val_loss: 0.9028
# Epoch 66/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0525 - val_loss: 0.9014
# Epoch 67/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8270 - val_loss: 0.8999
# Epoch 68/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1089 - val_loss: 0.8974
# Epoch 69/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9069 - val_loss: 0.8955
# Epoch 70/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1360 - val_loss: 0.8947
# Epoch 71/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9966 - val_loss: 0.8944
# Epoch 72/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0607 - val_loss: 0.8932
# Epoch 73/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9595 - val_loss: 0.8913
# Epoch 74/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0791 - val_loss: 0.8915
# Epoch 75/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9411 - val_loss: 0.8911
# Epoch 76/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1055 - val_loss: 0.8895
# Epoch 77/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0010 - val_loss: 0.8883
# Epoch 78/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9892 - val_loss: 0.8872
# Epoch 79/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0526 - val_loss: 0.8856
# Epoch 80/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9140 - val_loss: 0.8852
# Epoch 81/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9726 - val_loss: 0.8853
# Epoch 82/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0998 - val_loss: 0.8833
# Epoch 83/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9626 - val_loss: 0.8826
# Epoch 84/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9057 - val_loss: 0.8816
# Epoch 85/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8492 - val_loss: 0.8772
# Epoch 86/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0198 - val_loss: 0.8776
# Epoch 87/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9384 - val_loss: 0.8774
# Epoch 88/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.1113 - val_loss: 0.8770
# Epoch 89/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9427 - val_loss: 0.8763
# Epoch 90/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0237 - val_loss: 0.8762
# Epoch 91/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9650 - val_loss: 0.8762
# Epoch 92/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9181 - val_loss: 0.8744
# Epoch 93/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0408 - val_loss: 0.8739
# Epoch 94/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7994 - val_loss: 0.8735
# Epoch 95/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1281 - val_loss: 0.8726
# Epoch 96/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.9626 - val_loss: 0.8721
# Epoch 97/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9673 - val_loss: 0.8713
# Epoch 98/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0305 - val_loss: 0.8722
# Epoch 99/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0605 - val_loss: 0.8712
# Epoch 100/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9678 - val_loss: 0.8701
# Epoch 101/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9507 - val_loss: 0.8702
# Epoch 102/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7878 - val_loss: 0.8688
# Epoch 103/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8717 - val_loss: 0.8675
# Epoch 104/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9220 - val_loss: 0.8657
# Epoch 105/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9787 - val_loss: 0.8648
# Epoch 106/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9523 - val_loss: 0.8650
# Epoch 107/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8796 - val_loss: 0.8660
# Epoch 108/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9372 - val_loss: 0.8646
# Epoch 109/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9870 - val_loss: 0.8628
# Epoch 110/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0216 - val_loss: 0.8629
# Epoch 111/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8649 - val_loss: 0.8627
# Epoch 112/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0522 - val_loss: 0.8620
# Epoch 113/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8753 - val_loss: 0.8613
# Epoch 114/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9011 - val_loss: 0.8609
# Epoch 115/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0878 - val_loss: 0.8607
# Epoch 116/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0127 - val_loss: 0.8603
# Epoch 117/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9443 - val_loss: 0.8596
# Epoch 118/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8837 - val_loss: 0.8586
# Epoch 119/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8839 - val_loss: 0.8587
# Epoch 120/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9520 - val_loss: 0.8585
# Epoch 121/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8083 - val_loss: 0.8580
# Epoch 122/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9190 - val_loss: 0.8575
# Epoch 123/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0418 - val_loss: 0.8576
# Epoch 124/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9976 - val_loss: 0.8566
# Epoch 125/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9822 - val_loss: 0.8559
# Epoch 126/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9203 - val_loss: 0.8559
# Epoch 127/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9956 - val_loss: 0.8552
# Epoch 128/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9533 - val_loss: 0.8548
# Epoch 129/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8696 - val_loss: 0.8538
# Epoch 130/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8976 - val_loss: 0.8538
# Epoch 131/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8265 - val_loss: 0.8531
# Epoch 132/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9669 - val_loss: 0.8536
# Epoch 133/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8762 - val_loss: 0.8531
# Epoch 134/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0582 - val_loss: 0.8527
# Epoch 135/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0426 - val_loss: 0.8520
# Epoch 136/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9367 - val_loss: 0.8522
# Epoch 137/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9201 - val_loss: 0.8521
# Epoch 138/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9139 - val_loss: 0.8521
# Epoch 139/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9513 - val_loss: 0.8510
# Epoch 140/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0926 - val_loss: 0.8497
# Epoch 141/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9375 - val_loss: 0.8494
# Epoch 142/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9482 - val_loss: 0.8496
# Epoch 143/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8653 - val_loss: 0.8488
# Epoch 144/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8175 - val_loss: 0.8482
# Epoch 145/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1160 - val_loss: 0.8485
# Epoch 146/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8598 - val_loss: 0.8475
# Epoch 147/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0765 - val_loss: 0.8478
# Epoch 148/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9406 - val_loss: 0.8477
# Epoch 149/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9335 - val_loss: 0.8474
# Epoch 150/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9710 - val_loss: 0.8473
# Epoch 151/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8499 - val_loss: 0.8468
# Epoch 152/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9870 - val_loss: 0.8458
# Epoch 153/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0684 - val_loss: 0.8452
# Epoch 154/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9905 - val_loss: 0.8450
# Epoch 155/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8700 - val_loss: 0.8456
# Epoch 156/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9747 - val_loss: 0.8453
# Epoch 157/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8589 - val_loss: 0.8457
# Epoch 158/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9753 - val_loss: 0.8457
# Epoch 159/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9937 - val_loss: 0.8466
# Epoch 160/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9822 - val_loss: 0.8457
# Epoch 161/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9182 - val_loss: 0.8452
# Epoch 162/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9084 - val_loss: 0.8442
# Epoch 163/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1356 - val_loss: 0.8445
# Epoch 164/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9036 - val_loss: 0.8448
# Epoch 165/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2027 - val_loss: 0.8453
# Epoch 166/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8634 - val_loss: 0.8444
# Epoch 167/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0763 - val_loss: 0.8448
# Epoch 168/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9968 - val_loss: 0.8448
# Epoch 169/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9538 - val_loss: 0.8445
# Epoch 170/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9586 - val_loss: 0.8433
# Epoch 171/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0532 - val_loss: 0.8432
# Epoch 172/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9260 - val_loss: 0.8428
# Epoch 173/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0279 - val_loss: 0.8433
# Epoch 174/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9113 - val_loss: 0.8431
# Epoch 175/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0333 - val_loss: 0.8429
# Epoch 176/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9503 - val_loss: 0.8433
# Epoch 177/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8432 - val_loss: 0.8432
# Epoch 178/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9961 - val_loss: 0.8426
# Epoch 179/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9628 - val_loss: 0.8404
# Epoch 180/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9224 - val_loss: 0.8416
# Epoch 181/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9173 - val_loss: 0.8411
# Epoch 182/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9258 - val_loss: 0.8412
# Epoch 183/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0349 - val_loss: 0.8417
# Epoch 184/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0757 - val_loss: 0.8416
# Epoch 185/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9167 - val_loss: 0.8410
# Epoch 186/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9056 - val_loss: 0.8422
# Epoch 187/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9680 - val_loss: 0.8416
# Epoch 188/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9721 - val_loss: 0.8409
# Epoch 189/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8365 - val_loss: 0.8411
# Epoch 190/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0292 - val_loss: 0.8404
# Epoch 191/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9401 - val_loss: 0.8396
# Epoch 192/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8917 - val_loss: 0.8400
# Epoch 193/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8651 - val_loss: 0.8407
# Epoch 194/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8720 - val_loss: 0.8404
# Epoch 195/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9963 - val_loss: 0.8402
# Epoch 196/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9565 - val_loss: 0.8402
# Epoch 197/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8694 - val_loss: 0.8400
# Epoch 198/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9427 - val_loss: 0.8402
# Epoch 199/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8946 - val_loss: 0.8403
# Epoch 200/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9690 - val_loss: 0.8403
# Epoch 201/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8237 - val_loss: 0.8405
# Epoch 202/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8085 - val_loss: 0.8403
# Epoch 203/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8418 - val_loss: 0.8405
# Epoch 204/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9358 - val_loss: 0.8393
# Epoch 205/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9108 - val_loss: 0.8395
# Epoch 206/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9875 - val_loss: 0.8394
# Epoch 207/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9534 - val_loss: 0.8397
# Epoch 208/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9294 - val_loss: 0.8397
# Epoch 209/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9899 - val_loss: 0.8397
# Epoch 210/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9984 - val_loss: 0.8399
# Epoch 211/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9773 - val_loss: 0.8394
# Epoch 212/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9245 - val_loss: 0.8391
# Epoch 213/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0654 - val_loss: 0.8391
# Epoch 214/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8512 - val_loss: 0.8388
# Epoch 215/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0100 - val_loss: 0.8394
# Epoch 216/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0983 - val_loss: 0.8395
# Epoch 217/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9693 - val_loss: 0.8401
# Epoch 218/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9048 - val_loss: 0.8399
# Epoch 219/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9353 - val_loss: 0.8397
# Epoch 220/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8201 - val_loss: 0.8379
# Epoch 221/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0769 - val_loss: 0.8387
# Epoch 222/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0997 - val_loss: 0.8386
# Epoch 223/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9196 - val_loss: 0.8385
# Epoch 224/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1378 - val_loss: 0.8388
# Epoch 225/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9877 - val_loss: 0.8382
# Epoch 226/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0497 - val_loss: 0.8377
# Epoch 227/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9927 - val_loss: 0.8378
# Epoch 228/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8895 - val_loss: 0.8376
# Epoch 229/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8755 - val_loss: 0.8373
# Epoch 230/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9491 - val_loss: 0.8379
# Epoch 231/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1660 - val_loss: 0.8372
# Epoch 232/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8741 - val_loss: 0.8374
# Epoch 233/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9459 - val_loss: 0.8376
# Epoch 234/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8887 - val_loss: 0.8372
# Epoch 235/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9342 - val_loss: 0.8376
# Epoch 236/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7797 - val_loss: 0.8375
# Epoch 237/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9473 - val_loss: 0.8379
# Epoch 238/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8354 - val_loss: 0.8380
# Epoch 239/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.8985 - val_loss: 0.8378
# Epoch 240/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9432 - val_loss: 0.8377
# Epoch 241/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8833 - val_loss: 0.8379
# Epoch 242/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.8644 - val_loss: 0.8387
# Epoch 243/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8716 - val_loss: 0.8379
# Epoch 244/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9553 - val_loss: 0.8375
# Epoch 245/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9178 - val_loss: 0.8377
# Epoch 246/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9082 - val_loss: 0.8379
# Epoch 247/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8517 - val_loss: 0.8398
# Epoch 248/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9305 - val_loss: 0.8369
# Epoch 249/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9844 - val_loss: 0.8377
# Epoch 250/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8172 - val_loss: 0.8372
# Epoch 251/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8922 - val_loss: 0.8371
# Epoch 252/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9818 - val_loss: 0.8373
# Epoch 253/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7818 - val_loss: 0.8371
# Epoch 254/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9903 - val_loss: 0.8372
# Epoch 255/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8215 - val_loss: 0.8370
# Epoch 256/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9433 - val_loss: 0.8371
# Epoch 257/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8550 - val_loss: 0.8369
# Epoch 258/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8164 - val_loss: 0.8368
# Epoch 259/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0894 - val_loss: 0.8368
# Epoch 260/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9088 - val_loss: 0.8369
# Epoch 261/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8916 - val_loss: 0.8369
# Epoch 262/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8556 - val_loss: 0.8371
# Epoch 263/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0565 - val_loss: 0.8367
# Epoch 264/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8903 - val_loss: 0.8370
# Epoch 265/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9817 - val_loss: 0.8365
# Epoch 266/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8787 - val_loss: 0.8363
# Epoch 267/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9442 - val_loss: 0.8364
# Epoch 268/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8128 - val_loss: 0.8369
# Epoch 269/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8881 - val_loss: 0.8365
# Epoch 270/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9296 - val_loss: 0.8365
# Epoch 271/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9184 - val_loss: 0.8364
# Epoch 272/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9900 - val_loss: 0.8363
# Epoch 273/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9370 - val_loss: 0.8371
# Epoch 274/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9002 - val_loss: 0.8376
# Epoch 275/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8910 - val_loss: 0.8368
# Epoch 276/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8976 - val_loss: 0.8367
# Epoch 277/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0092 - val_loss: 0.8366
# Epoch 278/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9363 - val_loss: 0.8363
# Epoch 279/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1134 - val_loss: 0.8364
# Epoch 280/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9127 - val_loss: 0.8364
# Epoch 281/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9408 - val_loss: 0.8360
# Epoch 282/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8522 - val_loss: 0.8363
# Epoch 283/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0472 - val_loss: 0.8363
# Epoch 284/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8944 - val_loss: 0.8362
# Epoch 285/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9140 - val_loss: 0.8361
# Epoch 286/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8493 - val_loss: 0.8364
# Epoch 287/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8945 - val_loss: 0.8361
# Epoch 288/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0970 - val_loss: 0.8359
# Epoch 289/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8519 - val_loss: 0.8362
# Epoch 290/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8815 - val_loss: 0.8361
# Epoch 291/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0429 - val_loss: 0.8361
# Epoch 292/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9458 - val_loss: 0.8364
# Epoch 293/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9014 - val_loss: 0.8362
# Epoch 294/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9675 - val_loss: 0.8360
# Epoch 295/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9191 - val_loss: 0.8359
# Epoch 296/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8071 - val_loss: 0.8358
# Epoch 297/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9704 - val_loss: 0.8355
# Epoch 298/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8676 - val_loss: 0.8357
# Epoch 299/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9094 - val_loss: 0.8360
# Epoch 300/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9147 - val_loss: 0.8361
# Epoch 301/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9082 - val_loss: 0.8367
# Epoch 302/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8044 - val_loss: 0.8359
# Epoch 303/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9677 - val_loss: 0.8352
# Epoch 304/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0048 - val_loss: 0.8358
# Epoch 305/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0115 - val_loss: 0.8365
# Epoch 306/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8756 - val_loss: 0.8361
# Epoch 307/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9263 - val_loss: 0.8343
# Epoch 308/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9109 - val_loss: 0.8344
# Epoch 309/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9192 - val_loss: 0.8350
# Epoch 310/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8219 - val_loss: 0.8353
# Epoch 311/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9673 - val_loss: 0.8354
# Epoch 312/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1649 - val_loss: 0.8359
# Epoch 313/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8615 - val_loss: 0.8359
# Epoch 314/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9905 - val_loss: 0.8357
# Epoch 315/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9727 - val_loss: 0.8358
# Epoch 316/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9304 - val_loss: 0.8358
# Epoch 317/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9621 - val_loss: 0.8362
# Epoch 318/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8652 - val_loss: 0.8358
# Epoch 319/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8329 - val_loss: 0.8362
# Epoch 320/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9100 - val_loss: 0.8357
# Epoch 321/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9458 - val_loss: 0.8362
# Epoch 322/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0800 - val_loss: 0.8357
# Epoch 323/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1085 - val_loss: 0.8359
# Epoch 324/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9275 - val_loss: 0.8357
# Epoch 325/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9954 - val_loss: 0.8361
# Epoch 326/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.8935 - val_loss: 0.8360
# Epoch 327/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.8859 - val_loss: 0.8366
# Epoch 328/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8544 - val_loss: 0.8365
# Epoch 329/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9483 - val_loss: 0.8359
# Epoch 330/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9867 - val_loss: 0.8360
# Epoch 331/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9674 - val_loss: 0.8361
# Epoch 332/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9144 - val_loss: 0.8359
# Epoch 333/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9211 - val_loss: 0.8355
# Epoch 334/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0019 - val_loss: 0.8359
# Epoch 335/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9216 - val_loss: 0.8363
# Epoch 336/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8349 - val_loss: 0.8362
# Epoch 337/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8966 - val_loss: 0.8365
# Epoch 338/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8493 - val_loss: 0.8365
# Epoch 339/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8662 - val_loss: 0.8364
# Epoch 340/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9352 - val_loss: 0.8364
# Epoch 341/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0323 - val_loss: 0.8359
# Epoch 342/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0242 - val_loss: 0.8356
# Epoch 343/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9139 - val_loss: 0.8356
# Epoch 344/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0112 - val_loss: 0.8352
# Epoch 345/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8256 - val_loss: 0.8359
# Epoch 346/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9603 - val_loss: 0.8356
# Epoch 347/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0160 - val_loss: 0.8357
# Epoch 348/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8532 - val_loss: 0.8354
# Epoch 349/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0197 - val_loss: 0.8360
# Epoch 350/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9722 - val_loss: 0.8364
# Epoch 351/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1085 - val_loss: 0.8361
# Epoch 352/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8648 - val_loss: 0.8358
# Epoch 353/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9786 - val_loss: 0.8346
# Epoch 354/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0367 - val_loss: 0.8341
# Epoch 355/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0884 - val_loss: 0.8341
# Epoch 356/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0446 - val_loss: 0.8342
# Epoch 357/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8930 - val_loss: 0.8339
# Epoch 358/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9196 - val_loss: 0.8337
# Epoch 359/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8845 - val_loss: 0.8343
# Epoch 360/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9905 - val_loss: 0.8342
# Epoch 361/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1065 - val_loss: 0.8348
# Epoch 362/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8772 - val_loss: 0.8348
# Epoch 363/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9402 - val_loss: 0.8349
# Epoch 364/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9674 - val_loss: 0.8357
# Epoch 365/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0373 - val_loss: 0.8351
# Epoch 366/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9098 - val_loss: 0.8353
# Epoch 367/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9050 - val_loss: 0.8355
# Epoch 368/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8548 - val_loss: 0.8352
# Epoch 369/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9767 - val_loss: 0.8352
# Epoch 370/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9296 - val_loss: 0.8354
# Epoch 371/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8845 - val_loss: 0.8367
# Epoch 372/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9205 - val_loss: 0.8364
# Epoch 373/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9146 - val_loss: 0.8361
# Epoch 374/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0589 - val_loss: 0.8358
# Epoch 375/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9289 - val_loss: 0.8350
# Epoch 376/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0262 - val_loss: 0.8350
# Epoch 377/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9014 - val_loss: 0.8362
# Epoch 378/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8913 - val_loss: 0.8358
# Epoch 379/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9289 - val_loss: 0.8353
# Epoch 380/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9083 - val_loss: 0.8359
# Epoch 381/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7889 - val_loss: 0.8367
# Epoch 382/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9110 - val_loss: 0.8356
# Epoch 383/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9239 - val_loss: 0.8357
# Epoch 384/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0207 - val_loss: 0.8353
# Epoch 385/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8945 - val_loss: 0.8366
# Epoch 386/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9498 - val_loss: 0.8362
# Epoch 387/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8514 - val_loss: 0.8359
# Epoch 388/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9079 - val_loss: 0.8354
# Epoch 389/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8171 - val_loss: 0.8352
# Epoch 390/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8638 - val_loss: 0.8349
# Epoch 391/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9970 - val_loss: 0.8353
# Epoch 392/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8576 - val_loss: 0.8375
# Epoch 393/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9630 - val_loss: 0.8363
# Epoch 394/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0143 - val_loss: 0.8353
# Epoch 395/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0219 - val_loss: 0.8350
# Epoch 396/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8613 - val_loss: 0.8353
# Epoch 397/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9063 - val_loss: 0.8351
# Epoch 398/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9768 - val_loss: 0.8349
# Epoch 399/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9073 - val_loss: 0.8340
# Epoch 400/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8903 - val_loss: 0.8349
# Epoch 401/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9636 - val_loss: 0.8354
# Epoch 402/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9741 - val_loss: 0.8349
# Epoch 403/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1401 - val_loss: 0.8356
# Epoch 404/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8739 - val_loss: 0.8358
# Epoch 405/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8640 - val_loss: 0.8348
# Epoch 406/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9934 - val_loss: 0.8348
# Epoch 407/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9034 - val_loss: 0.8346
# Epoch 408/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8872 - val_loss: 0.8353

# %%
print(f"Pesos finais:\n {model.get_weights()}")
# Out:
# Pesos finais:
#  [array([[ 0.9202193 ],
#        [-0.89770377]], dtype=float32), array([0.01563294], dtype=float32)]

# %%
PlotHistory(history)

# %%
EvalModel(model)
# Out:
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# R²_Training = 0.4662027411183325
# MSE_Training = 0.13792865914032967
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# R²_Validation = 0.262640572643025
# MSE_Validation = 0.13075508220574572
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# R²_Test 1 = 0.4727037438133259
# MSE_Test 1 = 0.1307173624550887
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# R²_Test 2 = 0.2601163493888655
# MSE_Test 2 = 0.13080820251874986
